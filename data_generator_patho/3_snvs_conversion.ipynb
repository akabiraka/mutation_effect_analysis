# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
home_dir = "../"

import pandas as pd

# %%
from Bio.PDB.Polypeptide import protein_letters_3to1
protein_letters_1to3 = {value:key for key, value in protein_letters_3to1.items()}

def one_to_three(aa):
    if str.upper(aa) in protein_letters_1to3:
        return protein_letters_1to3[str.upper(aa)]
    return aa

def three_to_one(aa):
    if str.upper(aa) in protein_letters_3to1:
        return protein_letters_3to1[str.upper(aa)]
    return aa

def get_variants_df(df:pd.DataFrame, patho_type=None):
    variants = []
    n_datapoints_losing=0
    for row_i in range(df.shape[0]):
        # print(df.loc[row_i])

        clinical_sig = df.loc[row_i, "Clinical significance (Last reviewed)"]
        if "Likely pathogenic" in clinical_sig:
            class_name = "Likely-pathogenic"
        else: class_name = "Pathogenic"

        # mapping protein to genomic variant
        x = df.loc[row_i, "Name"].split()

        is_mapped = False
        if len(x)!=2: 
            # print(x) 
            # print(df.loc[row_i])
            prot_variants = df.loc[row_i, "Protein change"].split(", ")
            chrom_variants = df.loc[row_i, "Canonical SPDI"].split("|")
            is_mapped = True
            
            if len(prot_variants)!=len(chrom_variants): # these are the cases when number of prot variants does not match with the number of genomic variants, skipping them
                print(df.loc[row_i, "VariationID"], x, prot_variants, chrom_variants)
                n_datapoints_losing+=1
                prot_variants, chrom_variants = [], []
                # raise
        else:
            prot_variants = [x[1]]
            chrom_variants = [df.loc[row_i, "Canonical SPDI"]]

        # this should never occur, but for sanity check it is here.
        if len(prot_variants)!=len(chrom_variants): raise 

        for prot_v, chrom_v in list(zip(prot_variants, chrom_variants)):
            # print(prot_v, chrom_v)

            new_v = {"clinvar_id": df.loc[row_i, "VariationID"],
                    "gene_name": df.loc[row_i, "Symbol"],
                    "gene_id": df.loc[row_i, "GeneID"], 
                    "snp_id": df.loc[row_i, "dbSNP ID"],
                    "mrna_acc_version": df.loc[row_i, "RNA_nucleotide_accession.version"],
                    "mrna_gi": df.loc[row_i, "RNA_nucleotide_gi"],

                    "prot_variant": prot_v,
                    "prot_acc_version": df.loc[row_i, "protein_accession.version"],
                    "1indexed_prot_mt_pos": prot_v[1:-1] if is_mapped else prot_v[6:-4], #not converting into integer, since there can be "p.Ser151_Gly152delinsTyrGlu" type of mutation, which we are not considering
                    "wt_aa": one_to_three(prot_v[0]) if is_mapped else prot_v[3:6],
                    "mt_aa": one_to_three(prot_v[-1]) if is_mapped else prot_v[-4:-1],
                    "wt_aa_1letter": prot_v[0] if is_mapped else three_to_one(prot_v[3:6]),
                    "mt_aa_1letter": prot_v[-1] if is_mapped else three_to_one(prot_v[-4:-1]),

                    "chrom_variant": chrom_v,
                    "chrom_acc_version": chrom_v.split(":")[0],
                    "chrom_num": int(chrom_v.split(":")[0][chrom_v.index('_')+1 : chrom_v.index('.')]),
                    "chrom_pos": int(chrom_v.split(":")[1])+1, # chr-pos in Canonical SPDI is 0-indexed, so adding 1 to make it 1-indexed
                    "ref_allele": chrom_v.split(":")[2],
                    "alt_allele": chrom_v.split(":")[3],

                    "class": class_name
            }
            variants.append(new_v)

    print("#-data-points not match protvariants vs genomicvariants:", n_datapoints_losing)
    variants_df = pd.DataFrame(variants)
    return variants_df

# %%
inp_filepath = home_dir+"data/clinvar/filtered/clinvar_HumanPathogenicMissenseVariants01012022To01072023.txt"
df = pd.read_csv(inp_filepath, sep="\t")
print(df.shape)
patho_variants_df = get_variants_df(df)
print(patho_variants_df.shape)
# Out:
# (4206, 34)
# 2018405 ['NM_001370658.1(BTD):c.399+2T>G'] ['V155G', 'V134G'] ['NC_000003.12:15642058:T:G']
# 1723345 ['NM_000500.9(CYP21A2):c.[710T>A;713T>A]'] ['V238E', 'V103E', 'V208E', 'I237N', 'I207N', 'I102N'] ['NC_000006.12:32039809:T:A', 'NC_000006.12:32039806:T:A']
# 1695398 ['NM_014251.3(SLC25A13):c.[1956C>A;1962del]'] ['N652K', 'N653K', 'F654fs', 'F655fs'] ['NC_000007.14:96121262:G:T', 'NC_000007.14:96121256:AAA:AA']
# 1702645 ['NM_014491.4(FOXP2):c.1266+1G>C'] ['V423L', 'V448L'] ['NC_000007.14:114654009:G:C']
# 1683486 ['NM_004318.4(ASPH):c.323-11619A>G'] ['K202R', 'K217R'] ['NC_000008.11:61665278:T:C']
# 1683485 ['NM_004318.4(ASPH):c.323-11779G>C'] ['D149H', 'D164H'] ['NC_000008.11:61665438:C:G']
# 1683484 ['NM_004318.4(ASPH):c.322+12720A>C'] ['K103T', 'K88T'] ['NC_000008.11:61668247:T:G']
# 1701017 ['NM_001375567.1(FOCAD):c.[1687C>T;3694G>C]'] ['A1232P', 'A1197P', 'R563C', 'R528C'] ['NC_000009.12:20948288:G:C', 'NC_000009.12:20820964:C:T']
# 1705146 ['NM_000155.4(GALT):c.[413C>T;469G>A]'] ['T29M', 'V157I', 'V48I'] ['NC_000009.12:34647866:C:T', 'NC_000009.12:34647922:G:A']
# 2109602 ['NM_000548.5(TSC2):c.336+1G>T'] ['V64L', 'V113L'] ['NC_000016.10:2053452:G:T']
# 1256048 ['NM_001399.5(EDA):c.[866G>C;868A>T]'] ['R286P', 'R289P', 'S287C', 'S290C'] ['NC_000023.11:70033469:G:C', 'NC_000023.11:70033471:A:T']
# #-data-points not match protvariants vs genomicvariants: 11
# (4204, 20)

# %%
inp_filepath = home_dir+"data/clinvar/filtered/clinvar_HumanLikelyPathogenicMissenseVariants01012022To01072023.txt"
df = pd.read_csv(inp_filepath, sep="\t")
print(df.shape)
likelypatho_variants_df = get_variants_df(df)
print(likelypatho_variants_df.shape)
# Out:
# (7815, 34)
# 1334358 ['NM_170707.4(LMNA):c.1698+1G>A'] ['V486M', 'V567M', 'V381M', 'V455M'] ['NC_000001.11:156137743:G:A']
# 1802572 ['NM_001386135.1(AFF3):c.[2151dup;3059A>G]'] ['G718fs', 'G743fs', 'Q1020R', 'Q1045R'] ['NC_000002.12:99593509:A:AA', 'NC_000002.12:99565546:T:C']
# 1342974 ['NM_001178015.2(SLC4A10):c.[1730A>T;3308A>T]'] ['K354M', 'K498M', 'K546M', 'K547M', 'K557M', 'K558M', 'K559M', 'K576M', 'K577M', 'K588M', 'K589M', 'N1024I', 'N1072I', 'N1073I', 'N1083I', 'N1084I', 'N1085I', 'N1102I', 'N1103I', 'N1114I', 'N1115I', 'N880I'] ['NC_000002.12:161904887:A:T', 'NC_000002.12:161976839:A:T']
# 1510215 ['NM_004100.5(EYA4):c.970+1G>A'] ['G324D', 'G270D'] ['NC_000006.12:133468731:G:A']
# 1802567 ['NM_152743.4(BRAT1):c.[638dup;803G>A]'] ['V214fs', 'V39fs', 'R268H', 'R93H'] ['NC_000007.14:2543754:TT:TTT', 'NC_000007.14:2543589:C:T']
# 1713142 ['NM_000238.4(KCNH2):c.2398+5G>A'] ['M461I', 'M701I', 'M705I', 'M742I', 'M801I'] ['NC_000007.14:150950162:C:T']
# 2441609 ['NM_000431.4(MVK):c.1039+1G>C'] ['G295A', 'G347A'] ['NC_000012.12:109595181:G:C']
# 2109602 ['NM_000548.5(TSC2):c.336+1G>T'] ['V64L', 'V113L'] ['NC_000016.10:2053452:G:T']
# 1802600 ['NM_017777.4(MKS1):c.[1115_1117del;1476T>G]'] ['C492W', 'C289W', 'S372del', 'S169del'] ['NC_000017.11:58206478:A:C', 'NC_000017.11:58208152:AGGAG:AG']
# 1693111 ['NM_012340.5(NFATC2):c.*71T>G'] ['S698A', 'S897A', 'S917A'] ['NC_000020.11:51391424:A:C']
# 1802598 ['NM_058004.4(PI4KA):c.[1414A>C;355C>T]'] ['S450R', 'S472R', 'R119W'] ['NC_000022.11:20804346:T:G', 'NC_000022.11:20834573:G:A']
# 1722642 ['NM_001360016.2(G6PD):c.[1376G>T;1502T>G]'] ['R459L', 'R489L', 'F501C', 'F531C'] ['NC_000023.11:154532268:C:A', 'NC_000023.11:154532045:A:C']
# 1722628 ['NM_001360016.2(G6PD):c.[1347G>C;1360C>T]'] ['R454C', 'R484C', 'Q449H', 'Q479H'] ['NC_000023.11:154532389:G:A', 'NC_000023.11:154532402:C:G']
# 1722617 ['NM_001360016.2(G6PD):c.[1159C>T;376A>G]'] ['R387C', 'R417C', 'N126D', 'N156D'] ['NC_000023.11:154532694:G:A', 'NC_000023.11:154535276:T:C']
# 1722606 ['NM_001360016.2(G6PD):c.[1048G>C;406C>T]'] ['D350H', 'D380H', 'R136C', 'R166C'] ['NC_000023.11:154532944:C:G', 'NC_000023.11:154535246:G:A']
# 1722597 ['NM_001360016.2(G6PD):c.[376A>G;871G>A]'] ['V291M', 'V321M', 'N126D', 'N156D'] ['NC_000023.11:154533121:C:T', 'NC_000023.11:154535276:T:C']
# 1722596 ['NM_001360016.2(G6PD):c.[202G>A;871G>A]'] ['V291M', 'V321M', 'V68M', 'V98M'] ['NC_000023.11:154533121:C:T', 'NC_000023.11:154536001:C:T']
# 1722747 ['NM_001360016.2(G6PD):c.[376A>G;680G>T]'] ['R227L', 'R257L', 'N126D', 'N156D'] ['NC_000023.11:154534124:C:A', 'NC_000023.11:154535276:T:C']
# 1722605 ['NM_001360016.2(G6PD):c.[1037A>T;637G>T]'] ['V213L', 'V243L', 'N346I', 'N376I'] ['NC_000023.11:154534344:C:A', 'NC_000023.11:154532955:T:A']
# 1722723 ['NM_001360016.2(G6PD):c.[375G>T;379G>T383T>C384C>T]'] ['L128P', 'L158P', 'M125I', 'M155I', 'A127S', 'A157S'] ['NC_000023.11:154535269:A:G', 'NC_000023.11:154535268:G:A', 'NC_000023.11:154535277:C:A', 'NC_000023.11:154535273:C:A']
# 1722726 ['NM_001360016.2(G6PD):c.[376A>G;463C>G]'] ['N126D', 'N156D', 'H155D', 'H185D'] ['NC_000023.11:154535276:T:C', 'NC_000023.11:154535189:G:C']
# 1722622 ['NM_001360016.2(G6PD):c.[1264C>G;202G>A376A>G]'] ['V68M', 'V98M', 'N126D', 'N156D', 'L422V', 'L452V'] ['NC_000023.11:154536001:C:T', 'NC_000023.11:154535276:T:C', 'NC_000023.11:154532589:G:C']
# 1722739 ['NM_001360016.2(G6PD):c.[143T>C;563C>T]'] ['I48T', 'I78T', 'S188F', 'S218F'] ['NC_000023.11:154536155:A:G', 'NC_000023.11:154534418:G:A']
# 1722711 ['NM_001360016.2(G6PD):c.[143T>C;202G>A]'] ['I48T', 'I78T', 'V68M', 'V98M'] ['NC_000023.11:154536155:A:G', 'NC_000023.11:154536001:C:T']
# #-data-points not match protvariants vs genomicvariants: 24
# (7797, 20)

# %%
# merging and clearning patho-&-likelypatho data
variants_df = pd.concat([patho_variants_df, likelypatho_variants_df], ignore_index=True)
print(variants_df.shape)
variants_df.drop_duplicates(keep="first", inplace=True, ignore_index=True)
print(variants_df.shape)
variants_df["class"].value_counts()
# Out:
# (12001, 20)
# (11717, 20)
# Likely-pathogenic    7753
# Pathogenic           3964
# Name: class, dtype: int64

# %%
# downloaing proteins
from utils.ncbi_proteins import download_protein_list_mpi, download_protein_list
protein_acc_list = list(variants_df["prot_acc_version"].unique())
download_protein_list(protein_acc_list, start_i=0, home_dir=home_dir) # sequential downloading
# download_protein_list_mpi(protein_acc_list, len(protein_acc_list))
print("#-unique NCBI protein sequences downloaded: ", len(protein_acc_list))
# Out:
# 0 NP_001381642.1 Already existis
# 1 NP_542172.2 Already existis
# 2 NP_060341.2 Already existis
# 3 NP_001164006.1 Already existis
# 4 NP_002065.1 Already existis
# 5 NP_000806.2 Already existis
# 6 NP_003027.1 Already existis
# 7 NP_002608.1 Already existis
# 8 NP_056030.1 Already existis
# 9 NP_009193.2 Already existis
# 10 NP_001036146.1 Already existis
# 11 NP_004276.2 Already existis
# 12 NP_005017.3 Already existis
# 13 NP_004949.1 Already existis
# 14 NP_005948.3 Already existis
# 15 NP_055689.1 Already existis
# 16 NP_055816.2 Already existis
# 17 NP_000076.2 Already existis
# 18 NP_002991.2 Already existis
# 19 NP_000469.3 Already existis
# 20 NP_115612.4 Already existis
# 21 NP_001782.1 Already existis
# 22 NP_005817.1 Already existis
# 23 NP_000138.2 Already existis
# 24 NP_065184.2 Already existis
# 25 NP_006006.3 Already existis
# 26 NP_060116.2 Already existis
# 27 NP_116182.2 Already existis
# 28 NP_000301.1 Already existis
# 29 NP_683763.2 Already existis
# 30 NP_006507.2 Already existis
# 31 NP_005364.1 Already existis
# 32 NP_001246.2 Already existis
# 33 NP_001352928.1 Already existis
# 34 NP_060620.2 Already existis
# 35 NP_000365.3 Already existis
# 36 NP_116145.1 Already existis
# 37 NP_001041639.1 Already existis
# 38 NP_060209.4 Already existis
# 39 NP_001041631.1 Already existis
# 40 NP_000089.1 Already existis
# 41 NP_000783.2 Already existis
# 42 NP_777596.2 Already existis
# 43 NP_002624.2 Already existis
# 44 NP_002218.2 Already existis
# 45 NP_000320.1 Already existis
# 46 NP_000007.1 Already existis
# 47 NP_008965.2 Already existis
# 48 NP_891993.1 Already existis
# 49 NP_958357.1 Already existis
# 50 NP_001017975.5 Already existis
# 51 NP_000960.2 Already existis
# 52 NP_000341.2 Already existis
# 53 NP_036375.1 Already existis
# 54 NP_001909.4 Already existis
# 55 NP_057042.2 Already existis
# 56 NP_001845.3 Already existis
# 57 NP_006504.2 Already existis
# 58 NP_001010898.1 Already existis
# 59 NP_004965.1 Already existis
# 60 NP_073747.1 Already existis
# 61 NP_000692.2 Already existis
# 62 NP_000189.1 Already existis
# 63 NP_006614.2 Already existis
# 64 NP_077719.2 Already existis
# 65 NP_003837.1 Already existis
# 66 NP_005258.2 Already existis
# 67 NP_001382355.1 Already existis
# 68 NP_079426.2 Already existis
# 69 NP_061905.2 Already existis
# 70 NP_000387.1 Already existis
# 71 NP_067045.1 Already existis
# 72 NP_076946.1 Already existis
# 73 NP_001356552.1 Already existis
# 74 NP_055915.2 Already existis
# 75 NP_689476.2 Already existis
# 76 NP_000739.1 Already existis
# 77 NP_000148.2 Already existis
# 78 NP_000289.1 Already existis
# 79 NP_008843.1 Already existis
# 80 NP_733821.1 Already existis
# 81 NP_658985.2 Already existis
# 82 NP_002520.2 Already existis
# 83 NP_000693.1 Already existis
# 84 NP_002848.1 Already existis
# 85 NP_001116236.1 Already existis
# 86 NP_000521.2 Already existis
# 87 NP_002992.1 Already existis
# 88 NP_796372.1 Already existis
# 89 NP_061899.3 Already existis
# 90 NP_000252.1 Already existis
# 91 NP_060592.2 Already existis
# 92 NP_000479.1 Already existis
# 93 NP_003276.3 Already existis
# 94 NP_055440.1 Already existis
# 95 NP_001192222.1 Already existis
# 96 NP_000177.2 Already existis
# 97 NP_001985.2 Already existis
# 98 NP_957705.1 Already existis
# 99 NP_000060.2 Already existis
# 100 NP_001263274.1 Already existis
# 101 NP_006609.3 Already existis
# 102 NP_057083.2 Already existis
# 103 NP_002247.3 Already existis
# 104 NP_000219.2 Already existis
# 105 NP_006138.1 Already existis
# 106 NP_758872.1 Already existis
# 107 NP_054772.1 Already existis
# 108 NP_996816.3 Already existis
# 109 NP_004437.2 Already existis
# 110 NP_055991.1 Already existis
# 111 NP_002287.2 Already existis
# 112 NP_055513.2 Already existis
# 113 NP_002098.1 Already existis
# 114 NP_002212.3 Already existis
# 115 NP_001649.1 Already existis
# 116 NP_065168.2 Already existis
# 117 NP_001091.1 Already existis
# 118 NP_001026.2 Already existis
# 119 NP_000134.2 Already existis
# 120 NP_005456.1 Already existis
# 121 NP_932342.1 Already existis
# 122 NP_114032.2 Already existis
# 123 NP_001230062.1 Already existis
# 124 NP_001071178.2 Already existis
# 125 NP_003099.1 Already existis
# 126 NP_057291.1 Already existis
# 127 NP_056993.2 Already existis
# 128 NP_005369.2 Already existis
# 129 NP_000375.3 Already existis
# 130 NP_072046.2 Already existis
# 131 NP_000174.1 Already existis
# 132 NP_002237.1 Already existis
# 133 NP_006479.1 Already existis
# 134 NP_004332.2 Already existis
# 135 NP_000339.2 Already existis
# 136 NP_055761.2 Already existis
# 137 NP_001186067.1 Already existis
# 138 NP_001129123.1 Already existis
# 139 NP_000095.2 Already existis
# 140 NP_005624.2 Already existis
# 141 NP_008818.3 Already existis
# 142 NP_000332.2 Already existis
# 143 NP_001421.2 Already existis
# 144 NP_065191.2 Already existis
# 145 NP_001734.1 Already existis
# 146 NP_002345.2 Already existis
# 147 NP_000242.1 Already existis
# 148 NP_000170.1 Already existis
# 149 NP_000224.2 Already existis
# 150 NP_003119.2 Already existis
# 151 NP_149100.2 Already existis
# 152 NP_075044.2 Already existis
# 153 NP_003029.2 Already existis
# 154 NP_001124459.1 Already existis
# 155 NP_001606.1 Already existis
# 156 NP_550438.1 Already existis
# 157 NP_004073.2 Already existis
# 158 NP_003840.2 Already existis
# 159 NP_000812.2 Already existis
# 160 NP_000533.4 Already existis
# 161 NP_001358208.1 Already existis
# 162 NP_060319.1 Already existis
# 163 NP_110432.1 Already existis
# 164 NP_064569.3 Already existis
# 165 NP_001289.1 Already existis
# 166 NP_001373064.1 Already existis
# 167 NP_006227.1 Already existis
# 168 NP_071731.1 Already existis
# 169 NP_004327.1 Already existis
# 170 NP_000303.1 Already existis
# 171 NP_525125.2 Already existis
# 172 NP_112185.1 Already existis
# 173 NP_061027.2 Already existis
# 174 NP_003928.1 Already existis
# 175 NP_001365049.1 Already existis
# 176 NP_004513.1 Already existis
# 177 NP_006177.1 Already existis
# 178 NP_038478.2 Already existis
# 179 NP_006584.1 Already existis
# 180 NP_071451.2 Already existis
# 181 NP_008853.3 Already existis
# 182 NP_001035232.1 Already existis
# 183 NP_004473.2 Already existis
# 184 NP_001159435.1 Already existis
# 185 NP_003733.2 Already existis
# 186 NP_689597.1 Already existis
# 187 NP_003696.2 Already existis
# 188 NP_001680.1 Already existis
# 189 NP_003681.1 Already existis
# 190 NP_001036167.1 Already existis
# 191 NP_963842.1 Already existis
# 192 NP_000081.2 Already existis
# 193 NP_000384.2 Already existis
# 194 NP_009330.1 Already existis
# 195 NP_061720.2 Already existis
# 196 NP_001165980.1 Already existis
# 197 NP_001358980.1 Already existis
# 198 NP_001161693.1 Already existis
# 199 NP_065970.2 Already existis
# 200 NP_001866.2 Already existis
# 201 NP_775099.2 Already existis
# 202 NP_997647.2 Already existis
# 203 NP_054859.2 Already existis
# 204 NP_005435.1 Already existis
# 205 NP_001073335.1 Already existis
# 206 NP_000775.1 Already existis
# 207 NP_079492.2 Already existis
# 208 NP_002172.2 Already existis
# 209 NP_001918.3 Already existis
# 210 NP_037467.2 Already existis
# 211 NP_005061.3 Already existis
# 212 NP_852123.1 Already existis
# 213 NP_005678.3 Already existis
# 214 NP_000083.3 Already existis
# 215 NP_000082.2 Already existis
# 216 NP_849143.1 Already existis
# 217 NP_004817.2 Already existis
# 218 NP_000742.1 Already existis
# 219 NP_000454.1 Already existis
# 220 NP_001365343.1 Already existis
# 221 NP_001230937.1 Already existis
# 222 NP_000021.1 Already existis
# 223 NP_036277.2 Already existis
# 224 NP_689996.4 Already existis
# 225 NP_001365381.1 Already existis
# 226 NP_001073986.1 Already existis
# 227 NP_001003694.1 Already existis
# 228 NP_000542.1 Already existis
# 229 NP_001001331.1 Already existis
# 230 NP_003033.3 Already existis
# 231 NP_001336161.1 Already existis
# 232 NP_001271330.1 Already existis
# 233 NP_619725.3 Already existis
# 234 NP_079541.1 Already existis
# 235 NP_005668.2 Already existis
# 236 NP_001357587.1 Already existis
# 237 NP_002962.1 Already existis
# 238 NP_002939.2 Already existis
# 239 NP_001341641.1 Already existis
# 240 NP_000956.2 Already existis
# 241 NP_060767.2 Already existis
# 242 NP_003233.4 Already existis
# 243 NP_000395.3 Already existis
# 244 NP_006362.1 Already existis
# 245 NP_000240.1 Already existis
# 246 NP_000326.2 Already existis
# 247 NP_660149.2 Already existis
# 248 NP_116195.2 Already existis
# 249 NP_060545.3 Already existis
# 250 NP_057090.2 Already existis
# 251 NP_003269.2 Already existis
# 252 NP_056155.1 Already existis
# 253 NP_054878.5 Already existis
# 254 NP_619520.1 Already existis
# 255 NP_000085.1 Already existis
# 256 NP_000378.1 Already existis
# 257 NP_005042.1 Already existis
# 258 NP_000472.2 Already existis
# 259 NP_006832.1 Already existis
# 260 NP_056980.2 Already existis
# 261 NP_006021.2 Already existis
# 262 NP_056241.3 Already existis
# 263 NP_004647.1 Already existis
# 264 NP_003271.1 Already existis
# 265 NP_001122312.1 Already existis
# 266 NP_001448.2 Already existis
# 267 NP_000916.2 Already existis
# 268 NP_060600.2 Already existis
# 269 NP_002932.1 Already existis
# 270 NP_000149.4 Already existis
# 271 NP_000304.2 Already existis
# 272 NP_001167621.1 Already existis
# 273 NP_001265222.1 Already existis
# 274 NP_006061.2 Already existis
# 275 NP_055230.2 Already existis
# 276 NP_733762.2 Already existis
# 277 NP_001681.2 Already existis
# 278 NP_001335729.1 Already existis
# 279 NP_000178.2 Already existis
# 280 NP_000379.3 Already existis
# 281 NP_899200.1 Already existis
# 282 NP_115618.3 Already existis
# 283 NP_037468.1 Already existis
# 284 NP_054768.2 Already existis
# 285 NP_000165.1 Already existis
# 286 NP_000530.1 Already existis
# 287 NP_055918.3 Already existis
# 288 NP_001365616.1 Already existis
# 289 NP_079094.1 Already existis
# 290 NP_000523.2 Already existis
# 291 NP_004757.1 Already existis
# 292 NP_000676.1 Already existis
# 293 NP_777367.1 Already existis
# 294 NP_001258767.1 Already existis
# 295 NP_001116224.1 Already existis
# 296 NP_004982.2 Already existis
# 297 NP_000331.1 Already existis
# 298 NP_078941.2 Already existis
# 299 NP_006209.2 Already existis
# 300 NP_852091.1 Already existis
# 301 NP_003097.1 Already existis
# 302 NP_064551.3 Already existis
# 303 NP_060114.2 Already existis
# 304 NP_003898.2 Already existis
# 305 NP_000451.1 Already existis
# 306 NP_004445.1 Already existis
# 307 NP_001613.2 Already existis
# 308 NP_003713.3 Already existis
# 309 NP_570850.2 Already existis
# 310 NP_060876.5 Already existis
# 311 NP_001369202.1 Already existis
# 312 NP_940967.1 Already existis
# 313 NP_002568.2 Already existis
# 314 NP_001120650.1 Already existis
# 315 NP_071325.2 Already existis
# 316 NP_000194.2 Already existis
# 317 NP_000133.1 Already existis
# 318 NP_036450.1 Already existis
# 319 NP_775931.3 Already existis
# 320 NP_005996.2 Already existis
# 321 NP_001365544.1 Already existis
# 322 NP_000311.2 Already existis
# 323 NP_079408.3 Already existis
# 324 NP_003915.2 Already existis
# 325 NP_001073945.1 Already existis
# 326 NP_000798.2 Already existis
# 327 NP_001366199.1 Already existis
# 328 NP_000223.1 Already existis
# 329 NP_001072992.1 Already existis
# 330 NP_005603.3 Already existis
# 331 NP_001544.1 Already existis
# 332 NP_000397.1 Already existis
# 333 NP_059122.2 Already existis
# 334 NP_055806.2 Already existis
# 335 NP_055023.2 Already existis
# 336 NP_004398.1 Already existis
# 337 NP_001501.2 Already existis
# 338 NP_001194.1 Already existis
# 339 NP_000935.1 Already existis
# 340 NP_001128618.1 Already existis
# 341 NP_003989.2 Already existis
# 342 NP_000195.3 Already existis
# 343 NP_000316.2 Already existis
# 344 NP_001308500.1 Already existis
# 345 NP_061169.2 Already existis
# 346 NP_005024.2 Already existis
# 347 NP_789794.1 Already existis
# 348 NP_001124170.1 Already existis
# 349 NP_001278232.1 Already existis
# 350 NP_001358525.1 Already existis
# 351 NP_003592.3 Already existis
# 352 NP_758454.1 Already existis
# 353 NP_612373.2 Already existis
# 354 NP_001336727.1 Already existis
# 355 NP_000815.1 Already existis
# 356 NP_001077088.2 Already existis
# 357 NP_004444.2 Already existis
# 358 NP_006736.1 Already existis
# 359 NP_005236.2 Already existis
# 360 NP_004468.1 Already existis
# 361 NP_004159.2 Already existis
# 362 NP_001003841.1 Already existis
# 363 NP_937983.2 Already existis
# 364 NP_004544.1 Already existis
# 365 NP_060225.4 Already existis
# 366 NP_001323.1 Already existis
# 367 NP_001360.1 Already existis
# 368 NP_009049.2 Already existis
# 369 NP_612357.4 Already existis
# 370 NP_006718.2 Already existis
# 371 NP_057264.4 Already existis
# 372 NP_002176.2 Already existis
# 373 NP_001007528.1 Already existis
# 374 NP_597677.2 Already existis
# 375 NP_001371661.1 Already existis
# 376 NP_001121143.1 Already existis
# 377 NP_066550.2 Already existis
# 378 NP_789776.1 Already existis
# 379 NP_001177716.1 Already existis
# 380 NP_002175.2 Already existis
# 381 NP_001098101.1 Already existis
# 382 NP_000073.1 Already existis
# 383 NP_000335.1 Already existis
# 384 NP_071415.1 Already existis
# 385 NP_005900.2 Already existis
# 386 NP_000512.2 Already existis
# 387 NP_000850.1 Already existis
# 388 NP_000037.2 Already existis
# 389 NP_002430.3 Already existis
# 390 NP_002388.2 Already existis
# 391 NP_005645.1 Already existis
# 392 NP_001139150.1 Already existis
# 393 NP_937793.1 Already existis
# 394 NP_000430.3 Already existis
# 395 NP_620128.1 Already existis
# 396 NP_000029.2 Already existis
# 397 NP_067627.3 Already existis
# 398 NP_000405.1 Already existis
# 399 NP_001173.2 Already existis
# 400 NP_001243474.1 Already existis
# 401 NP_001990.2 Already existis
# 402 NP_001017372.1 Already existis
# 403 NP_001244237.1 Already existis
# 404 NP_588613.3 Already existis
# 405 NP_003051.1 Already existis
# 406 NP_055238.1 Already existis
# 407 NP_078991.3 Already existis
# 408 NP_000349.1 Already existis
# 409 NP_057688.3 Already existis
# 410 NP_938023.1 Already existis
# 411 NP_005850.1 Already existis
# 412 NP_061751.1 Already existis
# 413 NP_995308.1 Already existis
# 414 NP_078853.2 Already existis
# 415 NP_000103.2 Already existis
# 416 NP_001275634.1 Already existis
# 417 NP_002600.1 Already existis
# 418 NP_057065.2 Already existis
# 419 NP_001534.1 Already existis
# 420 NP_000162.2 Already existis
# 421 NP_001358656.1 Already existis
# 422 NP_001121116.1 Already existis
# 423 NP_944494.1 Already existis
# 424 NP_004378.1 Already existis
# 425 NP_071900.2 Already existis
# 426 NP_057306.2 Already existis
# 427 NP_000834.2 Already existis
# 428 NP_001244222.1 Already existis
# 429 NP_003891.1 Already existis
# 430 NP_891555.2 Already existis
# 431 NP_001444.2 Already existis
# 432 NP_001060.1 Already existis
# 433 NP_821080.1 Already existis
# 434 NP_112210.1 Already existis
# 435 NP_003098.1 Already existis
# 436 NP_001071.1 Already existis
# 437 NP_000401.1 Already existis
# 438 NP_003533.1 Already existis
# 439 NP_003536.1 Already existis
# 440 NP_003486.1 Already existis
# 441 NP_068803.1 Already existis
# 442 NP_001311.3 Already existis
# 443 NP_751898.1 Already existis
# 444 NP_000425.1 Already existis
# 445 NP_000491.4 Already existis
# 446 NP_002115.2 Already existis
# 447 NP_542411.2 Already existis
# 448 NP_008910.2 Already existis
# 449 NP_006763.2 Already existis
# 450 NP_002215.2 Already existis
# 451 NP_115716.1 Already existis
# 452 NP_003313.3 Already existis
# 453 NP_443193.1 Already existis
# 454 NP_001345459.1 Already existis
# 455 NP_001012426.1 Already existis
# 456 NP_001371839.1 Already existis
# 457 NP_000313.2 Already existis
# 458 NP_000278.3 Already existis
# 459 NP_006236.1 Already existis
# 460 NP_689945.2 Already existis
# 461 NP_065796.2 Already existis
# 462 NP_001019801.3 Already existis
# 463 NP_000246.2 Already existis
# 464 NP_619639.3 Already existis
# 465 NP_001361665.1 Already existis
# 466 NP_001136272.1 Already existis
# 467 NP_062816.2 Already existis
# 468 NP_036566.1 Already existis
# 469 NP_004361.3 Already existis
# 470 NP_001116241.1 Already existis
# 471 NP_898871.1 Already existis
# 472 NP_006407.1 Already existis
# 473 NP_064716.2 Already existis
# 474 NP_067067.1 Already existis
# 475 NP_663304.1 Already existis
# 476 NP_065822.2 Already existis
# 477 NP_001186492.1 Already existis
# 478 NP_116119.2 Already existis
# 479 NP_055660.1 Already existis
# 480 NP_937882.2 Already existis
# 481 NP_000484.2 Already existis
# 482 NP_001365831.1 Already existis
# 483 NP_001035940.1 Already existis
# 484 NP_000156.1 Already existis
# 485 NP_006064.2 Already existis
# 486 NP_000417.3 Already existis
# 487 NP_000036.2 Already existis
# 488 NP_004821.2 Already existis
# 489 NP_006199.2 Already existis
# 490 NP_004091.3 Already existis
# 491 NP_001128303.1 Already existis
# 492 NP_055554.1 Already existis
# 493 NP_005661.1 Already existis
# 494 NP_001264993.1 Already existis
# 495 NP_004681.1 Already existis
# 496 NP_001361757.1 Already existis
# 497 NP_116250.3 Already existis
# 498 NP_001258791.1 Already existis
# 499 NP_000867.3 Already existis
# 500 NP_002784.1 Already existis
# 501 NP_064608.2 Already existis
# 502 NP_115791.3 Already existis
# 503 NP_001092.1 Already existis
# 504 NP_996994.1 Already existis
# 505 NP_000526.2 Already existis
# 506 NP_008839.2 Already existis
# 507 NP_006399.1 Already existis
# 508 NP_000465.1 Already existis
# 509 NP_001264044.1 Already existis
# 510 NP_001026880.2 Already existis
# 511 NP_002038.2 Already existis
# 512 NP_940820.1 Already existis
# 513 NP_005393.2 Already existis
# 514 NP_003709.3 Already existis
# 515 NP_000153.1 Already existis
# 516 NP_002532.2 Already existis
# 517 NP_000587.1 Already existis
# 518 NP_001076440.2 Already existis
# 519 NP_005219.2 Already existis
# 520 NP_000172.2 Already existis
# 521 NP_000039.2 Already existis
# 522 NP_694578.1 Already existis
# 523 NP_036611.2 Already existis
# 524 NP_002060.4 Already existis
# 525 NP_000713.2 Already existis
# 526 NP_000434.1 Already existis
# 527 NP_001311347.1 Already existis
# 528 NP_919436.1 Already existis
# 529 NP_000080.2 Already existis
# 530 NP_003910.1 Already existis
# 531 NP_055066.1 Already existis
# 532 NP_001664.3 Already existis
# 533 NP_001139187.1 Already existis
# 534 NP_057272.1 Already existis
# 535 NP_004435.3 Already existis
# 536 NP_005951.1 Already existis
# 537 NP_000432.1 Already existis
# 538 NP_000102.1 Already existis
# 539 NP_000099.2 Already existis
# 540 NP_001032209.1 Already existis
# 541 NP_001159817.1 Already existis
# 542 NP_000483.3 Already existis
# 543 NP_036413.1 Already existis
# 544 NP_056265.2 Already existis
# 545 NP_000874.2 Already existis
# 546 NP_001449.3 Already existis
# 547 NP_065683.2 Already existis
# 548 NP_004324.2 Already existis
# 549 NP_002760.1 Already existis
# 550 NP_000074.3 Already existis
# 551 NP_071890.2 Already existis
# 552 NP_004447.2 Already existis
# 553 NP_060854.2 Already existis
# 554 NP_000229.1 Already existis
# 555 NP_003031.3 Already existis
# 556 NP_005605.1 Already existis
# 557 NP_057287.2 Already existis
# 558 NP_733751.2 Already existis
# 559 NP_570629.2 Already existis
# 560 NP_005506.3 Already existis
# 561 NP_490647.1 Already existis
# 562 NP_001295022.1 Already existis
# 563 NP_000228.1 Already existis
# 564 NP_001684.2 Already existis
# 565 NP_005135.2 Already existis
# 566 NP_001381061.1 Already existis
# 567 NP_644807.1 Already existis
# 568 NP_001304707.1 Already existis
# 569 NP_006120.1 Already existis
# 570 NP_001121903.1 Already existis
# 571 NP_001076580.1 Already existis
# 572 NP_000628.2 Already existis
# 573 NP_001095871.1 Already existis
# 574 NP_075598.2 Already existis
# 575 NP_000028.3 Already existis
# 576 NP_001244109.1 Already existis
# 577 NP_060575.1 Already existis
# 578 NP_689632.2 Already existis
# 579 NP_002341.1 Already existis
# 580 NP_005363.1 Already existis
# 581 NP_060250.2 Already existis
# 582 NP_015628.2 Already existis
# 583 NP_061845.2 Already existis
# 584 NP_061971.3 Already existis
# 585 NP_714915.3 Already existis
# 586 NP_002559.2 Already existis
# 587 NP_848660.3 Already existis
# 588 NP_054831.2 Already existis
# 589 NP_006256.1 Already existis
# 590 NP_000118.2 Already existis
# 591 NP_003175.2 Already existis
# 592 NP_004510.1 Already existis
# 593 NP_036604.2 Already existis
# 594 NP_000488.3 Already existis
# 595 NP_000489.3 Already existis
# 596 NP_835466.2 Already existis
# 597 NP_958786.1 Already existis
# 598 NP_003792.1 Already existis
# 599 NP_036211.2 Already existis
# 600 NP_004251.4 Already existis
# 601 NP_003061.3 Already existis
# 602 NP_598004.1 Already existis
# 603 NP_000161.2 Already existis
# 604 NP_001362496.1 Already existis
# 605 NP_000068.1 Already existis
# 606 NP_478102.2 Already existis
# 607 NP_000450.3 Already existis
# 608 NP_001488.2 Already existis
# 609 NP_001161.1 Already existis
# 610 NP_000146.2 Already existis
# 611 NP_001136256.1 Already existis
# 612 NP_009057.1 Already existis
# 613 NP_003986.2 Already existis
# 614 NP_005467.1 Already existis
# 615 NP_036335.1 Already existis
# 616 NP_001353074.1 Already existis
# 617 NP_619636.2 Already existis
# 618 NP_060132.3 Already existis
# 619 NP_002063.2 Already existis
# 620 NP_112553.1 Already existis
# 621 NP_001003800.1 Already existis
# 622 NP_003828.2 Already existis
# 623 NP_000498.2 Already existis
# 624 NP_000255.2 Already existis
# 625 NP_004603.1 Already existis
# 626 NP_149078.1 Already existis
# 627 NP_000026.2 Already existis
# 628 NP_001365140.1 Already existis
# 629 NP_001850.1 Already existis
# 630 NP_937895.1 Already existis
# 631 NP_004950.2 Already existis
# 632 NP_001167618.1 Already existis
# 633 NP_001027392.1 Already existis
# 634 NP_001108225.1 Already existis
# 635 NP_004399.2 Already existis
# 636 NP_057119.3 Already existis
# 637 NP_001123910.1 Already existis
# 638 NP_000104.1 Already existis
# 639 NP_446464.1 Already existis
# 640 NP_067632.2 Already existis
# 641 NP_001070833.1 Already existis
# 642 NP_055861.3 Already existis
# 643 NP_000359.1 Already existis
# 644 NP_001364233.1 Already existis
# 645 NP_003163.1 Already existis
# 646 NP_620596.2 Already existis
# 647 NP_000084.3 Already existis
# 648 NP_065873.2 Already existis
# 649 NP_063945.2 Already existis
# 650 NP_060087.3 Already existis
# 651 NP_006403.2 Already existis
# 652 NP_015566.1 Already existis
# 653 NP_001170787.2 Already existis
# 654 NP_079033.4 Already existis
# 655 NP_001357029.1 Already existis
# 656 NP_001002295.1 Already existis
# 657 NP_001313271.1 Already existis
# 658 NP_001029027.1 Already existis
# 659 NP_055132.2 Already existis
# 660 NP_057712.2 Already existis
# 661 NP_068506.2 Already existis
# 662 NP_001167567.1 Already existis
# 663 NP_004512.1 Already existis
# 664 NP_066124.1 Already existis
# 665 NP_065574.4 Already existis
# 666 NP_060715.2 Already existis
# 667 NP_000390.2 Already existis
# 668 NP_000179.2 Already existis
# 669 NP_001076585.1 Already existis
# 670 NP_071407.4 Already existis
# 671 NP_002769.1 Already existis
# 672 NP_148982.1 Already existis
# 673 NP_665875.1 Already existis
# 674 NP_000420.1 Already existis
# 675 NP_149091.1 Already existis
# 676 NP_060021.1 Already existis
# 677 NP_001015880.1 Already existis
# 678 NP_000305.3 Already existis
# 679 NP_000034.1 Already existis
# 680 NP_000226.2 Already existis
# 681 NP_004514.2 Already existis
# 682 NP_006195.3 Already existis
# 683 NP_002851.2 Already existis
# 684 NP_056446.4 Already existis
# 685 NP_612422.2 Already existis
# 686 NP_000186.2 Already existis
# 687 NP_060764.3 Already existis
# 688 NP_068602.2 Already existis
# 689 NP_001182192.1 Already existis
# 690 NP_000093.1 Already existis
# 691 NP_001338098.1 Already existis
# 692 NP_005436.1 Already existis
# 693 NP_976313.1 Already existis
# 694 NP_862823.1 Already existis
# 695 NP_006784.1 Already existis
# 696 NP_000132.3 Already existis
# 697 NP_002766.1 Already existis
# 698 NP_001359052.1 Already existis
# 699 NP_000265.1 Already existis
# 700 NP_073713.2 Already existis
# 701 NP_000366.1 Already existis
# 702 NP_001362309.1 Already existis
# 703 NP_796374.2 Already existis
# 704 NP_004083.3 Already existis
# 705 NP_066288.2 Already existis
# 706 NP_665893.2 Already existis
# 707 NP_002448.5 Already existis
# 708 NP_000603.1 Already existis
# 709 NP_000198.1 Already existis
# 710 NP_000351.2 Already existis
# 711 NP_000209.2 Already existis
# 712 NP_000534.3 Already existis
# 713 NP_653267.2 Already existis
# 714 NP_000382.3 Already existis
# 715 NP_036382.2 Already existis
# 716 NP_001137533.1 Already existis
# 717 NP_078790.2 Already existis
# 718 NP_000516.3 Already existis
# 719 NP_000343.2 Already existis
# 720 NP_001106212.1 Already existis
# 721 NP_004202.4 Already existis
# 722 NP_073562.1 Already existis
# 723 NP_113606.2 Already existis
# 724 NP_001355823.1 Already existis
# 725 NP_077744.4 Already existis
# 726 NP_000439.2 Already existis
# 727 NP_000527.2 Already existis
# 728 NP_068745.2 Already existis
# 729 NP_001363500.1 Already existis
# 730 NP_002795.2 Already existis
# 731 NP_005046.2 Already existis
# 732 NP_000053.2 Already existis
# 733 NP_945185.1 Already existis
# 734 NP_001034485.1 Already existis
# 735 NP_004174.1 Already existis
# 736 NP_036332.2 Already existis
# 737 NP_938148.1 Already existis
# 738 NP_000923.1 Already existis
# 739 NP_201567.1 Already existis
# 740 NP_653186.2 Already existis
# 741 NP_001092141.1 Already existis
# 742 NP_005600.1 Already existis
# 743 NP_001357188.2 Already existis
# 744 NP_058634.4 Already existis
# 745 NP_006833.2 Already existis
# 746 NP_060496.2 Already existis
# 747 NP_078925.3 Already existis
# 748 NP_009034.2 Already existis
# 749 NP_002326.2 Already existis
# 750 NP_001867.2 Already existis
# 751 NP_002171.2 Already existis
# 752 NP_001351.2 Already existis
# 753 NP_006176.2 Already existis
# 754 NP_057941.1 Already existis
# 755 NP_001245321.1 Already existis
# 756 NP_001273506.1 Already existis
# 757 NP_000251.3 Already existis
# 758 NP_076984.2 Already existis
# 759 NP_001092286.2 Already existis
# 760 NP_003788.2 Already existis
# 761 NP_036325.2 Already existis
# 762 NP_001805.4 Already existis
# 763 NP_000363.1 Already existis
# 764 NP_004612.2 Already existis
# 765 NP_001123617.1 Already existis
# 766 NP_001368.2 Already existis
# 767 NP_000820.4 Already existis
# 768 NP_000010.1 Already existis
# 769 NP_000042.3 Already existis
# 770 NP_079016.2 Already existis
# 771 NP_002993.1 Already existis
# 772 NP_000308.1 Already existis
# 773 NP_000030.1 Already existis
# 774 NP_001549.2 Already existis
# 775 NP_001184033.1 Already existis
# 776 NP_000181.2 Already existis
# 777 NP_001373.2 Already existis
# 778 NP_005179.2 Already existis
# 779 NP_001265360.1 Already existis
# 780 NP_079045.1 Already existis
# 781 NP_689926.1 Already existis
# 782 NP_001128265.1 Already existis
# 783 NP_722450.1 Already existis
# 784 NP_068813.1 Already existis
# 785 NP_055199.1 Already existis
# 786 NP_000710.5 Already existis
# 787 NP_003315.2 Already existis
# 788 NP_001265238.2 Already existis
# 789 NP_000208.2 Already existis
# 790 NP_000543.3 Already existis
# 791 NP_055046.1 Already existis
# 792 NP_001264.2 Already existis
# 793 NP_002327.2 Already existis
# 794 NP_000825.2 Already existis
# 795 NP_079130.2 Already existis
# 796 NP_064693.2 Already existis
# 797 NP_008871.3 Already existis
# 798 NP_004976.2 Already existis
# 799 NP_036192.2 Already existis
# 800 NP_001005242.2 Already existis
# 801 NP_001166935.1 Already existis
# 802 NP_000367.1 Already existis
# 803 NP_001835.3 Already existis
# 804 NP_001650.1 Already existis
# 805 NP_005421.1 Already existis
# 806 NP_003473.3 Already existis
# 807 NP_066382.1 Already existis
# 808 NP_006000.2 Already existis
# 809 NP_000477.1 Already existis
# 810 NP_001306928.1 Already existis
# 811 NP_001317189.1 Already existis
# 812 NP_000011.2 Already existis
# 813 NP_000415.2 Already existis
# 814 NP_006112.3 Already existis
# 815 NP_056480.1 Already existis
# 816 NP_065434.1 Already existis
# 817 NP_005328.2 Already existis
# 818 NP_001020.2 Already existis
# 819 NP_005410.1 Already existis
# 820 NP_001677.2 Already existis
# 821 NP_000776.1 Already existis
# 822 NP_776173.3 Already existis
# 823 NP_055069.1 Already existis
# 824 NP_037386.1 Already existis
# 825 NP_631875.1 Already existis
# 826 NP_005630.1 Already existis
# 827 NP_079390.3 Already existis
# 828 NP_000890.1 Already existis
# 829 NP_758440.1 Already existis
# 830 NP_001353450.1 Already existis
# 831 NP_077288.2 Already existis
# 832 NP_000268.1 Already existis
# 833 NP_056090.1 Already existis
# 834 NP_060552.4 Already existis
# 835 NP_569733.2 Already existis
# 836 NP_067638.3 Already existis
# 837 NP_733765.1 Already existis
# 838 NP_005466.1 Already existis
# 839 NP_003659.2 Already existis
# 840 NP_001375232.1 Already existis
# 841 NP_058132.2 Already existis
# 842 NP_852259.1 Already existis
# 843 NP_000536.6 Already existis
# 844 NP_115979.3 Already existis
# 845 NP_001340274.1 Already existis
# 846 NP_006222.2 Already existis
# 847 NP_068773.2 Already existis
# 848 NP_003995.2 Already existis
# 849 NP_001103689.1 Already existis
# 850 NP_002001.1 Already existis
# 851 NP_000222.2 Already existis
# 852 NP_055178.3 Already existis
# 853 NP_000050.3 Already existis
# 854 NP_037470.1 Already existis
# 855 NP_003841.1 Already existis
# 856 NP_000312.2 Already existis
# 857 NP_001155970.1 Already existis
# 858 NP_002258.2 Already existis
# 859 NP_000044.2 Already existis
# 860 NP_005699.1 Already existis
# 861 NP_000273.2 Already existis
# 862 NP_443099.1 Already existis
# 863 NP_001836.3 Already existis
# 864 NP_001837.2 Already existis
# 865 NP_001229811.1 Already existis
# 866 NP_056020.2 Already existis
# 867 NP_000495.1 Already existis
# 868 NP_009123.1 Already existis
# 869 NP_001164100.1 Already existis
# 870 NP_003973.3 Already existis
# 871 NP_001341569.1 Already existis
# 872 NP_000248.2 Already existis
# 873 NP_001341697.1 Already existis
# 874 NP_000350.1 Already existis
# 875 NP_005240.3 Already existis
# 876 NP_004077.1 Already existis
# 877 NP_001025226.1 Already existis
# 878 NP_619579.1 Already existis
# 879 NP_060387.2 Already existis
# 880 NP_055487.2 Already existis
# 881 NP_001073136.1 Already existis
# 882 NP_001359005.1 Already existis
# 883 NP_008870.2 Already existis
# 884 NP_079160.1 Already existis
# 885 NP_056999.2 Already existis
# 886 NP_000152.1 Already existis
# 887 NP_001072988.1 Already existis
# 888 NP_065861.3 Already existis
# 889 NP_001342365.1 Already existis
# 890 NP_065857.1 Already existis
# 891 NP_689656.2 Already existis
# 892 NP_001123476.1 Already existis
# 893 NP_000012.1 Already existis
# 894 NP_878314.1 Already existis
# 895 NP_005041.1 Already existis
# 896 NP_006423.1 Already existis
# 897 NP_001096034.1 Already existis
# 898 NP_000360.2 Already existis
# 899 NP_000144.2 Already existis
# 900 NP_060888.2 Already existis
# 901 NP_002793.2 Already existis
# 902 NP_008819.1 Already existis
# 903 NP_006320.2 Already existis
# 904 NP_004230.2 Already existis
# 905 NP_057501.2 Already existis
# 906 NP_003394.1 Already existis
# 907 NP_004175.2 Already existis
# 908 NP_001367.2 Already existis
# 909 NP_056471.1 Already existis
# 910 NP_071934.3 Already existis
# 911 NP_000805.1 Already existis
# 912 NP_000801.1 Already existis
# 913 NP_000266.2 Already existis
# 914 NP_001027.3 Already existis
# 915 NP_001352017.1 Already existis
# 916 NP_002216.3 Already existis
# 917 NP_061947.1 Already existis
# 918 NP_000061.1 Already existis
# 919 NP_612486.2 Already existis
# 920 NP_116281.2 Already existis
# 921 NP_079413.3 Already existis
# 922 NP_001350640.1 Already existis
# 923 NP_995322.1 Already existis
# 924 NP_000329.2 Already existis
# 925 NP_001020419.1 Already existis
# 926 NP_000129.3 Already existis
# 927 NP_000094.2 Already existis
# 928 NP_861454.2 Already existis
# 929 NP_057278.2 Already existis
# 930 NP_899058.1 Already existis
# 931 NP_073752.6 Already existis
# 932 NP_996920.1 Already existis
# 933 NP_003879.2 Already existis
# 934 NP_001094832.1 Already existis
# 935 NP_002746.1 Already existis
# 936 NP_005576.3 Already existis
# 937 NP_001354734.1 Already existis
# 938 NP_079093.2 Already existis
# 939 NP_055064.1 Already existis
# 940 NP_000511.2 Already existis
# 941 NP_149017.2 Already existis
# 942 NP_005468.1 Already existis
# 943 NP_003603.1 Already existis
# 944 NP_006706.2 Already existis
# 945 NP_116197.4 Already existis
# 946 NP_000128.1 Already existis
# 947 NP_078856.4 Already existis
# 948 NP_001012.1 Already existis
# 949 NP_000317.1 Already existis
# 950 NP_002684.1 Already existis
# 951 NP_001262.3 Already existis
# 952 NP_001365718.1 Already existis
# 953 NP_000508.1 Already existis
# 954 NP_000549.1 Already existis
# 955 NP_001278.1 Already existis
# 956 NP_057195.2 Already existis
# 957 NP_002519.2 Already existis
# 958 NP_000539.2 Already existis
# 959 NP_001009944.3 Already existis
# 960 NP_001080.2 Already existis
# 961 NP_001685.1 Already existis
# 962 NP_004371.2 Already existis
# 963 NP_061982.3 Already existis
# 964 NP_000294.1 Already existis
# 965 NP_001127879.1 Already existis
# 966 NP_001295071.1 Already existis
# 967 NP_001162.5 Already existis
# 968 NP_003352.2 Already existis
# 969 NP_060206.2 Already existis
# 970 NP_000327.2 Already existis
# 971 NP_705831.1 Already existis
# 972 NP_078951.2 Already existis
# 973 NP_004311.1 Already existis
# 974 NP_057235.2 Already existis
# 975 NP_115564.2 Already existis
# 976 NP_004951.1 Already existis
# 977 NP_001098717.1 Already existis
# 978 NP_891552.1 Already existis
# 979 NP_001357395.1 Already existis
# 980 NP_005844.4 Already existis
# 981 NP_004521.1 Already existis
# 982 NP_066268.1 Already existis
# 983 NP_001119580.2 Already existis
# 984 NP_588609.1 Already existis
# 985 NP_001288.3 Already existis
# 986 NP_057368.3 Already existis
# 987 NP_001788.2 Already existis
# 988 NP_004605.4 Already existis
# 989 NP_003896.1 Already existis
# 990 NP_003780.1 Already existis
# 991 NP_001361604.1 Already existis
# 992 NP_004585.1 Already existis
# 993 NP_000220.1 Already existis
# 994 NP_004351.1 Already existis
# 995 NP_001596.2 Already existis
# 996 NP_008816.3 Already existis
# 997 NP_077282.3 Already existis
# 998 NP_001070886.1 Already existis
# 999 NP_005539.1 Already existis
# 1000 NP_955387.1 Already existis
# 1001 NP_057457.1 Already existis
# 1002 NP_005351.2 Already existis
# 1003 NP_004474.2 Already existis
# 1004 NP_071324.1 Already existis
# 1005 NP_003782.1 Already existis
# 1006 NP_001442.2 Already existis
# 1007 NP_079011.3 Already existis
# 1008 NP_000503.1 Already existis
# 1009 NP_001230208.1 Already existis
# 1010 NP_037407.4 Already existis
# 1011 NP_003110.1 Already existis
# 1012 NP_000126.2 Already existis
# 1013 NP_006077.2 Already existis
# 1014 NP_056536.2 Already existis
# 1015 NP_057616.2 Already existis
# 1016 NP_006436.3 Already existis
# 1017 NP_002936.1 Already existis
# 1018 NP_000421.1 Already existis
# 1019 NP_000040.1 Already existis
# 1020 NP_659505.1 Already existis
# 1021 NP_004928.2 Already existis
# 1022 NP_000071.1 Already existis
# 1023 NP_000164.5 Already existis
# 1024 NP_055151.3 Already existis
# 1025 NP_001308004.1 Already existis
# 1026 NP_000009.1 Already existis
# 1027 NP_000537.3 Already existis
# 1028 NP_001005273.1 Already existis
# 1029 NP_000171.1 Already existis
# 1030 NP_079375.3 Already existis
# 1031 NP_000295.1 Already existis
# 1032 NP_057323.3 Already existis
# 1033 NP_000373.1 Already existis
# 1034 NP_659731.1 Already existis
# 1035 NP_001035957.1 Already existis
# 1036 NP_644814.1 Already existis
# 1037 NP_001333683.1 Already existis
# 1038 NP_000449.1 Already existis
# 1039 NP_006151.3 Already existis
# 1040 NP_000412.4 Already existis
# 1041 NP_644805.1 Already existis
# 1042 NP_001123493.1 Already existis
# 1043 NP_000254.2 Already existis
# 1044 NP_079509.5 Already existis
# 1045 NP_003623.1 Already existis
# 1046 NP_115763.2 Already existis
# 1047 NP_000142.2 Already existis
# 1048 NP_009225.1 Already existis
# 1049 NP_000333.1 Already existis
# 1050 NP_002078.1 Already existis
# 1051 NP_000410.2 Already existis
# 1052 NP_004238.3 Already existis
# 1053 NP_998772.1 Already existis
# 1054 NP_002046.1 Already existis
# 1055 NP_056258.1 Already existis
# 1056 NP_001247.3 Already existis
# 1057 NP_000203.2 Already existis
# 1058 NP_005211.1 Already existis
# 1059 NP_002195.1 Already existis
# 1060 NP_000014.1 Already existis
# 1061 NP_000079.2 Already existis
# 1062 NP_004366.1 Already existis
# 1063 NP_008855.1 Already existis
# 1064 NP_004850.1 Already existis
# 1065 NP_001308049.1 Already existis
# 1066 NP_005112.2 Already existis
# 1067 NP_002392.2 Already existis
# 1068 NP_000325.4 Already existis
# 1069 NP_002725.1 Already existis
# 1070 NP_000337.1 Already existis
# 1071 NP_694941.2 Already existis
# 1072 NP_077728.3 Already existis
# 1073 NP_001119593.1 Already existis
# 1074 NP_000204.3 Already existis
# 1075 NP_005315.1 Already existis
# 1076 NP_001182356.1 Already existis
# 1077 NP_775899.3 Already existis
# 1078 NP_000143.2 Already existis
# 1079 NP_000190.1 Already existis
# 1080 NP_001243000.2 Already existis
# 1081 NP_002513.2 Already existis
# 1082 NP_001079990.1 Already existis
# 1083 NP_001605.1 Already existis
# 1084 NP_056110.2 Already existis
# 1085 NP_036439.2 Already existis
# 1086 NP_001365112.1 Already existis
# 1087 NP_892023.1 Already existis
# 1088 NP_006787.2 Already existis
# 1089 NP_000262.2 Already existis
# 1090 NP_817123.1 Already existis
# 1091 NP_000362.1 Already existis
# 1092 NP_060725.1 Already existis
# 1093 NP_056374.2 Already existis
# 1094 NP_001371403.1 Already existis
# 1095 NP_005892.1 Already existis
# 1096 NP_001073936.1 Already existis
# 1097 NP_005206.2 Already existis
# 1098 NP_001077431.1 Already existis
# 1099 NP_000131.2 Already existis
# 1100 NP_038463.2 Already existis
# 1101 NP_001185.3 Already existis
# 1102 NP_005026.3 Already existis
# 1103 NP_001963.1 Already existis
# 1104 NP_004359.1 Already existis
# 1105 NP_000446.1 Already existis
# 1106 NP_000147.1 Already existis
# 1107 NP_005874.1 Already existis
# 1108 NP_000470.3 Already existis
# 1109 NP_001137458.1 Already existis
# 1110 NP_002058.2 Already existis
# 1111 NP_001138637.1 Already existis
# 1112 NP_057347.2 Already existis
# 1113 NP_149053.1 Already existis
# 1114 NP_056982.1 Already existis
# 1115 NP_631898.3 Already existis
# 1116 NP_006078.2 Already existis
# 1117 NP_001159586.1 Already existis
# 1118 NP_001164626.1 Already existis
# 1119 NP_008880.2 Already existis
# 1120 NP_078966.2 Already existis
# 1121 NP_003322.3 Already existis
# 1122 NP_987096.1 Already existis
# 1123 NP_003063.2 Already existis
# 1124 NP_000518.1 Already existis
# 1125 NP_001602.1 Already existis
# 1126 NP_004308.2 Already existis
# 1127 NP_006388.2 Already existis
# 1128 NP_055790.1 Already existis
# 1129 NP_001366.1 Already existis
# 1130 NP_000150.1 Already existis
# 1131 NP_004452.1 Already existis
# 1132 NP_001352831.1 Already existis
# 1133 NP_001120694.1 Already existis
# 1134 NP_055736.2 Already existis
# 1135 NP_612510.1 Already existis
# 1136 NP_000426.2 Already existis
# 1137 NP_116009.2 Already existis
# 1138 NP_000206.2 Already existis
# 1139 NP_005526.1 Already existis
# 1140 NP_001380433.1 Already existis
# 1141 NP_005018.2 Already existis
# 1142 NP_000086.2 Already existis
# 1143 NP_067090.1 Already existis
# 1144 NP_055085.1 Already existis
# 1145 NP_004355.2 Already existis
# 1146 NP_000166.2 Already existis
# 1147 NP_116024.1 Already existis
# 1148 NP_055542.1 Already existis
# 1149 NP_004637.1 Already existis
# 1150 NP_001077430.1 Already existis
# 1151 NP_066925.1 Already existis
# 1152 NP_000531.2 Already existis
# 1153 NP_004915.2 Already existis
# 1154 NP_000651.3 Already existis
# 1155 NP_000700.1 Already existis
# 1156 NP_001013.1 Already existis
# 1157 NP_689509.1 Already existis
# 1158 NP_597701.1 Already existis
# 1159 NP_001373227.1 Already existis
# 1160 NP_055112.2 Already existis
# 1161 NP_061981.2 Already existis
# 1162 NP_000032.1 Already existis
# 1163 NP_001369351.1 Already existis
# 1164 NP_000391.1 Already existis
# 1165 NP_005175.2 Already existis
# 1166 NP_077277.1 Already existis
# 1167 NP_000225.1 Already existis
# 1168 NP_000827.2 Already existis
# 1169 NP_003651.1 Already existis
# 1170 NP_060106.2 Already existis
# 1171 NP_004908.4 Already existis
# 1172 NP_001976.1 Already existis
# 1173 NP_002730.1 Already existis
# 1174 NP_056444.3 Already existis
# 1175 NP_077274.3 Already existis
# 1176 NP_003274.3 Already existis
# 1177 NP_000354.4 Already existis
# 1178 NP_808227.1 Already existis
# 1179 NP_212134.3 Already existis
# 1180 NP_000481.2 Already existis
# 1181 NP_001167560.1 Already existis
# 1182 NP_001373322.1 Already existis
# 1183 NP_061968.1 Already existis
# 1184 NP_001191.1 Already existis
# 1185 NP_570824.1 Already existis
# 1186 NP_000205.1 Already existis
# 1187 NP_057184.1 Already existis
# 1188 NP_056400.3 Already existis
# 1189 NP_060944.3 Already existis
# 1190 NP_056153.2 Already existis
# 1191 NP_008823.1 Already existis
# 1192 NP_000548.2 Already existis
# 1193 NP_110517.2 Already existis
# 1194 NP_005452.2 Already existis
# 1195 NP_787110.2 Already existis
# 1196 NP_000013.2 Already existis
# 1197 NP_000299.3 Already existis
# 1198 NP_110404.1 Already existis
# 1199 NP_004966.1 Already existis
# 1200 NP_001269460.1 Already existis
# 1201 NP_000773.2 Already existis
# 1202 NP_001710.1 Already existis
# 1203 NP_002582.3 Already existis
# 1204 NP_000507.1 Already existis
# 1205 NP_110400.1 Already existis
# 1206 NP_742105.1 Already existis
# 1207 NP_001949.1 Already existis
# 1208 NP_001269938.1 Already existis
# 1209 NP_079495.1 Already existis
# 1210 NP_000475.1 Already existis
# 1211 NP_001340623.1 Already existis
# 1212 NP_000445.1 Already existis
# 1213 NP_060083.1 Already existis
# 1214 NP_001745.2 Already existis
# 1215 NP_001339443.1 Already existis
# 1216 NP_001334650.1 Already existis
# 1217 NP_001243246.1 Already existis
# 1218 NP_543136.1 Already existis
# 1219 NP_000374.1 Already existis
# 1220 NP_004919.1 Already existis
# 1221 NP_659428.2 Already existis
# 1222 NP_000202.3 Already existis
# 1223 NP_001103.1 Already existis
# 1224 NP_001839.2 Already existis
# 1225 NP_001840.3 Already existis
# 1226 NP_002331.3 Already existis
# 1227 NP_001269154.1 Already existis
# 1228 NP_061816.1 Already existis
# 1229 NP_005975.1 Already existis
# 1230 NP_000398.1 Already existis
# 1231 NP_690870.3 Already existis
# 1232 NP_477352.3 Already existis
# 1233 NP_006758.2 Already existis
# 1234 NP_998885.1 Already existis
# 1235 NP_056145.5 Already existis
# 1236 NP_057411.1 Already existis
# 1237 NP_004067.1 Already existis
# 1238 NP_000487.1 Already existis
# 1239 NP_001118.3 Already existis
# 1240 NP_000259.1 Already existis
# 1241 NP_001290185.1 Already existis
# 1242 NP_000334.1 Already existis
# 1243 NP_000353.1 Already existis
# 1244 NP_002464.1 Already existis
# 1245 NP_006069.1 Already existis
# 1246 NP_008872.1 Already existis
# 1247 NP_003551.2 Already existis
# 1248 NP_066919.2 Already existis
# 1249 NP_000017.1 Already existis
# 1250 NP_001420.2 Already existis
# 1251 NP_001089.1 Already existis
# 1252 NP_060476.2 Already existis
# 1253 NP_055981.1 Already existis
# 1254 NP_005129.2 Already existis
# 1255 NP_001944.1 Already existis
# 1256 NP_000478.3 Already existis
# 1257 NP_000442.1 Already existis
# 1258 NP_000038.2 Already existis
# 1259 NP_000207.2 Already existis
# 1260 NP_000264.2 Already existis
# 1261 NP_005324.3 Already existis
# 1262 NP_001133.1 Already existis
# 1263 NP_057646.1 Already existis
# 1264 NP_619542.1 Already existis
# 1265 NP_002054.1 Already existis
# 1266 NP_002632.1 Already existis
# 1267 NP_001278796.1 Already existis
# 1268 NP_001310218.1 Already existis
# 1269 NP_000321.1 Already existis
# 1270 NP_000275.1 Already existis
# 1271 NP_004577.1 Already existis
# 1272 NP_055147.1 Already existis
# 1273 NP_000435.3 Already existis
# 1274 NP_005382.1 Already existis
# 1275 NP_620689.1 Already existis
# 1276 NP_000388.2 Already existis
# 1277 NP_001030025.1 Already existis
# 1278 NP_000522.3 Already existis
# 1279 NP_001347.3 Already existis
# 1280 NP_001354650.1 Already existis
# 1281 NP_000257.1 Already existis
# 1282 NP_008846.2 Already existis
# 1283 NP_005626.1 Already existis
# 1284 NP_006570.1 Already existis
# 1285 NP_000368.1 Already existis
# 1286 NP_002040.1 Already existis
# 1287 NP_005651.1 Already existis
# 1288 NP_006512.2 Already existis
# 1289 NP_001025067.1 Already existis
# 1290 NP_054728.2 Already existis
# 1291 NP_005439.2 Already existis
# 1292 NP_004178.2 Already existis
# 1293 NP_001104595.1 Already existis
# 1294 NP_006297.2 Already existis
# 1295 NP_065973.2 Already existis
# 1296 NP_004454.2 Already existis
# 1297 NP_000023.2 Already existis
# 1298 NP_001340850.1 Already existis
# 1299 NP_061154.1 Already existis
# 1300 NP_000035.2 Already existis
# 1301 NP_004420.1 Already existis
# 1302 NP_001390.1 Already existis
# 1303 NP_851820.1 Already existis
# 1304 NP_000157.1 Already existis
# 1305 NP_004597.3 Already existis
# 1306 NP_060956.1 Already existis
# 1307 NP_006508.2 Already existis
# 1308 NP_000480.3 Already existis
# 1309 NP_000043.4 Already existis
# 1310 NP_000282.1 Already existis
# 1311 NP_694984.5 Already existis
# 1312 NP_001171809.1 Already existis
# 1313 NP_000052.1 Already existis
# 1314 NP_000160.1 Already existis
# 1315 NP_000524.3 Already existis
# 1316 NP_203699.1 Already existis
# 1317 NP_001182482.1 Already existis
# 1318 NP_001093392.1 Already existis
# 1319 NP_065922.3 Already existis
# 1320 NP_005023.2 Already existis
# 1321 NP_653259.3 Already existis
# 1322 NP_001143.2 Already existis
# 1323 NP_003327.2 Already existis
# 1324 NP_078804.2 Already existis
# 1325 NP_002285.1 Already existis
# 1326 NP_001011551.1 Already existis
# 1327 NP_015564.5 Already existis
# 1328 NP_002342.1 Already existis
# 1329 NP_000267.2 Already existis
# 1330 NP_001412.1 Already existis
# 1331 NP_919253.1 Already existis
# 1332 NP_114113.1 Already existis
# 1333 NP_001015877.1 Already existis
# 1334 NP_000185.1 Already existis
# 1335 NP_001153171.1 Already existis
# 1336 NP_000065.1 Already existis
# 1337 NP_000124.1 Already existis
# 1338 NP_115928.1 Already existis
# 1339 NP_000193.1 Already existis
# 1340 NP_000243.1 Already existis
# 1341 NP_000799.1 Already existis
# 1342 NP_005620.1 Already existis
# 1343 NP_000024.2 Already existis
# 1344 NP_001265045.1 Already existis
# 1345 NP_000045.1 Already existis
# 1346 NP_001104262.1 Already existis
# 1347 NP_001104026.1 Already existis
# 1348 NP_000107.1 Already existis
# 1349 NP_001346945.1 Already existis
# 1350 NP_001354.1 Already existis
# 1351 NP_000123.1 Already existis
# 1352 NP_940978.2 Already existis
# 1353 NP_114127.3 Already existis
# 1354 NP_113663.2 Already existis
# 1355 NP_073624.2 Already existis
# 1356 NP_031401.1 Already existis
# 1357 NP_000293.2 Already existis
# 1358 NP_056193.2 Already existis
# 1359 NP_009203.2 Already existis
# 1360 NP_004422.2 Already existis
# 1361 NP_071372.1 Already existis
# 1362 NP_997304.3 Already existis
# 1363 NP_055862.1 Already existis
# 1364 NP_115785.1 Already existis
# 1365 NP_005520.4 Already existis
# 1366 NP_001009999.1 Already existis
# 1367 NP_001008217.1 Already existis
# 1368 NP_056442.2 Already existis
# 1369 NP_001358857.1 Already existis
# 1370 NP_003671.1 Already existis
# 1371 NP_071440.1 Already existis
# 1372 NP_001380991.1 Already existis
# 1373 NP_004691.2 Already existis
# 1374 NP_071751.3 Already existis
# 1375 NP_006270.1 Already existis
# 1376 NP_065098.1 Already existis
# 1377 NP_056321.2 Already existis
# 1378 NP_036318.1 Already existis
# 1379 NP_001128145.1 Already existis
# 1380 NP_002294.2 Already existis
# 1381 NP_057062.1 Already existis
# 1382 NP_000101.2 Already existis
# 1383 NP_000633.2 Already existis
# 1384 NP_003663.2 Already existis
# 1385 NP_006487.1 Already existis
# 1386 NP_001355738.1 Already existis
# 1387 NP_002223.3 Already existis
# 1388 NP_001365898.1 Already existis
# 1389 NP_001240781.1 Already existis
# 1390 NP_002515.1 Already existis
# 1391 NP_056651.1 Already existis
# 1392 NP_998818.1 Already existis
# 1393 NP_001020774.1 Already existis
# 1394 NP_002240.3 Already existis
# 1395 NP_006547.1 Already existis
# 1396 NP_079483.3 Already existis
# 1397 NP_060959.2 Already existis
# 1398 NP_060586.2 Already existis
# 1399 NP_003117.2 Already existis
# 1400 NP_002232.2 Already existis
# 1401 NP_001222.3 Already existis
# 1402 NP_004362.2 Already existis
# 1403 NP_006173.2 Already existis
# 1404 NP_002576.1 Already existis
# 1405 NP_008927.1 Already existis
# 1406 NP_000121.2 Already existis
# 1407 NP_001002294.1 Already existis
# 1408 NP_066956.1 Already existis
# 1409 NP_940905.2 Already existis
# 1410 NP_002104.2 Already existis
# 1411 NP_060606.3 Already existis
# 1412 NP_002829.3 Already existis
# 1413 NP_001239031.1 Already existis
# 1414 NP_796376.2 Already existis
# 1415 NP_000528.1 Already existis
# 1416 NP_001006659.1 Already existis
# 1417 NP_758861.1 Already existis
# 1418 NP_060530.3 Already existis
# 1419 NP_001366332.1 Already existis
# 1420 NP_064632.2 Already existis
# 1421 NP_073623.1 Already existis
# 1422 NP_000072.2 Already existis
# 1423 NP_665860.2 Already existis
# 1424 NP_991331.1 Already existis
# 1425 NP_001193673.1 Already existis
# 1426 NP_001289981.1 Already existis
# 1427 NP_001034451.1 Already existis
# 1428 NP_065830.2 Already existis
# 1429 NP_002372.1 Already existis
# 1430 NP_060733.4 Already existis
# 1431 NP_000173.2 Already existis
# 1432 NP_919224.1 Already existis
# 1433 NP_066918.2 Already existis
# 1434 NP_002428.1 Already existis
# 1435 NP_001029288.1 Already existis
# 1436 NP_056477.1 Already existis
# 1437 NP_002700.1 Already existis
# 1438 NP_001025054.1 Already existis
# 1439 NP_004295.2 Already existis
# 1440 NP_071881.1 Already existis
# 1441 NP_071882.1 Already existis
# 1442 NP_573566.2 Already existis
# 1443 NP_001165084.1 Already existis
# 1444 NP_001177203.1 Already existis
# 1445 NP_001034842.2 Already existis
# 1446 NP_060532.2 Already existis
# 1447 NP_001231639.1 Already existis
# 1448 NP_001683.2 Already existis
# 1449 NP_003115.1 Already existis
# 1450 NP_001365383.1 Already existis
# 1451 NP_001274420.1 Already existis
# 1452 NP_006293.2 Already existis
# 1453 NP_001129121.1 Already existis
# 1454 NP_653164.2 Already existis
# 1455 NP_054733.2 Already existis
# 1456 NP_068587.1 Already existis
# 1457 NP_006334.2 Already existis
# 1458 NP_003457.1 Already existis
# 1459 NP_001361282.1 Already existis
# 1460 NP_000113.1 Already existis
# 1461 NP_055610.1 Already existis
# 1462 NP_001157980.2 Already existis
# 1463 NP_689735.1 Already existis
# 1464 NP_000879.2 Already existis
# ...
# 1691 NP_000058.1 Already existis
# 1692 NP_002476.2 Already existis
# 1693 NP_057107.4 Already existis
# 1694 NP_001139332.1 Already existis
# 1695 NP_001153844.1 Already existis
# 1696 NP_036286.2 Already existis
# 1697 NP_510965.1 Already existis
# 1698 NP_001350047.1 Already existis
# 1699 NP_570901.3 Already existis
# 1700 NP_003374.3 Already existis
# 1701 NP_004963.1 Already existis
# 1702 NP_065880.2 Already existis
# 1703 NP_000541.1 Already existis
# 1704 NP_001177666.1 Already existis
# 1705 NP_001366010.1 Already existis
# 1706 NP_057609.2 Already existis
# 1707 NP_001152.1 Already existis
# 1708 NP_036276.1 Already existis
# 1709 NP_005857.1 Already existis
# 1710 NP_004620.1 Already existis
# 1711 NP_116023.2 Already existis
# 1712 NP_003280.2 Already existis
# 1713 NP_057126.2 Already existis
# 1714 NP_008845.2 Already existis
# 1715 NP_150648.2 Already existis
# 1716 NP_001689.1 Already existis
# 1717 NP_004551.2 Already existis
# 1718 NP_006406.1 Already existis
# 1719 NP_000127.2 Already existis
# 1720 NP_000188.1 Already existis
# 1721 NP_061819.2 Already existis
# 1722 NP_005449.5 Already existis
# 1723 NP_775822.3 Already existis
# 1724 NP_061924.1 Already existis
# 1725 NP_005493.2 Already existis
# 1726 NP_067047.4 Already existis
# 1727 NP_005583.1 Already existis
# 1728 NP_116277.2 Already existis
# 1729 NP_036342.2 Already existis
# 1730 NP_775960.4 Already existis
# 1731 NP_003156.1 Already existis
# 1732 NP_003854.1 Already existis
# 1733 NP_005085.2 Already existis
# 1734 NP_003002.2 Already existis
# 1735 NP_055723.1 Already existis
# 1736 NP_005148.2 Already existis
# 1737 NP_115925.2 Already existis
# 1738 NP_055509.2 Already existis
# 1739 NP_835258.1 Already existis
# 1740 NP_006079.1 Already existis
# 1741 NP_055970.1 Already existis
# 1742 NP_001008213.1 Already existis
# 1743 NP_057288.1 Already existis
# 1744 NP_000115.1 Already existis
# 1745 NP_001371069.1 Already existis
# 1746 NP_660161.1 Already existis
# 1747 NP_001073918.2 Already existis
# 1748 NP_001345192.1 Already existis
# 1749 NP_060814.4 Already existis
# 1750 NP_004264.2 Already existis
# 1751 NP_001354463.1 Already existis
# 1752 NP_036462.2 Already existis
# 1753 NP_001154824.1 Already existis
# 1754 NP_065071.1 Already existis
# 1755 NP_001092138.1 Already existis
# 1756 NP_004320.2 Already existis
# 1757 NP_005262.1 Already existis
# 1758 NP_001604.1 Already existis
# 1759 NP_005088.1 Already existis
# 1760 NP_057425.3 Already existis
# 1761 NP_003052.2 Already existis
# 1762 NP_510870.1 Already existis
# 1763 NP_000269.3 Already existis
# 1764 NP_001364066.1 Already existis
# 1765 NP_060119.3 Already existis
# 1766 NP_569157.2 Already existis
# 1767 NP_001127835.2 Already existis
# 1768 NP_031399.2 Already existis
# 1769 NP_001600.1 Already existis
# 1770 NP_065109.1 Already existis
# 1771 NP_003273.1 Already existis
# 1772 NP_001014437.1 Already existis
# 1773 NP_055304.1 Already existis
# 1774 NP_001369496.1 Already existis
# 1775 NP_000509.1 Already existis
# 1776 NP_001243615.1 Already existis
# 1777 NP_001018067.1 Already existis
# 1778 NP_000306.1 Already existis
# 1779 NP_001354802.1 Already existis
# 1780 NP_001278992.1 Already existis
# 1781 NP_005557.1 Already existis
# 1782 NP_998764.1 Already existis
# 1783 NP_000602.1 Already existis
# 1784 NP_004162.2 Already existis
# 1785 NP_997005.1 Already existis
# 1786 NP_004804.2 Already existis
# 1787 NP_000497.1 Already existis
# 1788 NP_000247.2 Already existis
# 1789 NP_004542.1 Already existis
# 1790 NP_001914.3 Already existis
# 1791 NP_001116427.1 Already existis
# 1792 NP_006259.1 Already existis
# 1793 NP_001123616.1 Already existis
# 1794 NP_008877.2 Already existis
# 1795 NP_001035806.1 Already existis
# 1796 NP_660201.1 Already existis
# 1797 NP_002487.1 Already existis
# 1798 NP_006010.2 Already existis
# 1799 NP_060105.3 Already existis
# 1800 NP_060631.2 Already existis
# 1801 NP_001138341.1 Already existis
# 1802 NP_001122394.1 Already existis
# 1803 NP_002567.3 Already existis
# 1804 NP_004259.3 Already existis
# 1805 NP_005582.1 Already existis
# 1806 NP_002418.1 Already existis
# 1807 NP_055771.4 Already existis
# 1808 NP_005788.1 Already existis
# 1809 NP_004388.2 Already existis
# 1810 NP_001157749.1 Already existis
# 1811 NP_005413.2 Already existis
# 1812 NP_001245173.1 Already existis
# 1813 NP_002008.2 Already existis
# 1814 NP_000881.3 Already existis
# 1815 NP_001036068.1 Already existis
# 1816 NP_061852.3 Already existis
# 1817 NP_001161095.1 Already existis
# 1818 NP_001750.1 Already existis
# 1819 NP_065689.1 Already existis
# 1820 NP_002226.1 Already existis
# 1821 NP_001056.1 Already existis
# 1822 NP_001724.4 Already existis
# 1823 NP_065712.1 Already existis
# 1824 NP_001978.1 Already existis
# 1825 NP_004973.1 Already existis
# 1826 NP_945316.1 Already existis
# 1827 NP_085911.2 Already existis
# 1828 NP_001035526.1 Already existis
# 1829 NP_000280.1 Already existis
# 1830 NP_004809.2 Already existis
# 1831 NP_003385.2 Already existis
# 1832 NP_060583.2 Already existis
# 1833 NP_003067.3 Already existis
# 1834 NP_055006.1 Already existis
# 1835 NP_000414.2 Already existis
# 1836 NP_002896.2 Already existis
# 1837 NP_001027558.1 Already existis
# 1838 NP_001973.2 Already existis
# 1839 NP_004975.2 Already existis
# 1840 NP_005717.3 Already existis
# 1841 NP_002067.1 Already existis
# 1842 NP_055134.2 Already existis
# 1843 NP_001026849.1 Already existis
# 1844 NP_065134.1 Already existis
# 1845 NP_078961.3 Already existis
# 1846 NP_001138498.1 Already existis
# 1847 NP_647480.1 Already existis
# 1848 NP_001193908.1 Already existis
# 1849 NP_002456.2 Already existis
# 1850 NP_055521.1 Already existis
# 1851 NP_443077.1 Already existis
# 1852 NP_000422.1 Already existis
# 1853 NP_001076007.1 Already existis
# 1854 NP_001359503.1 Already existis
# 1855 NP_002825.3 Already existis
# 1856 NP_005987.3 Already existis
# 1857 NP_056150.1 Already existis
# 1858 NP_000008.1 Already existis
# 1859 NP_001405.1 Already existis
# 1860 NP_079085.2 Already existis
# 1861 NP_036595.2 Already existis
# 1862 NP_079491.2 Already existis
# 1863 NP_005923.3 Already existis
# 1864 NP_060921.3 Already existis
# 1865 NP_001251.1 Already existis
# 1866 NP_000200.1 Already existis
# 1867 NP_001256.4 Already existis
# 1868 NP_919299.3 Already existis
# 1869 NP_570718.1 Already existis
# 1870 NP_057701.1 Already existis
# 1871 NP_997244.4 Already existis
# 1872 NP_055120.1 Already existis
# 1873 NP_009060.2 Already existis
# 1874 NP_000114.3 Already existis
# 1875 NP_996820.1 Already existis
# 1876 NP_062562.1 Already existis
# 1877 NP_060277.1 Already existis
# 1878 NP_000261.2 Already existis
# 1879 NP_001092744.1 Already existis
# 1880 NP_002733.2 Already existis
# 1881 NP_006355.2 Already existis
# 1882 NP_002854.3 Already existis
# 1883 NP_001193.2 Already existis
# 1884 NP_060269.3 Already existis
# 1885 NP_068374.1 Already existis
# 1886 NP_005973.1 Already existis
# 1887 NP_001521.1 Already existis
# 1888 NP_647479.2 Already existis
# 1889 NP_056161.2 Already existis
# 1890 NP_001035197.1 Already existis
# 1891 NP_060261.2 Already existis
# 1892 NP_078772.1 Already existis
# 1893 NP_037514.2 Already existis
# 1894 NP_004854.1 Already existis
# 1895 NP_000286.3 Already existis
# 1896 NP_803187.1 Already existis
# 1897 NP_003375.1 Already existis
# 1898 NP_612808.1 Already existis
# 1899 NP_001357524.1 Already existis
# 1900 NP_001369359.1 Already existis
# 1901 NP_002217.3 Already existis
# 1902 NP_001510.2 Already existis
# 1903 NP_570854.1 Already existis
# 1904 NP_055782.3 Already existis
# 1905 NP_001238953.1 Already existis
# 1906 NP_005150.1 Already existis
# 1907 NP_733775.1 Already existis
# 1908 NP_001202.5 Already existis
# 1909 NP_002866.2 Already existis
# 1910 NP_714544.1 Already existis
# 1911 NP_689661.1 Already existis
# 1912 NP_997464.2 Already existis
# 1913 NP_001473.1 Already existis
# 1914 NP_076968.2 Already existis
# 1915 NP_001181927.1 Already existis
# 1916 NP_000227.2 Already existis
# 1917 NP_004989.2 Already existis
# 1918 NP_599023.1 Already existis
# 1919 NP_001018005.1 Already existis
# 1920 NP_000933.1 Already existis
# 1921 NP_004654.1 Already existis
# 1922 NP_005893.1 Already existis
# 1923 NP_060352.1 Already existis
# 1924 NP_000772.2 Already existis
# 1925 NP_002426.1 Already existis
# 1926 NP_001138830.1 Already existis
# 1927 NP_000741.1 Already existis
# 1928 NP_001356197.1 Already existis
# 1929 NP_001106849.1 Already existis
# 1930 NP_000048.1 Already existis
# 1931 NP_061138.3 Already existis
# 1932 NP_066285.1 Already existis
# 1933 NP_000866.1 Already existis
# 1934 NP_620688.2 Already existis
# 1935 NP_000684.2 Already existis
# 1936 NP_005852.2 Already existis
# 1937 NP_066921.2 Already existis
# 1938 NP_076425.1 Already existis
# 1939 NP_115647.2 Already existis
# 1940 NP_001752.2 Already existis
# 1941 NP_001186036.1 Already existis
# 1942 NP_077315.2 Already existis
# 1943 NP_003461.2 Already existis
# 1944 NP_001129944.1 Already existis
# 1945 NP_005227.1 Already existis
# 1946 NP_002573.1 Already existis
# 1947 NP_002465.1 Already existis
# 1948 NP_653273.3 Already existis
# 1949 NP_001077083.1 Already existis
# 1950 NP_001035897.1 Already existis
# 1951 NP_015556.1 Already existis
# 1952 NP_660282.2 Already existis
# 1953 NP_009005.1 Already existis
# 1954 NP_006653.2 Already existis
# 1955 NP_000285.1 Already existis
# 1956 NP_055527.1 Already existis
# 1957 NP_443106.1 Already existis
# 1958 NP_597700.1 Already existis
# 1959 NP_003022.3 Already existis
# 1960 NP_002959.2 Already existis
# 1961 NP_056087.2 Already existis
# 1962 NP_114091.4 Already existis
# 1963 NP_055484.3 Already existis
# 1964 NP_958933.1 Already existis
# 1965 NP_037374.1 Already existis
# 1966 NP_000187.3 Already existis
# 1967 NP_006556.1 Already existis
# 1968 NP_061896.1 Already existis
# 1969 NP_115758.3 Already existis
# 1970 NP_001119.3 Already existis
# 1971 NP_002652.2 Already existis
# 1972 NP_000092.2 Already existis
# 1973 NP_001136336.2 Already existis
# 1974 NP_000968.2 Already existis
# 1975 NP_002759.2 Already existis
# 1976 NP_001157281.1 Already existis
# 1977 NP_542435.2 Already existis
# 1978 NP_006603.2 Already existis
# 1979 NP_055619.2 Already existis
# 1980 NP_808218.1 Already existis
# 1981 NP_000738.2 Already existis
# 1982 NP_000928.1 Already existis
# 1983 NP_001335645.1 Already existis
# 1984 NP_001242941.1 Already existis
# 1985 NP_002461.2 Already existis
# 1986 NP_001363.2 Already existis
# 1987 NP_060597.4 Already existis
# 1988 NP_001036162.1 Already existis
# 1989 NP_004269.1 Already existis
# 1990 NP_659434.2 Already existis
# 1991 NP_109590.3 Already existis
# 1992 NP_002009.1 Already existis
# 1993 NP_056496.1 Already existis
# 1994 NP_000682.3 Already existis
# 1995 NP_001230368.1 Already existis
# 1996 NP_114140.4 Already existis
# 1997 NP_065842.1 Already existis
# 1998 NP_056170.2 Already existis
# 1999 NP_001253981.1 Already existis
# 2000 NP_942131.1 Already existis
# 2001 NP_219487.3 Already existis
# 2002 NP_955366.1 Already existis
# 2003 NP_003070.3 Already existis
# 2004 NP_000217.2 Already existis
# 2005 NP_000517.3 Already existis
# 2006 NP_068758.3 Already existis
# 2007 NP_036580.2 Already existis
# 2008 NP_001061.2 Already existis
# 2009 NP_001073143.1 Already existis
# 2010 NP_612396.1 Already existis
# 2011 NP_003387.1 Already existis
# 2012 NP_004278.2 Already existis
# 2013 NP_001007229.1 Already existis
# 2014 NP_061496.2 Already existis
# 2015 NP_003638.1 Already existis
# 2016 NP_003611.1 Already existis
# 2017 NP_114432.2 Already existis
# 2018 NP_006843.2 Already existis
# 2019 NP_000506.2 Already existis
# 2020 NP_872579.2 Already existis
# 2021 NP_060035.2 Already existis
# 2022 NP_758424.1 Already existis
# 2023 NP_000882.1 Already existis
# 2024 NP_997229.2 Already existis
# 2025 NP_954712.1 Already existis
# 2026 NP_001153245.1 Already existis
# 2027 NP_000909.2 Already existis
# 2028 NP_008838.2 Already existis
# 2029 NP_005550.2 Already existis
# 2030 NP_066552.2 Already existis
# 2031 NP_000520.1 Already existis
# 2032 NP_001136438.1 Already existis
# 2033 NP_002885.1 Already existis
# 2034 NP_085135.1 Already existis
# 2035 NP_055083.1 Already existis
# 2036 NP_005350.1 Already existis
# 2037 NP_004530.1 Already existis
# 2038 NP_001361314.1 Already existis
# 2039 NP_005903.2 Already existis
# 2040 NP_003830.1 Already existis
# 2041 NP_775901.3 Already existis
# 2042 NP_077718.3 Already existis
# 2043 NP_001051.1 Already existis
# 2044 NP_001952.1 Already existis
# 2045 NP_109587.1 Already existis
# 2046 NP_115484.2 Already existis
# 2047 NP_891549.1 Already existis
# 2048 NP_783313.1 Already existis
# 2049 NP_006003.1 Already existis
# 2050 NP_000055.2 Already existis
# 2051 NP_000199.2 Already existis
# 2052 NP_001124295.1 Already existis
# 2053 NP_001005361.1 Already existis
# 2054 NP_001276033.1 Already existis
# 2055 NP_000519.2 Already existis
# 2056 NP_001369170.1 Already existis
# 2057 NP_001129507.1 Already existis
# 2058 NP_443108.1 Already existis
# 2059 NP_001366220.1 Already existis
# 2060 NP_775754.2 Already existis
# 2061 NP_001073890.2 Already existis
# 2062 NP_004741.1 Already existis
# 2063 NP_001483.3 Already existis
# 2064 NP_004829.3 Already existis
# 2065 NP_113636.2 Already existis
# 2066 NP_644813.1 Already existis
# 2067 NP_079152.3 Already existis
# 2068 NP_114429.2 Already existis
# 2069 NP_004482.4 Already existis
# 2070 NP_008990.2 Already existis
# 2071 NP_001139281.1 Already existis
# 2072 NP_004968.2 Already existis
# 2073 NP_057232.2 Already existis
# 2074 NP_149059.1 Already existis
# 2075 NP_055040.2 Already existis
# 2076 NP_055331.1 Already existis
# 2077 NP_001243644.1 Already existis
# 2078 NP_009210.1 Already existis
# 2079 NP_945345.2 Already existis
# 2080 NP_003082.1 Already existis
# 2081 NP_000302.1 Already existis
# 2082 NP_001364071.1 Already existis
# 2083 NP_740754.1 Already existis
# 2084 NP_077025.2 Already existis
# 2085 NP_006354.2 Already existis
# 2086 NP_068556.2 Already existis
# 2087 NP_003089.1 Already existis
# 2088 NP_001269862.1 Already existis
# 2089 NP_000169.1 Already existis
# 2090 NP_056289.2 Already existis
# 2091 NP_001290386.1 Already existis
# 2092 NP_542119.1 Already existis
# 2093 NP_001073941.1 Already existis
# 2094 NP_004985.2 Already existis
# 2095 NP_065759.1 Already existis
# 2096 NP_073740.2 Already existis
# 2097 NP_005551.3 Already existis
# 2098 NP_059142.3 Already existis
# 2099 NP_001276054.1 Already existis
# 2100 NP_000620.2 Already existis
# 2101 NP_005060.1 Already existis
# 2102 NP_000062.1 Already existis
# 2103 NP_056074.1 Already existis
# 2104 NP_001121121.1 Already existis
# 2105 NP_001366129.1 Already existis
# 2106 NP_878315.2 Already existis
# 2107 NP_004773.1 Already existis
# 2108 NP_002736.3 Already existis
# 2109 NP_003064.2 Already existis
# 2110 NP_001878.1 Already existis
# 2111 NP_001877.1 Already existis
# 2112 NP_002421.3 Already existis
# 2113 NP_001229825.1 Already existis
# 2114 NP_002863.1 Already existis
# 2115 NP_689726.3 Already existis
# 2116 NP_443177.1 Already existis
# 2117 NP_001365347.1 Already existis
# 2118 NP_000389.1 Already existis
# 2119 NP_061868.1 Already existis
# 2120 NP_758448.1 Already existis
# 2121 NP_001307681.2 Already existis
# 2122 NP_001821.2 Already existis
# 2123 NP_000283.1 Already existis
# 2124 NP_004586.2 Already existis
# 2125 NP_000466.2 Already existis
# 2126 NP_003997.2 Already existis
# 2127 NP_005756.2 Already existis
# 2128 NP_001034680.2 Already existis
# 2129 NP_001278344.1 Already existis
# 2130 NP_001129470.1 Already existis
# 2131 NP_005667.2 Already existis
# 2132 NP_008881.2 Already existis
# 2133 NP_982301.1 Already existis
# 2134 NP_001027554.1 Already existis
# 2135 NP_001129629.1 Already existis
# 2136 NP_003170.1 Already existis
# 2137 NP_001138545.1 Already existis
# 2138 NP_001121370.1 Already existis
# 2139 NP_004484.1 Already existis
# 2140 NP_113584.3 Already existis
# 2141 NP_002538.1 Already existis
# 2142 NP_000197.1 Already existis
# 2143 NP_005111.2 Already existis
# 2144 NP_000298.3 Already existis
# 2145 NP_001004051.1 Already existis
# 2146 NP_004771.2 Already existis
# 2147 NP_002755.1 Already existis
# 2148 NP_001137453.1 Already existis
# 2149 NP_001075019.1 Already existis
# 2150 NP_001036215.1 Already existis
# 2151 NP_004199.1 Already existis
# 2152 NP_004475.1 Already existis
# 2153 NP_001366039.1 Already existis
# 2154 NP_003404.1 Already existis
# 2155 NP_004105.1 Already existis
# 2156 NP_002015.1 Already existis
# 2157 NP_002016.2 Already existis
# 2158 NP_001702.1 Already existis
# 2159 NP_003482.1 Already existis
# 2160 NP_001174.2 Already existis
# 2161 NP_004690.1 Already existis
# 2162 NP_000393.4 Already existis
# 2163 NP_001093327.1 Already existis
# 2164 NP_003131.1 Already existis
# #-unique NCBI protein sequences downloaded:  2165

# %%
# filtering on seq-len <= 1022
from Bio import SeqIO
data = []
n_prots = len(protein_acc_list)
for i, prot in enumerate(protein_acc_list):
    filepath = home_dir+f"data/np_proteins/fastas/{prot}.fasta" 
    seq_record = SeqIO.parse(filepath, format="fasta").__next__()
    seq = str(seq_record.seq)
    seq_len = len(seq)
    if seq_len<=1022:
        print(f"{i}/{n_prots}")
        x = variants_df[variants_df['prot_acc_version']==prot].copy()
        # x["seq_len"] = int(seq_len)
        # x["seq"] = seq
        data.append(x)
variants_df = pd.concat(data)
print(variants_df.shape)
variants_df["class"].value_counts()
# Out:
# 0/2165
# 1/2165
# 2/2165
# 3/2165
# 4/2165
# 5/2165
# 6/2165
# 7/2165
# 9/2165
# 11/2165
# 14/2165
# 15/2165
# 17/2165
# 18/2165
# 19/2165
# 21/2165
# 22/2165
# 23/2165
# 24/2165
# 26/2165
# 27/2165
# 28/2165
# 29/2165
# 30/2165
# 31/2165
# 32/2165
# 34/2165
# 35/2165
# 36/2165
# 37/2165
# 38/2165
# 40/2165
# 41/2165
# 42/2165
# 43/2165
# 45/2165
# 46/2165
# 47/2165
# 48/2165
# 51/2165
# 53/2165
# 54/2165
# 55/2165
# 57/2165
# 58/2165
# 59/2165
# 60/2165
# 62/2165
# 63/2165
# 65/2165
# 66/2165
# 68/2165
# 70/2165
# 71/2165
# 72/2165
# 73/2165
# 75/2165
# 76/2165
# 77/2165
# 78/2165
# 79/2165
# 80/2165
# 81/2165
# 82/2165
# 83/2165
# 84/2165
# 85/2165
# 86/2165
# 87/2165
# 88/2165
# 89/2165
# 90/2165
# 91/2165
# 92/2165
# 94/2165
# 97/2165
# 100/2165
# 102/2165
# 103/2165
# 105/2165
# 106/2165
# 107/2165
# 110/2165
# 111/2165
# 112/2165
# 113/2165
# 114/2165
# 115/2165
# 116/2165
# 117/2165
# 119/2165
# 120/2165
# 121/2165
# 122/2165
# 124/2165
# 125/2165
# 126/2165
# 128/2165
# 130/2165
# 131/2165
# 132/2165
# 133/2165
# 135/2165
# 136/2165
# 138/2165
# 139/2165
# 141/2165
# 142/2165
# 143/2165
# 144/2165
# 145/2165
# 146/2165
# 147/2165
# 149/2165
# 151/2165
# 152/2165
# 153/2165
# 155/2165
# 156/2165
# 158/2165
# 159/2165
# 160/2165
# 161/2165
# 162/2165
# 163/2165
# 164/2165
# 165/2165
# 167/2165
# 168/2165
# 170/2165
# 171/2165
# 172/2165
# 174/2165
# 176/2165
# 177/2165
# 179/2165
# 183/2165
# 186/2165
# 187/2165
# 188/2165
# 189/2165
# 190/2165
# 191/2165
# 194/2165
# 196/2165
# 197/2165
# 203/2165
# 204/2165
# 205/2165
# 206/2165
# 207/2165
# 208/2165
# 209/2165
# 210/2165
# 212/2165
# 213/2165
# 216/2165
# 217/2165
# 218/2165
# 219/2165
# 222/2165
# 223/2165
# 224/2165
# 228/2165
# 230/2165
# 231/2165
# 232/2165
# 233/2165
# 234/2165
# 235/2165
# 236/2165
# 237/2165
# 238/2165
# 239/2165
# 240/2165
# 241/2165
# 242/2165
# 243/2165
# 244/2165
# 245/2165
# 247/2165
# 248/2165
# 249/2165
# 250/2165
# 251/2165
# 252/2165
# 256/2165
# 257/2165
# 258/2165
# 259/2165
# 260/2165
# 262/2165
# 263/2165
# 264/2165
# 267/2165
# 268/2165
# 270/2165
# 271/2165
# 272/2165
# 273/2165
# 274/2165
# 276/2165
# 277/2165
# 278/2165
# 279/2165
# 283/2165
# 284/2165
# 285/2165
# 286/2165
# 288/2165
# 289/2165
# 290/2165
# 291/2165
# 292/2165
# 293/2165
# 294/2165
# 295/2165
# 297/2165
# 298/2165
# 300/2165
# 301/2165
# 302/2165
# 303/2165
# 304/2165
# 305/2165
# 306/2165
# 307/2165
# 308/2165
# 309/2165
# 312/2165
# 313/2165
# 314/2165
# 315/2165
# 316/2165
# 317/2165
# 318/2165
# 319/2165
# 320/2165
# 322/2165
# 324/2165
# 325/2165
# 326/2165
# 327/2165
# 328/2165
# 329/2165
# 331/2165
# 332/2165
# 333/2165
# 336/2165
# 337/2165
# 338/2165
# 339/2165
# 340/2165
# 341/2165
# 342/2165
# 343/2165
# 344/2165
# 345/2165
# 346/2165
# 347/2165
# 348/2165
# 350/2165
# 352/2165
# 353/2165
# 354/2165
# 355/2165
# 356/2165
# 357/2165
# 358/2165
# 360/2165
# 361/2165
# 362/2165
# 364/2165
# 365/2165
# 369/2165
# 370/2165
# 371/2165
# 372/2165
# 373/2165
# 377/2165
# 378/2165
# 379/2165
# 380/2165
# 381/2165
# 382/2165
# 383/2165
# 384/2165
# 386/2165
# 387/2165
# 388/2165
# 390/2165
# 391/2165
# 393/2165
# 394/2165
# 395/2165
# 397/2165
# 398/2165
# 399/2165
# 402/2165
# 403/2165
# 405/2165
# 407/2165
# 408/2165
# 410/2165
# 411/2165
# 412/2165
# 415/2165
# 416/2165
# 418/2165
# 419/2165
# 420/2165
# 421/2165
# 422/2165
# 423/2165
# 424/2165
# 426/2165
# 427/2165
# 428/2165
# 429/2165
# 431/2165
# 432/2165
# 433/2165
# 434/2165
# 435/2165
# 436/2165
# 437/2165
# 438/2165
# 439/2165
# 440/2165
# 441/2165
# 442/2165
# 443/2165
# 444/2165
# 445/2165
# 446/2165
# 448/2165
# 451/2165
# 452/2165
# 453/2165
# 454/2165
# 455/2165
# 456/2165
# 457/2165
# 458/2165
# 459/2165
# 460/2165
# 461/2165
# 462/2165
# 463/2165
# 467/2165
# 468/2165
# 470/2165
# 471/2165
# 472/2165
# 473/2165
# 474/2165
# 475/2165
# 476/2165
# 477/2165
# 478/2165
# 479/2165
# 480/2165
# 481/2165
# 483/2165
# 484/2165
# 485/2165
# 487/2165
# 489/2165
# 490/2165
# 492/2165
# 493/2165
# 497/2165
# 498/2165
# 500/2165
# 501/2165
# 503/2165
# 504/2165
# 505/2165
# 506/2165
# 507/2165
# 508/2165
# 510/2165
# 511/2165
# 512/2165
# 513/2165
# 515/2165
# 517/2165
# 518/2165
# 520/2165
# 521/2165
# 522/2165
# 523/2165
# 524/2165
# 527/2165
# 528/2165
# 530/2165
# 531/2165
# 532/2165
# 533/2165
# 534/2165
# 535/2165
# 537/2165
# 538/2165
# 539/2165
# 541/2165
# 543/2165
# 544/2165
# 545/2165
# 547/2165
# 548/2165
# 549/2165
# 550/2165
# 551/2165
# 552/2165
# 553/2165
# 556/2165
# 557/2165
# 559/2165
# 560/2165
# 561/2165
# 562/2165
# 563/2165
# 564/2165
# 566/2165
# 567/2165
# 568/2165
# 569/2165
# 570/2165
# 571/2165
# 572/2165
# 573/2165
# 574/2165
# 576/2165
# 577/2165
# 578/2165
# 579/2165
# 580/2165
# 583/2165
# 584/2165
# 585/2165
# 586/2165
# 587/2165
# 589/2165
# 590/2165
# 592/2165
# 593/2165
# 594/2165
# 595/2165
# 596/2165
# 598/2165
# 599/2165
# 602/2165
# 603/2165
# 605/2165
# 606/2165
# 608/2165
# 609/2165
# 610/2165
# 611/2165
# 612/2165
# 614/2165
# 615/2165
# 617/2165
# 619/2165
# 620/2165
# 621/2165
# 622/2165
# 623/2165
# 625/2165
# 626/2165
# 627/2165
# 629/2165
# 630/2165
# 631/2165
# 632/2165
# 633/2165
# 634/2165
# 635/2165
# 636/2165
# 638/2165
# 639/2165
# 640/2165
# 641/2165
# 644/2165
# 645/2165
# 649/2165
# 651/2165
# 652/2165
# 653/2165
# 655/2165
# 656/2165
# 657/2165
# 658/2165
# 659/2165
# 660/2165
# 663/2165
# 665/2165
# 666/2165
# 667/2165
# 668/2165
# 669/2165
# 671/2165
# 672/2165
# 673/2165
# 674/2165
# 675/2165
# 676/2165
# 677/2165
# 678/2165
# 679/2165
# 680/2165
# 682/2165
# 683/2165
# 684/2165
# 685/2165
# 686/2165
# 687/2165
# 688/2165
# 690/2165
# 691/2165
# 693/2165
# 694/2165
# 695/2165
# 696/2165
# 697/2165
# 698/2165
# 699/2165
# 700/2165
# 701/2165
# 702/2165
# 703/2165
# 704/2165
# 705/2165
# 706/2165
# 708/2165
# 709/2165
# 710/2165
# 711/2165
# 712/2165
# 714/2165
# 715/2165
# 716/2165
# 717/2165
# 718/2165
# 720/2165
# 721/2165
# 722/2165
# 723/2165
# 724/2165
# 725/2165
# 727/2165
# 728/2165
# 730/2165
# 731/2165
# 732/2165
# 733/2165
# 734/2165
# 735/2165
# 736/2165
# 737/2165
# 739/2165
# 740/2165
# 741/2165
# 742/2165
# 743/2165
# 744/2165
# 745/2165
# 746/2165
# 747/2165
# 748/2165
# 750/2165
# 751/2165
# 752/2165
# 754/2165
# 755/2165
# 758/2165
# 760/2165
# 761/2165
# 762/2165
# 763/2165
# 764/2165
# 765/2165
# 767/2165
# 768/2165
# 770/2165
# 771/2165
# 772/2165
# 773/2165
# 774/2165
# 776/2165
# 777/2165
# 778/2165
# 779/2165
# 780/2165
# 781/2165
# 782/2165
# 783/2165
# 784/2165
# 785/2165
# 787/2165
# 788/2165
# 789/2165
# 791/2165
# 795/2165
# 797/2165
# 798/2165
# 799/2165
# 800/2165
# 802/2165
# 804/2165
# 805/2165
# 807/2165
# 808/2165
# 809/2165
# 810/2165
# 812/2165
# 813/2165
# 814/2165
# 815/2165
# 816/2165
# 818/2165
# 819/2165
# 820/2165
# 821/2165
# 822/2165
# 823/2165
# 824/2165
# 825/2165
# 826/2165
# 828/2165
# 829/2165
# 832/2165
# 836/2165
# 838/2165
# 839/2165
# 841/2165
# 842/2165
# 843/2165
# 847/2165
# 848/2165
# 849/2165
# 850/2165
# 851/2165
# 854/2165
# 855/2165
# 856/2165
# 857/2165
# 858/2165
# 860/2165
# 861/2165
# 865/2165
# 867/2165
# 870/2165
# 871/2165
# 873/2165
# 874/2165
# 875/2165
# 876/2165
# 878/2165
# 879/2165
# 880/2165
# 881/2165
# 882/2165
# 884/2165
# 885/2165
# 886/2165
# 887/2165
# 888/2165
# 890/2165
# 891/2165
# 892/2165
# 893/2165
# 894/2165
# 895/2165
# 896/2165
# 897/2165
# 898/2165
# 899/2165
# 900/2165
# 901/2165
# 902/2165
# 903/2165
# 905/2165
# 906/2165
# 907/2165
# 911/2165
# 912/2165
# 913/2165
# 916/2165
# 917/2165
# 918/2165
# 920/2165
# 923/2165
# 925/2165
# 927/2165
# 928/2165
# 929/2165
# 930/2165
# 932/2165
# 933/2165
# 934/2165
# 935/2165
# 936/2165
# 937/2165
# 938/2165
# 939/2165
# 940/2165
# 941/2165
# 943/2165
# 945/2165
# 946/2165
# 948/2165
# 949/2165
# 952/2165
# 953/2165
# 954/2165
# 955/2165
# 956/2165
# 957/2165
# 961/2165
# 963/2165
# 964/2165
# 968/2165
# 969/2165
# 970/2165
# 971/2165
# 973/2165
# 975/2165
# 976/2165
# 977/2165
# 978/2165
# 979/2165
# 980/2165
# 981/2165
# 982/2165
# 983/2165
# 984/2165
# 987/2165
# 988/2165
# 989/2165
# 990/2165
# 991/2165
# 992/2165
# 993/2165
# 994/2165
# 995/2165
# 997/2165
# 998/2165
# 999/2165
# 1001/2165
# 1002/2165
# 1003/2165
# 1004/2165
# 1006/2165
# 1007/2165
# 1008/2165
# 1009/2165
# 1011/2165
# 1013/2165
# 1015/2165
# 1017/2165
# 1018/2165
# 1019/2165
# 1020/2165
# 1021/2165
# 1022/2165
# 1023/2165
# 1024/2165
# 1025/2165
# 1026/2165
# 1027/2165
# 1031/2165
# 1033/2165
# 1034/2165
# 1036/2165
# 1037/2165
# 1038/2165
# 1039/2165
# 1040/2165
# 1041/2165
# 1042/2165
# 1043/2165
# 1044/2165
# 1047/2165
# 1049/2165
# 1050/2165
# 1052/2165
# 1053/2165
# 1054/2165
# 1056/2165
# 1057/2165
# 1058/2165
# 1060/2165
# 1062/2165
# 1063/2165
# 1065/2165
# 1067/2165
# 1069/2165
# 1070/2165
# 1071/2165
# 1072/2165
# 1073/2165
# 1075/2165
# 1076/2165
# 1078/2165
# 1079/2165
# 1081/2165
# 1082/2165
# 1083/2165
# 1087/2165
# 1088/2165
# 1091/2165
# 1092/2165
# 1095/2165
# 1098/2165
# 1099/2165
# 1100/2165
# 1101/2165
# 1103/2165
# 1104/2165
# 1105/2165
# 1106/2165
# 1108/2165
# 1109/2165
# 1110/2165
# 1111/2165
# 1112/2165
# 1113/2165
# 1114/2165
# 1115/2165
# 1116/2165
# 1118/2165
# 1119/2165
# 1122/2165
# 1124/2165
# 1125/2165
# 1126/2165
# 1127/2165
# 1129/2165
# 1130/2165
# 1131/2165
# 1132/2165
# 1135/2165
# 1137/2165
# 1139/2165
# 1141/2165
# 1142/2165
# 1143/2165
# 1144/2165
# 1145/2165
# 1146/2165
# 1147/2165
# 1151/2165
# 1153/2165
# 1154/2165
# 1155/2165
# 1156/2165
# 1157/2165
# 1158/2165
# 1160/2165
# 1161/2165
# 1162/2165
# 1163/2165
# 1164/2165
# 1165/2165
# 1166/2165
# 1167/2165
# 1171/2165
# 1172/2165
# 1173/2165
# 1174/2165
# 1175/2165
# 1176/2165
# 1177/2165
# 1178/2165
# 1179/2165
# 1180/2165
# 1181/2165
# 1182/2165
# 1183/2165
# 1184/2165
# 1185/2165
# 1187/2165
# 1189/2165
# 1191/2165
# 1192/2165
# 1193/2165
# 1194/2165
# 1195/2165
# 1196/2165
# 1197/2165
# 1198/2165
# 1199/2165
# 1201/2165
# 1202/2165
# 1203/2165
# 1204/2165
# 1205/2165
# 1206/2165
# 1207/2165
# 1209/2165
# 1210/2165
# 1212/2165
# 1213/2165
# 1214/2165
# 1215/2165
# 1216/2165
# 1217/2165
# 1218/2165
# 1219/2165
# 1220/2165
# 1221/2165
# 1222/2165
# 1223/2165
# 1225/2165
# 1226/2165
# 1227/2165
# 1228/2165
# 1229/2165
# 1230/2165
# 1231/2165
# 1233/2165
# 1234/2165
# 1236/2165
# 1237/2165
# 1238/2165
# 1239/2165
# 1240/2165
# 1242/2165
# 1243/2165
# 1245/2165
# 1246/2165
# 1247/2165
# 1249/2165
# 1251/2165
# 1252/2165
# 1253/2165
# 1254/2165
# 1255/2165
# 1256/2165
# 1257/2165
# 1258/2165
# 1259/2165
# 1260/2165
# 1261/2165
# 1262/2165
# 1265/2165
# 1266/2165
# 1268/2165
# 1269/2165
# 1270/2165
# 1271/2165
# 1272/2165
# 1273/2165
# 1274/2165
# 1275/2165
# 1276/2165
# 1278/2165
# 1279/2165
# 1280/2165
# 1281/2165
# 1282/2165
# 1283/2165
# 1284/2165
# 1285/2165
# 1286/2165
# 1287/2165
# 1288/2165
# 1289/2165
# 1290/2165
# 1291/2165
# 1296/2165
# 1297/2165
# 1298/2165
# 1299/2165
# 1300/2165
# 1301/2165
# 1302/2165
# 1303/2165
# 1304/2165
# 1306/2165
# 1307/2165
# 1310/2165
# 1313/2165
# 1314/2165
# 1315/2165
# 1317/2165
# 1319/2165
# 1320/2165
# 1322/2165
# 1323/2165
# 1324/2165
# 1325/2165
# 1326/2165
# 1327/2165
# 1328/2165
# 1329/2165
# 1330/2165
# 1331/2165
# 1332/2165
# 1333/2165
# 1334/2165
# 1335/2165
# 1336/2165
# 1337/2165
# 1338/2165
# 1339/2165
# 1340/2165
# 1341/2165
# 1342/2165
# 1343/2165
# 1345/2165
# 1346/2165
# 1348/2165
# 1349/2165
# 1350/2165
# 1353/2165
# 1354/2165
# 1355/2165
# 1356/2165
# 1357/2165
# 1359/2165
# 1360/2165
# 1362/2165
# 1363/2165
# 1364/2165
# 1366/2165
# 1367/2165
# 1368/2165
# 1370/2165
# 1371/2165
# 1373/2165
# 1374/2165
# 1375/2165
# 1376/2165
# 1377/2165
# 1378/2165
# 1379/2165
# 1381/2165
# 1384/2165
# 1385/2165
# 1386/2165
# 1387/2165
# 1388/2165
# 1389/2165
# 1390/2165
# 1391/2165
# 1392/2165
# 1393/2165
# 1394/2165
# 1395/2165
# 1396/2165
# 1398/2165
# 1400/2165
# 1401/2165
# 1403/2165
# 1404/2165
# 1405/2165
# 1407/2165
# 1408/2165
# 1410/2165
# 1414/2165
# 1415/2165
# 1417/2165
# 1418/2165
# 1419/2165
# 1420/2165
# 1421/2165
# 1423/2165
# 1424/2165
# 1425/2165
# 1427/2165
# 1429/2165
# 1431/2165
# 1433/2165
# 1434/2165
# 1435/2165
# 1437/2165
# 1440/2165
# 1441/2165
# 1443/2165
# 1444/2165
# 1446/2165
# 1447/2165
# 1448/2165
# 1449/2165
# 1452/2165
# 1453/2165
# 1454/2165
# 1456/2165
# 1457/2165
# 1458/2165
# 1460/2165
# 1463/2165
# 1464/2165
# 1468/2165
# 1469/2165
# 1470/2165
# 1471/2165
# 1472/2165
# 1473/2165
# 1474/2165
# 1475/2165
# 1477/2165
# 1478/2165
# 1479/2165
# 1480/2165
# 1482/2165
# 1484/2165
# 1485/2165
# 1486/2165
# 1487/2165
# 1488/2165
# 1489/2165
# 1490/2165
# 1492/2165
# 1494/2165
# 1495/2165
# 1497/2165
# 1498/2165
# 1500/2165
# 1502/2165
# 1504/2165
# 1505/2165
# 1506/2165
# 1507/2165
# 1509/2165
# 1510/2165
# 1512/2165
# 1513/2165
# 1514/2165
# 1516/2165
# 1517/2165
# 1518/2165
# 1519/2165
# 1520/2165
# 1521/2165
# 1522/2165
# 1523/2165
# 1524/2165
# 1525/2165
# 1528/2165
# 1529/2165
# 1530/2165
# 1532/2165
# 1533/2165
# 1534/2165
# 1535/2165
# 1537/2165
# 1538/2165
# 1540/2165
# 1541/2165
# 1543/2165
# 1544/2165
# 1546/2165
# 1547/2165
# 1548/2165
# 1549/2165
# 1550/2165
# 1553/2165
# 1554/2165
# 1555/2165
# 1556/2165
# 1557/2165
# 1558/2165
# 1559/2165
# 1560/2165
# 1562/2165
# 1563/2165
# 1564/2165
# 1565/2165
# 1566/2165
# 1567/2165
# 1568/2165
# 1569/2165
# 1571/2165
# 1572/2165
# 1573/2165
# 1574/2165
# 1575/2165
# 1576/2165
# 1577/2165
# 1578/2165
# 1580/2165
# 1582/2165
# 1586/2165
# 1587/2165
# 1589/2165
# 1590/2165
# 1592/2165
# 1594/2165
# 1595/2165
# 1596/2165
# 1598/2165
# 1599/2165
# 1600/2165
# 1601/2165
# 1602/2165
# 1604/2165
# 1605/2165
# 1606/2165
# 1608/2165
# 1609/2165
# 1610/2165
# 1611/2165
# 1613/2165
# 1616/2165
# 1617/2165
# 1618/2165
# 1620/2165
# 1623/2165
# 1624/2165
# 1626/2165
# 1627/2165
# 1628/2165
# 1630/2165
# 1631/2165
# 1633/2165
# 1635/2165
# 1636/2165
# 1638/2165
# 1639/2165
# 1640/2165
# 1641/2165
# 1642/2165
# 1643/2165
# 1644/2165
# 1645/2165
# 1646/2165
# 1647/2165
# 1648/2165
# 1650/2165
# 1651/2165
# 1652/2165
# 1653/2165
# 1654/2165
# 1655/2165
# 1659/2165
# 1661/2165
# 1662/2165
# 1663/2165
# 1664/2165
# 1666/2165
# 1668/2165
# 1670/2165
# 1671/2165
# 1672/2165
# 1673/2165
# 1674/2165
# 1675/2165
# 1676/2165
# 1677/2165
# 1678/2165
# 1679/2165
# 1680/2165
# 1683/2165
# 1684/2165
# 1685/2165
# 1686/2165
# 1688/2165
# 1689/2165
# 1690/2165
# 1691/2165
# 1692/2165
# 1693/2165
# 1696/2165
# 1697/2165
# 1698/2165
# 1699/2165
# 1700/2165
# 1703/2165
# 1704/2165
# 1706/2165
# 1707/2165
# 1708/2165
# 1709/2165
# 1710/2165
# 1712/2165
# 1713/2165
# 1714/2165
# 1716/2165
# 1717/2165
# 1718/2165
# 1719/2165
# 1720/2165
# 1721/2165
# 1722/2165
# 1723/2165
# 1724/2165
# 1727/2165
# 1729/2165
# 1731/2165
# 1732/2165
# 1733/2165
# 1734/2165
# 1735/2165
# 1737/2165
# 1738/2165
# 1739/2165
# 1740/2165
# 1741/2165
# 1742/2165
# 1743/2165
# 1746/2165
# 1748/2165
# 1749/2165
# 1750/2165
# 1751/2165
# 1755/2165
# 1756/2165
# 1757/2165
# 1758/2165
# 1759/2165
# 1762/2165
# 1763/2165
# 1765/2165
# 1766/2165
# 1768/2165
# 1769/2165
# 1770/2165
# 1771/2165
# 1772/2165
# 1773/2165
# 1774/2165
# 1775/2165
# 1776/2165
# 1777/2165
# 1778/2165
# 1779/2165
# 1781/2165
# 1782/2165
# 1783/2165
# 1784/2165
# 1785/2165
# 1786/2165
# 1787/2165
# 1789/2165
# 1791/2165
# 1792/2165
# 1796/2165
# 1797/2165
# 1798/2165
# 1799/2165
# 1800/2165
# 1801/2165
# 1802/2165
# 1803/2165
# 1804/2165
# 1805/2165
# 1806/2165
# 1808/2165
# 1809/2165
# 1810/2165
# 1812/2165
# 1813/2165
# 1814/2165
# 1818/2165
# 1819/2165
# 1820/2165
# 1821/2165
# 1822/2165
# 1823/2165
# 1824/2165
# 1825/2165
# 1826/2165
# 1827/2165
# 1828/2165
# 1829/2165
# 1830/2165
# 1831/2165
# 1832/2165
# 1833/2165
# 1835/2165
# 1836/2165
# 1837/2165
# 1840/2165
# 1841/2165
# 1842/2165
# 1843/2165
# 1844/2165
# 1845/2165
# 1847/2165
# 1848/2165
# 1850/2165
# 1851/2165
# 1852/2165
# 1853/2165
# 1855/2165
# 1856/2165
# 1858/2165
# 1859/2165
# 1860/2165
# 1861/2165
# 1862/2165
# 1863/2165
# 1865/2165
# 1866/2165
# 1867/2165
# 1868/2165
# 1869/2165
# 1870/2165
# 1872/2165
# 1873/2165
# 1875/2165
# 1876/2165
# 1877/2165
# 1878/2165
# 1879/2165
# 1880/2165
# 1881/2165
# 1882/2165
# 1883/2165
# 1884/2165
# 1885/2165
# 1886/2165
# 1887/2165
# 1888/2165
# 1891/2165
# 1892/2165
# 1893/2165
# 1894/2165
# 1895/2165
# 1897/2165
# 1898/2165
# 1899/2165
# 1900/2165
# 1902/2165
# 1903/2165
# 1904/2165
# 1906/2165
# 1907/2165
# 1909/2165
# 1911/2165
# 1912/2165
# 1913/2165
# 1914/2165
# 1916/2165
# 1918/2165
# 1919/2165
# 1920/2165
# 1921/2165
# 1922/2165
# 1923/2165
# 1924/2165
# 1925/2165
# 1927/2165
# 1931/2165
# 1932/2165
# 1935/2165
# 1936/2165
# 1938/2165
# 1939/2165
# 1940/2165
# 1941/2165
# 1942/2165
# 1944/2165
# 1945/2165
# 1946/2165
# 1949/2165
# 1950/2165
# 1951/2165
# 1952/2165
# 1953/2165
# 1955/2165
# 1957/2165
# 1958/2165
# 1959/2165
# 1962/2165
# 1963/2165
# 1964/2165
# 1965/2165
# 1966/2165
# 1967/2165
# 1968/2165
# 1969/2165
# 1970/2165
# 1972/2165
# 1974/2165
# 1975/2165
# 1977/2165
# 1979/2165
# 1980/2165
# 1981/2165
# 1987/2165
# 1988/2165
# 1989/2165
# 1990/2165
# 1993/2165
# 1994/2165
# 1996/2165
# 1997/2165
# 1998/2165
# 1999/2165
# 2001/2165
# 2002/2165
# 2003/2165
# 2004/2165
# 2005/2165
# 2006/2165
# 2007/2165
# 2008/2165
# 2009/2165
# 2010/2165
# 2011/2165
# 2012/2165
# 2013/2165
# 2015/2165
# 2016/2165
# 2018/2165
# 2019/2165
# 2021/2165
# 2023/2165
# 2024/2165
# 2026/2165
# 2027/2165
# 2028/2165
# 2030/2165
# 2031/2165
# 2033/2165
# 2035/2165
# 2036/2165
# 2037/2165
# 2039/2165
# 2040/2165
# 2042/2165
# 2043/2165
# 2044/2165
# 2045/2165
# 2046/2165
# 2047/2165
# 2048/2165
# 2049/2165
# 2053/2165
# 2054/2165
# 2055/2165
# 2056/2165
# 2057/2165
# 2058/2165
# 2060/2165
# 2062/2165
# 2063/2165
# 2064/2165
# 2065/2165
# 2066/2165
# 2067/2165
# 2068/2165
# 2070/2165
# 2072/2165
# 2074/2165
# 2075/2165
# 2076/2165
# 2077/2165
# 2078/2165
# 2079/2165
# 2080/2165
# 2081/2165
# 2083/2165
# 2084/2165
# 2085/2165
# 2086/2165
# 2087/2165
# 2088/2165
# 2089/2165
# 2090/2165
# 2092/2165
# 2093/2165
# 2094/2165
# 2096/2165
# 2098/2165
# 2099/2165
# 2100/2165
# 2101/2165
# 2102/2165
# 2103/2165
# 2104/2165
# 2105/2165
# 2106/2165
# 2107/2165
# 2108/2165
# 2109/2165
# 2110/2165
# 2111/2165
# 2114/2165
# 2116/2165
# 2118/2165
# 2120/2165
# 2121/2165
# 2122/2165
# 2124/2165
# 2125/2165
# 2127/2165
# 2130/2165
# 2131/2165
# 2132/2165
# 2133/2165
# 2134/2165
# 2135/2165
# 2136/2165
# 2137/2165
# 2138/2165
# 2139/2165
# 2141/2165
# 2142/2165
# 2144/2165
# 2145/2165
# 2146/2165
# 2147/2165
# 2148/2165
# 2151/2165
# 2152/2165
# 2153/2165
# 2154/2165
# 2155/2165
# 2156/2165
# 2158/2165
# 2159/2165
# 2160/2165
# 2161/2165
# 2162/2165
# 2163/2165
# 2164/2165
# (7426, 20)
# Likely-pathogenic    4865
# Pathogenic           2561
# Name: class, dtype: int64

# %%
variants_removing_delins_df = variants_df[variants_df.apply(lambda row: "delins" not in row.prot_variant, axis=1)]
print(variants_removing_delins_df.shape[0], variants_df.shape[0]-variants_removing_delins_df.shape[0])

# filter unknown AA in ref and alt
print(variants_removing_delins_df["wt_aa_1letter"].value_counts())
print(variants_removing_delins_df["mt_aa_1letter"].value_counts())

variants_removing_unknownaa_df = variants_removing_delins_df[variants_removing_delins_df.apply(lambda row: len(row.wt_aa_1letter)==1 and len(row.mt_aa_1letter)==1, axis=1)]
print(variants_removing_unknownaa_df.shape[0], variants_removing_delins_df.shape[0]-variants_removing_unknownaa_df.shape[0])

# filter unknown Nuc in ref and alt allele
print(variants_removing_unknownaa_df["ref_allele"].value_counts())
print(variants_removing_unknownaa_df["alt_allele"].value_counts())

variants_removing_unknownnuc_df = variants_removing_unknownaa_df[variants_removing_unknownaa_df.apply(lambda row: len(row.ref_allele)==1 and len(row.alt_allele)==1, axis=1)]
print(variants_removing_unknownnuc_df.shape[0], variants_removing_unknownaa_df.shape[0]-variants_removing_unknownnuc_df.shape[0])

# convert prot mut position into int
variants_removing_unknownnuc_df["1indexed_prot_mt_pos"] = variants_removing_unknownnuc_df.apply(lambda row: int(row["1indexed_prot_mt_pos"]), axis=1).copy()

filtered_variants_df = variants_removing_unknownnuc_df.copy()
# Out:
# 7425 1
# R    1033
# G     883
# L     518
# M     466
# P     430
# D     406
# A     404
# S     371
# C     363
# V     334
# T     282
# E     278
# I     252
# Y     247
# H     242
# N     213
# F     212
# K     189
# Q     152
# W     150
# Name: wt_aa_1letter, dtype: int64
# R      806
# P      587
# L      558
# S      556
# V      520
# C      402
# T      401
# G      377
# H      337
# D      321
# N      300
# K      283
# Y      282
# I      281
# E      269
# Q      265
# A      258
# F      238
# W      209
# M      141
# Ter     34
# Name: mt_aa_1letter, dtype: int64
# 7391 34
# G                        2327
# C                        2211
# T                        1463
# A                        1331
# GC                         17
# TC                          5
# GA                          4
# TG                          4
# CA                          3
# CC                          3
# AG                          2
# CG                          2
# GT                          2
# GG                          2
# CT                          2
# AA                          1
# CCC                         1
# GGG                         1
# CAG                         1
# CGAGGTCTATAAGCACGAGGT       1
# AT                          1
# AC                          1
# GAG                         1
# CAC                         1
# GAC                         1
# ACG                         1
# TGT                         1
# TT                          1
# Name: ref_allele, dtype: int64
# A         1980
# T         1950
# G         1714
# C         1688
# AA          12
# TT          11
# CA           5
# AT           5
# CT           4
# GC           3
# AG           2
# TC           2
# GG           2
# TA           1
# TCT          1
# CGAGGT       1
# TAT          1
# TGT          1
# AC           1
# AAA          1
# TAG          1
# TGG          1
# GT           1
# GAT          1
# CCA          1
# GA           1
# Name: alt_allele, dtype: int64
# 7332 59
# /tmp/ipykernel_2345795/2081839051.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   variants_removing_unknownnuc_df["1indexed_prot_mt_pos"] = variants_removing_unknownnuc_df.apply(lambda row: int(row["1indexed_prot_mt_pos"]), axis=1).copy()

# %%
filtered_variants_df.loc[filtered_variants_df["chrom_num"]==23, "chrom_num"] = "X"
filtered_variants_df.loc[filtered_variants_df["chrom_num"]==24, "chrom_num"] = "Y"

# %%
print(filtered_variants_df["wt_aa_1letter"].value_counts())
print(filtered_variants_df["mt_aa_1letter"].value_counts())
print(filtered_variants_df["ref_allele"].value_counts())
print(filtered_variants_df["alt_allele"].value_counts())
print(filtered_variants_df["1indexed_prot_mt_pos"].value_counts()) # perfect
print(filtered_variants_df["chrom_num"].value_counts()) 
print(filtered_variants_df.shape)
print(filtered_variants_df["class"].value_counts()) 
print(filtered_variants_df["clinvar_id"].dropna().unique().shape[0])
print(filtered_variants_df["gene_name"].dropna().unique().shape[0])
print(filtered_variants_df["prot_acc_version"].dropna().unique().shape[0])
# Out:
# R    1026
# G     872
# L     514
# M     463
# P     424
# D     402
# A     397
# S     366
# C     356
# V     331
# T     281
# E     267
# I     251
# H     241
# Y     240
# N     213
# F     211
# K     187
# W     146
# Q     144
# Name: wt_aa_1letter, dtype: int64
# R    805
# P    584
# S    553
# L    550
# V    514
# T    401
# C    398
# G    374
# H    335
# D    319
# N    296
# Y    281
# K    278
# I    278
# E    266
# Q    263
# A    257
# F    234
# W    208
# M    138
# Name: mt_aa_1letter, dtype: int64
# G    2327
# C    2211
# T    1463
# A    1331
# Name: ref_allele, dtype: int64
# A    1980
# T    1950
# G    1714
# C    1688
# Name: alt_allele, dtype: int64
# 1      276
# 101     28
# 57      27
# 202     27
# 156     26
#       ...
# 710      1
# 895      1
# 567      1
# 651      1
# 569      1
# Name: 1indexed_prot_mt_pos, Length: 839, dtype: int64
# 23    815
# 1     732
# 11    518
# 2     451
# 3     427
# 17    424
# 19    418
# 12    351
# 7     343
# 6     321
# 9     313
# 16    296
# 5     290
# 4     235
# 14    219
# 10    216
# 8     194
# 20    194
# 15    173
# 22    120
# 21    107
# 13    101
# 18     66
# 24      8
# Name: chrom_num, dtype: int64
# (7332, 20)
# Likely-pathogenic    4818
# Pathogenic           2514
# Name: class, dtype: int64
# 7328
# 1599
# 1603

# %%
# saving variants and combined fasta file
from utils.ncbi_proteins import create_combined_fasta
filename = "patho_and_likelypatho"
out_filepath = home_dir+f"data/datasets_patho/{filename}"

print("\nLog: saving variants ...")
filtered_variants_df.to_csv(out_filepath+".tsv", index=False, sep="\t", header=True)


print("\nLog: Creating merged fasta document ...")
protein_acc_list = list(filtered_variants_df["prot_acc_version"].unique())
create_combined_fasta(protein_acc_list, out_filepath+".fasta", home_dir)
# Out:
# Log: saving variants ...
#
# Log: Creating merged fasta document ...
# 0 NP_001381642.1 Already existis
# 1 NP_542172.2 Already existis
# 2 NP_060341.2 Already existis
# 3 NP_001164006.1 Already existis
# 4 NP_002065.1 Already existis
# 5 NP_000806.2 Already existis
# 6 NP_003027.1 Already existis
# 7 NP_002608.1 Already existis
# 8 NP_009193.2 Already existis
# 9 NP_004276.2 Already existis
# 10 NP_005948.3 Already existis
# 11 NP_055689.1 Already existis
# 12 NP_000076.2 Already existis
# 13 NP_002991.2 Already existis
# 14 NP_000469.3 Already existis
# 15 NP_001782.1 Already existis
# 16 NP_005817.1 Already existis
# 17 NP_000138.2 Already existis
# 18 NP_065184.2 Already existis
# 19 NP_060116.2 Already existis
# 20 NP_116182.2 Already existis
# 21 NP_000301.1 Already existis
# 22 NP_683763.2 Already existis
# 23 NP_006507.2 Already existis
# 24 NP_005364.1 Already existis
# 25 NP_001246.2 Already existis
# 26 NP_060620.2 Already existis
# 27 NP_000365.3 Already existis
# 28 NP_116145.1 Already existis
# 29 NP_001041639.1 Already existis
# 30 NP_060209.4 Already existis
# 31 NP_000089.1 Already existis
# 32 NP_000783.2 Already existis
# 33 NP_777596.2 Already existis
# 34 NP_002624.2 Already existis
# 35 NP_000320.1 Already existis
# 36 NP_000007.1 Already existis
# 37 NP_008965.2 Already existis
# 38 NP_891993.1 Already existis
# 39 NP_000960.2 Already existis
# 40 NP_036375.1 Already existis
# 41 NP_001909.4 Already existis
# 42 NP_057042.2 Already existis
# 43 NP_006504.2 Already existis
# 44 NP_001010898.1 Already existis
# 45 NP_004965.1 Already existis
# 46 NP_073747.1 Already existis
# 47 NP_000189.1 Already existis
# 48 NP_006614.2 Already existis
# 49 NP_003837.1 Already existis
# 50 NP_005258.2 Already existis
# 51 NP_079426.2 Already existis
# 52 NP_000387.1 Already existis
# 53 NP_067045.1 Already existis
# 54 NP_076946.1 Already existis
# 55 NP_001356552.1 Already existis
# 56 NP_689476.2 Already existis
# 57 NP_000739.1 Already existis
# 58 NP_000148.2 Already existis
# 59 NP_000289.1 Already existis
# 60 NP_008843.1 Already existis
# 61 NP_733821.1 Already existis
# 62 NP_658985.2 Already existis
# 63 NP_002520.2 Already existis
# 64 NP_000693.1 Already existis
# 65 NP_002848.1 Already existis
# 66 NP_001116236.1 Already existis
# 67 NP_000521.2 Already existis
# 68 NP_002992.1 Already existis
# 69 NP_796372.1 Already existis
# 70 NP_061899.3 Already existis
# 71 NP_000252.1 Already existis
# 72 NP_060592.2 Already existis
# 73 NP_000479.1 Already existis
# 74 NP_055440.1 Already existis
# 75 NP_001985.2 Already existis
# 76 NP_001263274.1 Already existis
# 77 NP_057083.2 Already existis
# 78 NP_002247.3 Already existis
# 79 NP_006138.1 Already existis
# 80 NP_758872.1 Already existis
# 81 NP_054772.1 Already existis
# 82 NP_055991.1 Already existis
# 83 NP_002287.2 Already existis
# 84 NP_055513.2 Already existis
# 85 NP_002098.1 Already existis
# 86 NP_002212.3 Already existis
# 87 NP_001649.1 Already existis
# 88 NP_065168.2 Already existis
# 89 NP_001091.1 Already existis
# 90 NP_000134.2 Already existis
# 91 NP_005456.1 Already existis
# 92 NP_932342.1 Already existis
# 93 NP_114032.2 Already existis
# 94 NP_001071178.2 Already existis
# 95 NP_003099.1 Already existis
# 96 NP_057291.1 Already existis
# 97 NP_005369.2 Already existis
# 98 NP_072046.2 Already existis
# 99 NP_000174.1 Already existis
# 100 NP_002237.1 Already existis
# 101 NP_006479.1 Already existis
# 102 NP_000339.2 Already existis
# 103 NP_055761.2 Already existis
# 104 NP_001129123.1 Already existis
# 105 NP_000095.2 Already existis
# 106 NP_008818.3 Already existis
# 107 NP_000332.2 Already existis
# 108 NP_001421.2 Already existis
# 109 NP_065191.2 Already existis
# 110 NP_001734.1 Already existis
# 111 NP_002345.2 Already existis
# 112 NP_000242.1 Already existis
# 113 NP_000224.2 Already existis
# 114 NP_149100.2 Already existis
# 115 NP_075044.2 Already existis
# 116 NP_003029.2 Already existis
# 117 NP_001606.1 Already existis
# 118 NP_550438.1 Already existis
# 119 NP_003840.2 Already existis
# 120 NP_000812.2 Already existis
# 121 NP_000533.4 Already existis
# 122 NP_001358208.1 Already existis
# 123 NP_060319.1 Already existis
# 124 NP_110432.1 Already existis
# 125 NP_064569.3 Already existis
# 126 NP_001289.1 Already existis
# 127 NP_006227.1 Already existis
# 128 NP_071731.1 Already existis
# 129 NP_000303.1 Already existis
# 130 NP_525125.2 Already existis
# 131 NP_112185.1 Already existis
# 132 NP_003928.1 Already existis
# 133 NP_004513.1 Already existis
# 134 NP_006177.1 Already existis
# 135 NP_006584.1 Already existis
# 136 NP_004473.2 Already existis
# 137 NP_689597.1 Already existis
# 138 NP_003696.2 Already existis
# 139 NP_001680.1 Already existis
# 140 NP_003681.1 Already existis
# 141 NP_001036167.1 Already existis
# 142 NP_963842.1 Already existis
# 143 NP_009330.1 Already existis
# 144 NP_001165980.1 Already existis
# 145 NP_054859.2 Already existis
# 146 NP_005435.1 Already existis
# 147 NP_001073335.1 Already existis
# 148 NP_000775.1 Already existis
# 149 NP_079492.2 Already existis
# 150 NP_002172.2 Already existis
# 151 NP_001918.3 Already existis
# 152 NP_037467.2 Already existis
# 153 NP_852123.1 Already existis
# 154 NP_005678.3 Already existis
# 155 NP_849143.1 Already existis
# 156 NP_004817.2 Already existis
# 157 NP_000742.1 Already existis
# 158 NP_000454.1 Already existis
# 159 NP_000021.1 Already existis
# 160 NP_036277.2 Already existis
# 161 NP_689996.4 Already existis
# 162 NP_000542.1 Already existis
# 163 NP_003033.3 Already existis
# 164 NP_001336161.1 Already existis
# 165 NP_001271330.1 Already existis
# 166 NP_619725.3 Already existis
# 167 NP_079541.1 Already existis
# 168 NP_005668.2 Already existis
# 169 NP_001357587.1 Already existis
# 170 NP_002962.1 Already existis
# 171 NP_002939.2 Already existis
# 172 NP_001341641.1 Already existis
# 173 NP_000956.2 Already existis
# 174 NP_060767.2 Already existis
# 175 NP_003233.4 Already existis
# 176 NP_000395.3 Already existis
# 177 NP_006362.1 Already existis
# 178 NP_000240.1 Already existis
# 179 NP_660149.2 Already existis
# 180 NP_116195.2 Already existis
# 181 NP_060545.3 Already existis
# 182 NP_003269.2 Already existis
# 183 NP_056155.1 Already existis
# 184 NP_000378.1 Already existis
# 185 NP_005042.1 Already existis
# 186 NP_000472.2 Already existis
# 187 NP_006832.1 Already existis
# 188 NP_056980.2 Already existis
# 189 NP_056241.3 Already existis
# 190 NP_004647.1 Already existis
# 191 NP_003271.1 Already existis
# 192 NP_000916.2 Already existis
# 193 NP_060600.2 Already existis
# 194 NP_000149.4 Already existis
# 195 NP_000304.2 Already existis
# 196 NP_001167621.1 Already existis
# 197 NP_001265222.1 Already existis
# 198 NP_006061.2 Already existis
# 199 NP_733762.2 Already existis
# 200 NP_001681.2 Already existis
# 201 NP_001335729.1 Already existis
# 202 NP_000178.2 Already existis
# 203 NP_037468.1 Already existis
# 204 NP_054768.2 Already existis
# 205 NP_000165.1 Already existis
# 206 NP_000530.1 Already existis
# 207 NP_001365616.1 Already existis
# 208 NP_079094.1 Already existis
# 209 NP_000523.2 Already existis
# 210 NP_004757.1 Already existis
# 211 NP_000676.1 Already existis
# 212 NP_777367.1 Already existis
# 213 NP_001258767.1 Already existis
# 214 NP_001116224.1 Already existis
# 215 NP_000331.1 Already existis
# 216 NP_078941.2 Already existis
# 217 NP_852091.1 Already existis
# 218 NP_003097.1 Already existis
# 219 NP_064551.3 Already existis
# 220 NP_060114.2 Already existis
# 221 NP_003898.2 Already existis
# 222 NP_000451.1 Already existis
# 223 NP_004445.1 Already existis
# 224 NP_001613.2 Already existis
# 225 NP_003713.3 Already existis
# 226 NP_570850.2 Already existis
# 227 NP_940967.1 Already existis
# 228 NP_002568.2 Already existis
# 229 NP_001120650.1 Already existis
# 230 NP_071325.2 Already existis
# 231 NP_000194.2 Already existis
# 232 NP_000133.1 Already existis
# 233 NP_036450.1 Already existis
# 234 NP_775931.3 Already existis
# 235 NP_005996.2 Already existis
# 236 NP_000311.2 Already existis
# 237 NP_003915.2 Already existis
# 238 NP_001073945.1 Already existis
# 239 NP_000798.2 Already existis
# 240 NP_001366199.1 Already existis
# 241 NP_000223.1 Already existis
# 242 NP_001072992.1 Already existis
# 243 NP_001544.1 Already existis
# 244 NP_000397.1 Already existis
# 245 NP_059122.2 Already existis
# 246 NP_004398.1 Already existis
# 247 NP_001501.2 Already existis
# 248 NP_001194.1 Already existis
# 249 NP_000935.1 Already existis
# 250 NP_001128618.1 Already existis
# 251 NP_003989.2 Already existis
# 252 NP_000195.3 Already existis
# 253 NP_000316.2 Already existis
# 254 NP_001308500.1 Already existis
# 255 NP_005024.2 Already existis
# 256 NP_789794.1 Already existis
# 257 NP_001124170.1 Already existis
# 258 NP_001358525.1 Already existis
# 259 NP_758454.1 Already existis
# 260 NP_612373.2 Already existis
# 261 NP_001336727.1 Already existis
# 262 NP_000815.1 Already existis
# 263 NP_001077088.2 Already existis
# 264 NP_004444.2 Already existis
# 265 NP_006736.1 Already existis
# 266 NP_004468.1 Already existis
# 267 NP_004159.2 Already existis
# 268 NP_001003841.1 Already existis
# 269 NP_004544.1 Already existis
# 270 NP_060225.4 Already existis
# 271 NP_612357.4 Already existis
# 272 NP_006718.2 Already existis
# 273 NP_057264.4 Already existis
# 274 NP_002176.2 Already existis
# 275 NP_001007528.1 Already existis
# 276 NP_066550.2 Already existis
# 277 NP_789776.1 Already existis
# 278 NP_001177716.1 Already existis
# 279 NP_002175.2 Already existis
# 280 NP_001098101.1 Already existis
# 281 NP_000073.1 Already existis
# 282 NP_000335.1 Already existis
# 283 NP_071415.1 Already existis
# 284 NP_000512.2 Already existis
# 285 NP_000850.1 Already existis
# 286 NP_000037.2 Already existis
# 287 NP_002388.2 Already existis
# 288 NP_005645.1 Already existis
# 289 NP_937793.1 Already existis
# 290 NP_000430.3 Already existis
# 291 NP_620128.1 Already existis
# 292 NP_067627.3 Already existis
# 293 NP_000405.1 Already existis
# 294 NP_001173.2 Already existis
# 295 NP_001017372.1 Already existis
# 296 NP_001244237.1 Already existis
# 297 NP_003051.1 Already existis
# 298 NP_078991.3 Already existis
# 299 NP_000349.1 Already existis
# 300 NP_938023.1 Already existis
# 301 NP_005850.1 Already existis
# 302 NP_061751.1 Already existis
# 303 NP_000103.2 Already existis
# 304 NP_001275634.1 Already existis
# 305 NP_057065.2 Already existis
# 306 NP_001534.1 Already existis
# 307 NP_000162.2 Already existis
# 308 NP_001358656.1 Already existis
# 309 NP_001121116.1 Already existis
# 310 NP_944494.1 Already existis
# 311 NP_004378.1 Already existis
# 312 NP_057306.2 Already existis
# 313 NP_000834.2 Already existis
# 314 NP_001244222.1 Already existis
# 315 NP_003891.1 Already existis
# 316 NP_001444.2 Already existis
# 317 NP_001060.1 Already existis
# 318 NP_821080.1 Already existis
# 319 NP_112210.1 Already existis
# 320 NP_003098.1 Already existis
# 321 NP_001071.1 Already existis
# 322 NP_000401.1 Already existis
# 323 NP_003533.1 Already existis
# 324 NP_003536.1 Already existis
# 325 NP_003486.1 Already existis
# 326 NP_068803.1 Already existis
# 327 NP_001311.3 Already existis
# 328 NP_751898.1 Already existis
# 329 NP_000425.1 Already existis
# 330 NP_000491.4 Already existis
# 331 NP_002115.2 Already existis
# 332 NP_008910.2 Already existis
# 333 NP_115716.1 Already existis
# 334 NP_003313.3 Already existis
# 335 NP_443193.1 Already existis
# 336 NP_001345459.1 Already existis
# 337 NP_001012426.1 Already existis
# 338 NP_001371839.1 Already existis
# 339 NP_000313.2 Already existis
# 340 NP_000278.3 Already existis
# 341 NP_006236.1 Already existis
# 342 NP_689945.2 Already existis
# 343 NP_065796.2 Already existis
# 344 NP_001019801.3 Already existis
# 345 NP_000246.2 Already existis
# 346 NP_062816.2 Already existis
# 347 NP_036566.1 Already existis
# 348 NP_001116241.1 Already existis
# 349 NP_898871.1 Already existis
# 350 NP_006407.1 Already existis
# 351 NP_064716.2 Already existis
# 352 NP_067067.1 Already existis
# 353 NP_663304.1 Already existis
# 354 NP_065822.2 Already existis
# 355 NP_001186492.1 Already existis
# 356 NP_116119.2 Already existis
# 357 NP_055660.1 Already existis
# 358 NP_937882.2 Already existis
# 359 NP_000484.2 Already existis
# 360 NP_001035940.1 Already existis
# 361 NP_000156.1 Already existis
# 362 NP_006064.2 Already existis
# 363 NP_000036.2 Already existis
# 364 NP_006199.2 Already existis
# 365 NP_004091.3 Already existis
# 366 NP_055554.1 Already existis
# 367 NP_005661.1 Already existis
# 368 NP_116250.3 Already existis
# 369 NP_001258791.1 Already existis
# 370 NP_002784.1 Already existis
# 371 NP_064608.2 Already existis
# 372 NP_001092.1 Already existis
# 373 NP_996994.1 Already existis
# 374 NP_000526.2 Already existis
# 375 NP_008839.2 Already existis
# 376 NP_006399.1 Already existis
# 377 NP_000465.1 Already existis
# 378 NP_001026880.2 Already existis
# 379 NP_002038.2 Already existis
# 380 NP_940820.1 Already existis
# 381 NP_005393.2 Already existis
# 382 NP_000153.1 Already existis
# 383 NP_000587.1 Already existis
# 384 NP_001076440.2 Already existis
# 385 NP_000172.2 Already existis
# 386 NP_000039.2 Already existis
# 387 NP_694578.1 Already existis
# 388 NP_036611.2 Already existis
# 389 NP_002060.4 Already existis
# 390 NP_001311347.1 Already existis
# 391 NP_919436.1 Already existis
# 392 NP_003910.1 Already existis
# 393 NP_055066.1 Already existis
# 394 NP_001664.3 Already existis
# 395 NP_001139187.1 Already existis
# 396 NP_057272.1 Already existis
# 397 NP_004435.3 Already existis
# 398 NP_000432.1 Already existis
# 399 NP_000102.1 Already existis
# 400 NP_000099.2 Already existis
# 401 NP_001159817.1 Already existis
# 402 NP_036413.1 Already existis
# 403 NP_056265.2 Already existis
# 404 NP_000874.2 Already existis
# 405 NP_065683.2 Already existis
# 406 NP_004324.2 Already existis
# 407 NP_002760.1 Already existis
# 408 NP_000074.3 Already existis
# 409 NP_071890.2 Already existis
# 410 NP_004447.2 Already existis
# 411 NP_060854.2 Already existis
# 412 NP_005605.1 Already existis
# 413 NP_057287.2 Already existis
# 414 NP_570629.2 Already existis
# 415 NP_005506.3 Already existis
# 416 NP_490647.1 Already existis
# 417 NP_001295022.1 Already existis
# 418 NP_000228.1 Already existis
# 419 NP_001684.2 Already existis
# 420 NP_001381061.1 Already existis
# 421 NP_644807.1 Already existis
# 422 NP_001304707.1 Already existis
# 423 NP_006120.1 Already existis
# 424 NP_001121903.1 Already existis
# 425 NP_001076580.1 Already existis
# 426 NP_000628.2 Already existis
# 427 NP_001095871.1 Already existis
# 428 NP_075598.2 Already existis
# 429 NP_001244109.1 Already existis
# 430 NP_060575.1 Already existis
# 431 NP_689632.2 Already existis
# 432 NP_002341.1 Already existis
# 433 NP_005363.1 Already existis
# 434 NP_061845.2 Already existis
# 435 NP_061971.3 Already existis
# 436 NP_714915.3 Already existis
# 437 NP_002559.2 Already existis
# 438 NP_848660.3 Already existis
# 439 NP_006256.1 Already existis
# 440 NP_000118.2 Already existis
# 441 NP_004510.1 Already existis
# 442 NP_036604.2 Already existis
# 443 NP_000488.3 Already existis
# 444 NP_000489.3 Already existis
# 445 NP_835466.2 Already existis
# 446 NP_003792.1 Already existis
# 447 NP_036211.2 Already existis
# 448 NP_598004.1 Already existis
# 449 NP_000161.2 Already existis
# 450 NP_000068.1 Already existis
# 451 NP_478102.2 Already existis
# 452 NP_001488.2 Already existis
# 453 NP_001161.1 Already existis
# 454 NP_000146.2 Already existis
# 455 NP_001136256.1 Already existis
# 456 NP_009057.1 Already existis
# 457 NP_005467.1 Already existis
# 458 NP_036335.1 Already existis
# 459 NP_619636.2 Already existis
# 460 NP_002063.2 Already existis
# 461 NP_112553.1 Already existis
# 462 NP_001003800.1 Already existis
# 463 NP_003828.2 Already existis
# 464 NP_000498.2 Already existis
# 465 NP_004603.1 Already existis
# 466 NP_149078.1 Already existis
# 467 NP_000026.2 Already existis
# 468 NP_001850.1 Already existis
# 469 NP_937895.1 Already existis
# 470 NP_004950.2 Already existis
# 471 NP_001167618.1 Already existis
# 472 NP_001027392.1 Already existis
# 473 NP_001108225.1 Already existis
# 474 NP_004399.2 Already existis
# 475 NP_057119.3 Already existis
# 476 NP_000104.1 Already existis
# 477 NP_446464.1 Already existis
# 478 NP_067632.2 Already existis
# 479 NP_001070833.1 Already existis
# 480 NP_001364233.1 Already existis
# 481 NP_003163.1 Already existis
# 482 NP_063945.2 Already existis
# 483 NP_006403.2 Already existis
# 484 NP_015566.1 Already existis
# 485 NP_001170787.2 Already existis
# 486 NP_001357029.1 Already existis
# 487 NP_001002295.1 Already existis
# 488 NP_001313271.1 Already existis
# 489 NP_001029027.1 Already existis
# 490 NP_055132.2 Already existis
# 491 NP_004512.1 Already existis
# 492 NP_065574.4 Already existis
# 493 NP_060715.2 Already existis
# 494 NP_000390.2 Already existis
# 495 NP_000179.2 Already existis
# 496 NP_001076585.1 Already existis
# 497 NP_002769.1 Already existis
# 498 NP_148982.1 Already existis
# 499 NP_000420.1 Already existis
# 500 NP_149091.1 Already existis
# 501 NP_060021.1 Already existis
# 502 NP_001015880.1 Already existis
# 503 NP_000305.3 Already existis
# 504 NP_000034.1 Already existis
# 505 NP_000226.2 Already existis
# 506 NP_006195.3 Already existis
# 507 NP_002851.2 Already existis
# 508 NP_056446.4 Already existis
# 509 NP_612422.2 Already existis
# 510 NP_000186.2 Already existis
# 511 NP_060764.3 Already existis
# 512 NP_068602.2 Already existis
# 513 NP_000093.1 Already existis
# 514 NP_001338098.1 Already existis
# 515 NP_976313.1 Already existis
# 516 NP_862823.1 Already existis
# 517 NP_006784.1 Already existis
# 518 NP_000132.3 Already existis
# 519 NP_002766.1 Already existis
# 520 NP_001359052.1 Already existis
# 521 NP_000265.1 Already existis
# 522 NP_073713.2 Already existis
# 523 NP_000366.1 Already existis
# 524 NP_001362309.1 Already existis
# 525 NP_796374.2 Already existis
# 526 NP_004083.3 Already existis
# 527 NP_066288.2 Already existis
# 528 NP_665893.2 Already existis
# 529 NP_000603.1 Already existis
# 530 NP_000198.1 Already existis
# 531 NP_000351.2 Already existis
# 532 NP_000209.2 Already existis
# 533 NP_000534.3 Already existis
# 534 NP_000382.3 Already existis
# 535 NP_036382.2 Already existis
# 536 NP_001137533.1 Already existis
# 537 NP_000516.3 Already existis
# 538 NP_001106212.1 Already existis
# 539 NP_004202.4 Already existis
# 540 NP_073562.1 Already existis
# 541 NP_113606.2 Already existis
# 542 NP_001355823.1 Already existis
# 543 NP_077744.4 Already existis
# 544 NP_000527.2 Already existis
# 545 NP_068745.2 Already existis
# 546 NP_002795.2 Already existis
# 547 NP_005046.2 Already existis
# 548 NP_000053.2 Already existis
# 549 NP_945185.1 Already existis
# 550 NP_001034485.1 Already existis
# 551 NP_004174.1 Already existis
# 552 NP_036332.2 Already existis
# 553 NP_938148.1 Already existis
# 554 NP_201567.1 Already existis
# 555 NP_653186.2 Already existis
# 556 NP_001092141.1 Already existis
# 557 NP_005600.1 Already existis
# 558 NP_001357188.2 Already existis
# 559 NP_058634.4 Already existis
# 560 NP_006833.2 Already existis
# 561 NP_060496.2 Already existis
# 562 NP_078925.3 Already existis
# 563 NP_009034.2 Already existis
# 564 NP_001867.2 Already existis
# 565 NP_002171.2 Already existis
# 566 NP_001351.2 Already existis
# 567 NP_057941.1 Already existis
# 568 NP_001245321.1 Already existis
# 569 NP_076984.2 Already existis
# 570 NP_003788.2 Already existis
# 571 NP_036325.2 Already existis
# 572 NP_001805.4 Already existis
# 573 NP_000363.1 Already existis
# 574 NP_004612.2 Already existis
# 575 NP_001123617.1 Already existis
# 576 NP_000820.4 Already existis
# 577 NP_000010.1 Already existis
# 578 NP_079016.2 Already existis
# 579 NP_002993.1 Already existis
# 580 NP_000308.1 Already existis
# 581 NP_000030.1 Already existis
# 582 NP_001549.2 Already existis
# 583 NP_000181.2 Already existis
# 584 NP_001373.2 Already existis
# 585 NP_005179.2 Already existis
# 586 NP_001265360.1 Already existis
# 587 NP_079045.1 Already existis
# 588 NP_689926.1 Already existis
# 589 NP_001128265.1 Already existis
# 590 NP_722450.1 Already existis
# 591 NP_068813.1 Already existis
# 592 NP_055199.1 Already existis
# 593 NP_003315.2 Already existis
# 594 NP_001265238.2 Already existis
# 595 NP_000208.2 Already existis
# 596 NP_055046.1 Already existis
# 597 NP_079130.2 Already existis
# 598 NP_008871.3 Already existis
# 599 NP_004976.2 Already existis
# 600 NP_036192.2 Already existis
# 601 NP_001005242.2 Already existis
# 602 NP_000367.1 Already existis
# 603 NP_001650.1 Already existis
# 604 NP_005421.1 Already existis
# 605 NP_066382.1 Already existis
# 606 NP_006000.2 Already existis
# 607 NP_000477.1 Already existis
# 608 NP_001306928.1 Already existis
# 609 NP_000011.2 Already existis
# 610 NP_000415.2 Already existis
# 611 NP_006112.3 Already existis
# 612 NP_056480.1 Already existis
# 613 NP_065434.1 Already existis
# 614 NP_001020.2 Already existis
# 615 NP_005410.1 Already existis
# 616 NP_001677.2 Already existis
# 617 NP_000776.1 Already existis
# 618 NP_776173.3 Already existis
# 619 NP_055069.1 Already existis
# 620 NP_037386.1 Already existis
# 621 NP_631875.1 Already existis
# 622 NP_005630.1 Already existis
# 623 NP_000890.1 Already existis
# 624 NP_758440.1 Already existis
# 625 NP_000268.1 Already existis
# 626 NP_067638.3 Already existis
# 627 NP_005466.1 Already existis
# 628 NP_003659.2 Already existis
# 629 NP_058132.2 Already existis
# 630 NP_852259.1 Already existis
# 631 NP_000536.6 Already existis
# 632 NP_068773.2 Already existis
# 633 NP_003995.2 Already existis
# 634 NP_001103689.1 Already existis
# 635 NP_002001.1 Already existis
# 636 NP_000222.2 Already existis
# 637 NP_037470.1 Already existis
# 638 NP_003841.1 Already existis
# 639 NP_000312.2 Already existis
# 640 NP_001155970.1 Already existis
# 641 NP_002258.2 Already existis
# 642 NP_005699.1 Already existis
# 643 NP_000273.2 Already existis
# 644 NP_001229811.1 Already existis
# 645 NP_000495.1 Already existis
# 646 NP_003973.3 Already existis
# 647 NP_001341569.1 Already existis
# 648 NP_001341697.1 Already existis
# 649 NP_000350.1 Already existis
# 650 NP_005240.3 Already existis
# 651 NP_004077.1 Already existis
# 652 NP_619579.1 Already existis
# 653 NP_060387.2 Already existis
# 654 NP_055487.2 Already existis
# 655 NP_001073136.1 Already existis
# 656 NP_001359005.1 Already existis
# 657 NP_079160.1 Already existis
# 658 NP_056999.2 Already existis
# 659 NP_000152.1 Already existis
# 660 NP_001072988.1 Already existis
# 661 NP_065861.3 Already existis
# 662 NP_065857.1 Already existis
# 663 NP_689656.2 Already existis
# 664 NP_001123476.1 Already existis
# 665 NP_000012.1 Already existis
# 666 NP_878314.1 Already existis
# 667 NP_005041.1 Already existis
# 668 NP_006423.1 Already existis
# 669 NP_001096034.1 Already existis
# 670 NP_000360.2 Already existis
# 671 NP_000144.2 Already existis
# 672 NP_060888.2 Already existis
# 673 NP_002793.2 Already existis
# 674 NP_008819.1 Already existis
# 675 NP_006320.2 Already existis
# 676 NP_057501.2 Already existis
# 677 NP_003394.1 Already existis
# 678 NP_004175.2 Already existis
# 679 NP_000805.1 Already existis
# 680 NP_000801.1 Already existis
# 681 NP_000266.2 Already existis
# 682 NP_002216.3 Already existis
# 683 NP_061947.1 Already existis
# 684 NP_000061.1 Already existis
# 685 NP_116281.2 Already existis
# 686 NP_995322.1 Already existis
# 687 NP_001020419.1 Already existis
# 688 NP_000094.2 Already existis
# 689 NP_861454.2 Already existis
# 690 NP_057278.2 Already existis
# 691 NP_899058.1 Already existis
# 692 NP_996920.1 Already existis
# 693 NP_003879.2 Already existis
# 694 NP_001094832.1 Already existis
# 695 NP_002746.1 Already existis
# 696 NP_005576.3 Already existis
# 697 NP_001354734.1 Already existis
# 698 NP_079093.2 Already existis
# 699 NP_055064.1 Already existis
# 700 NP_000511.2 Already existis
# 701 NP_149017.2 Already existis
# 702 NP_003603.1 Already existis
# 703 NP_116197.4 Already existis
# 704 NP_000128.1 Already existis
# 705 NP_001012.1 Already existis
# 706 NP_000317.1 Already existis
# 707 NP_001365718.1 Already existis
# 708 NP_000508.1 Already existis
# 709 NP_000549.1 Already existis
# 710 NP_001278.1 Already existis
# 711 NP_057195.2 Already existis
# 712 NP_001685.1 Already existis
# 713 NP_061982.3 Already existis
# 714 NP_000294.1 Already existis
# 715 NP_003352.2 Already existis
# 716 NP_060206.2 Already existis
# 717 NP_000327.2 Already existis
# 718 NP_705831.1 Already existis
# 719 NP_004311.1 Already existis
# 720 NP_115564.2 Already existis
# 721 NP_004951.1 Already existis
# 722 NP_001098717.1 Already existis
# 723 NP_891552.1 Already existis
# 724 NP_001357395.1 Already existis
# 725 NP_005844.4 Already existis
# 726 NP_004521.1 Already existis
# 727 NP_066268.1 Already existis
# 728 NP_001119580.2 Already existis
# 729 NP_588609.1 Already existis
# 730 NP_001788.2 Already existis
# 731 NP_004605.4 Already existis
# 732 NP_003896.1 Already existis
# 733 NP_003780.1 Already existis
# 734 NP_001361604.1 Already existis
# 735 NP_004585.1 Already existis
# 736 NP_000220.1 Already existis
# 737 NP_004351.1 Already existis
# 738 NP_001596.2 Already existis
# 739 NP_077282.3 Already existis
# 740 NP_001070886.1 Already existis
# 741 NP_005539.1 Already existis
# 742 NP_057457.1 Already existis
# 743 NP_005351.2 Already existis
# 744 NP_004474.2 Already existis
# 745 NP_071324.1 Already existis
# 746 NP_001442.2 Already existis
# 747 NP_079011.3 Already existis
# 748 NP_000503.1 Already existis
# 749 NP_001230208.1 Already existis
# 750 NP_003110.1 Already existis
# 751 NP_006077.2 Already existis
# 752 NP_057616.2 Already existis
# 753 NP_002936.1 Already existis
# 754 NP_000421.1 Already existis
# 755 NP_000040.1 Already existis
# 756 NP_659505.1 Already existis
# 757 NP_004928.2 Already existis
# 758 NP_000071.1 Already existis
# 759 NP_000164.5 Already existis
# 760 NP_055151.3 Already existis
# 761 NP_001308004.1 Already existis
# 762 NP_000009.1 Already existis
# 763 NP_000537.3 Already existis
# 764 NP_000295.1 Already existis
# 765 NP_000373.1 Already existis
# 766 NP_659731.1 Already existis
# 767 NP_644814.1 Already existis
# 768 NP_001333683.1 Already existis
# 769 NP_000449.1 Already existis
# 770 NP_006151.3 Already existis
# 771 NP_000412.4 Already existis
# 772 NP_644805.1 Already existis
# 773 NP_001123493.1 Already existis
# 774 NP_000254.2 Already existis
# 775 NP_079509.5 Already existis
# 776 NP_000142.2 Already existis
# 777 NP_000333.1 Already existis
# 778 NP_002078.1 Already existis
# 779 NP_004238.3 Already existis
# 780 NP_002046.1 Already existis
# 781 NP_001247.3 Already existis
# 782 NP_000203.2 Already existis
# 783 NP_005211.1 Already existis
# 784 NP_000014.1 Already existis
# 785 NP_004366.1 Already existis
# 786 NP_008855.1 Already existis
# 787 NP_001308049.1 Already existis
# 788 NP_002392.2 Already existis
# 789 NP_002725.1 Already existis
# 790 NP_000337.1 Already existis
# 791 NP_694941.2 Already existis
# 792 NP_077728.3 Already existis
# 793 NP_001119593.1 Already existis
# 794 NP_005315.1 Already existis
# 795 NP_001182356.1 Already existis
# 796 NP_000143.2 Already existis
# 797 NP_000190.1 Already existis
# 798 NP_002513.2 Already existis
# 799 NP_001079990.1 Already existis
# 800 NP_001605.1 Already existis
# 801 NP_892023.1 Already existis
# 802 NP_006787.2 Already existis
# 803 NP_000362.1 Already existis
# 804 NP_060725.1 Already existis
# 805 NP_005892.1 Already existis
# 806 NP_001077431.1 Already existis
# 807 NP_000131.2 Already existis
# 808 NP_038463.2 Already existis
# 809 NP_001185.3 Already existis
# 810 NP_001963.1 Already existis
# 811 NP_004359.1 Already existis
# 812 NP_000446.1 Already existis
# 813 NP_000147.1 Already existis
# 814 NP_000470.3 Already existis
# 815 NP_001137458.1 Already existis
# 816 NP_002058.2 Already existis
# 817 NP_001138637.1 Already existis
# 818 NP_057347.2 Already existis
# 819 NP_149053.1 Already existis
# 820 NP_056982.1 Already existis
# 821 NP_631898.3 Already existis
# 822 NP_006078.2 Already existis
# 823 NP_001164626.1 Already existis
# 824 NP_008880.2 Already existis
# 825 NP_987096.1 Already existis
# 826 NP_000518.1 Already existis
# 827 NP_001602.1 Already existis
# 828 NP_004308.2 Already existis
# 829 NP_006388.2 Already existis
# 830 NP_001366.1 Already existis
# 831 NP_000150.1 Already existis
# 832 NP_004452.1 Already existis
# 833 NP_001352831.1 Already existis
# 834 NP_612510.1 Already existis
# 835 NP_116009.2 Already existis
# 836 NP_005526.1 Already existis
# 837 NP_005018.2 Already existis
# 838 NP_000086.2 Already existis
# 839 NP_067090.1 Already existis
# 840 NP_055085.1 Already existis
# 841 NP_004355.2 Already existis
# 842 NP_000166.2 Already existis
# 843 NP_116024.1 Already existis
# 844 NP_066925.1 Already existis
# 845 NP_004915.2 Already existis
# 846 NP_000651.3 Already existis
# 847 NP_000700.1 Already existis
# 848 NP_001013.1 Already existis
# 849 NP_689509.1 Already existis
# 850 NP_597701.1 Already existis
# 851 NP_055112.2 Already existis
# 852 NP_061981.2 Already existis
# 853 NP_000032.1 Already existis
# 854 NP_001369351.1 Already existis
# 855 NP_000391.1 Already existis
# 856 NP_005175.2 Already existis
# 857 NP_077277.1 Already existis
# 858 NP_000225.1 Already existis
# 859 NP_004908.4 Already existis
# 860 NP_001976.1 Already existis
# 861 NP_002730.1 Already existis
# 862 NP_056444.3 Already existis
# 863 NP_077274.3 Already existis
# 864 NP_003274.3 Already existis
# 865 NP_000354.4 Already existis
# 866 NP_808227.1 Already existis
# 867 NP_212134.3 Already existis
# 868 NP_000481.2 Already existis
# 869 NP_001167560.1 Already existis
# 870 NP_001373322.1 Already existis
# 871 NP_061968.1 Already existis
# 872 NP_001191.1 Already existis
# 873 NP_570824.1 Already existis
# 874 NP_057184.1 Already existis
# 875 NP_008823.1 Already existis
# 876 NP_110517.2 Already existis
# 877 NP_005452.2 Already existis
# 878 NP_787110.2 Already existis
# 879 NP_000013.2 Already existis
# 880 NP_000299.3 Already existis
# 881 NP_110404.1 Already existis
# 882 NP_004966.1 Already existis
# 883 NP_000773.2 Already existis
# 884 NP_001710.1 Already existis
# 885 NP_002582.3 Already existis
# 886 NP_000507.1 Already existis
# 887 NP_110400.1 Already existis
# 888 NP_742105.1 Already existis
# 889 NP_001949.1 Already existis
# 890 NP_079495.1 Already existis
# 891 NP_000475.1 Already existis
# 892 NP_000445.1 Already existis
# 893 NP_060083.1 Already existis
# 894 NP_001745.2 Already existis
# 895 NP_001339443.1 Already existis
# 896 NP_001334650.1 Already existis
# 897 NP_001243246.1 Already existis
# 898 NP_543136.1 Already existis
# 899 NP_000374.1 Already existis
# 900 NP_004919.1 Already existis
# 901 NP_659428.2 Already existis
# 902 NP_000202.3 Already existis
# 903 NP_001103.1 Already existis
# 904 NP_001840.3 Already existis
# 905 NP_002331.3 Already existis
# 906 NP_001269154.1 Already existis
# 907 NP_061816.1 Already existis
# 908 NP_005975.1 Already existis
# 909 NP_000398.1 Already existis
# 910 NP_006758.2 Already existis
# 911 NP_057411.1 Already existis
# 912 NP_004067.1 Already existis
# 913 NP_000487.1 Already existis
# 914 NP_001118.3 Already existis
# 915 NP_000259.1 Already existis
# 916 NP_000334.1 Already existis
# 917 NP_000353.1 Already existis
# 918 NP_006069.1 Already existis
# 919 NP_008872.1 Already existis
# 920 NP_003551.2 Already existis
# 921 NP_000017.1 Already existis
# 922 NP_001089.1 Already existis
# 923 NP_060476.2 Already existis
# 924 NP_055981.1 Already existis
# 925 NP_005129.2 Already existis
# 926 NP_001944.1 Already existis
# 927 NP_000478.3 Already existis
# 928 NP_000442.1 Already existis
# 929 NP_000038.2 Already existis
# 930 NP_000207.2 Already existis
# 931 NP_000264.2 Already existis
# 932 NP_005324.3 Already existis
# 933 NP_001133.1 Already existis
# 934 NP_002054.1 Already existis
# 935 NP_002632.1 Already existis
# 936 NP_001310218.1 Already existis
# 937 NP_000321.1 Already existis
# 938 NP_000275.1 Already existis
# 939 NP_004577.1 Already existis
# 940 NP_055147.1 Already existis
# 941 NP_000435.3 Already existis
# 942 NP_005382.1 Already existis
# 943 NP_620689.1 Already existis
# 944 NP_000388.2 Already existis
# 945 NP_000522.3 Already existis
# 946 NP_001347.3 Already existis
# 947 NP_001354650.1 Already existis
# 948 NP_000257.1 Already existis
# 949 NP_008846.2 Already existis
# 950 NP_005626.1 Already existis
# 951 NP_006570.1 Already existis
# 952 NP_000368.1 Already existis
# 953 NP_002040.1 Already existis
# 954 NP_005651.1 Already existis
# 955 NP_006512.2 Already existis
# 956 NP_001025067.1 Already existis
# 957 NP_054728.2 Already existis
# 958 NP_005439.2 Already existis
# 959 NP_004454.2 Already existis
# 960 NP_000023.2 Already existis
# 961 NP_001340850.1 Already existis
# 962 NP_061154.1 Already existis
# 963 NP_000035.2 Already existis
# 964 NP_004420.1 Already existis
# 965 NP_001390.1 Already existis
# 966 NP_851820.1 Already existis
# 967 NP_000157.1 Already existis
# 968 NP_060956.1 Already existis
# 969 NP_006508.2 Already existis
# 970 NP_000282.1 Already existis
# 971 NP_000052.1 Already existis
# 972 NP_000160.1 Already existis
# 973 NP_000524.3 Already existis
# 974 NP_001182482.1 Already existis
# 975 NP_065922.3 Already existis
# 976 NP_005023.2 Already existis
# 977 NP_001143.2 Already existis
# 978 NP_003327.2 Already existis
# 979 NP_078804.2 Already existis
# 980 NP_002285.1 Already existis
# 981 NP_001011551.1 Already existis
# 982 NP_015564.5 Already existis
# 983 NP_002342.1 Already existis
# 984 NP_000267.2 Already existis
# 985 NP_001412.1 Already existis
# 986 NP_919253.1 Already existis
# 987 NP_114113.1 Already existis
# 988 NP_001015877.1 Already existis
# 989 NP_000185.1 Already existis
# 990 NP_001153171.1 Already existis
# 991 NP_000065.1 Already existis
# 992 NP_000124.1 Already existis
# 993 NP_115928.1 Already existis
# 994 NP_000193.1 Already existis
# 995 NP_000243.1 Already existis
# 996 NP_000799.1 Already existis
# 997 NP_005620.1 Already existis
# 998 NP_000024.2 Already existis
# 999 NP_000045.1 Already existis
# 1000 NP_001104262.1 Already existis
# 1001 NP_000107.1 Already existis
# 1002 NP_001346945.1 Already existis
# 1003 NP_001354.1 Already existis
# 1004 NP_114127.3 Already existis
# 1005 NP_113663.2 Already existis
# 1006 NP_073624.2 Already existis
# 1007 NP_031401.1 Already existis
# 1008 NP_000293.2 Already existis
# 1009 NP_009203.2 Already existis
# 1010 NP_004422.2 Already existis
# 1011 NP_997304.3 Already existis
# 1012 NP_055862.1 Already existis
# 1013 NP_115785.1 Already existis
# 1014 NP_001009999.1 Already existis
# 1015 NP_001008217.1 Already existis
# 1016 NP_056442.2 Already existis
# 1017 NP_003671.1 Already existis
# 1018 NP_071440.1 Already existis
# 1019 NP_004691.2 Already existis
# 1020 NP_071751.3 Already existis
# 1021 NP_006270.1 Already existis
# 1022 NP_065098.1 Already existis
# 1023 NP_056321.2 Already existis
# 1024 NP_036318.1 Already existis
# 1025 NP_001128145.1 Already existis
# 1026 NP_057062.1 Already existis
# 1027 NP_003663.2 Already existis
# 1028 NP_006487.1 Already existis
# 1029 NP_001355738.1 Already existis
# 1030 NP_002223.3 Already existis
# 1031 NP_001365898.1 Already existis
# 1032 NP_001240781.1 Already existis
# 1033 NP_002515.1 Already existis
# 1034 NP_056651.1 Already existis
# 1035 NP_998818.1 Already existis
# 1036 NP_001020774.1 Already existis
# 1037 NP_002240.3 Already existis
# 1038 NP_006547.1 Already existis
# 1039 NP_079483.3 Already existis
# 1040 NP_060586.2 Already existis
# 1041 NP_002232.2 Already existis
# 1042 NP_001222.3 Already existis
# 1043 NP_006173.2 Already existis
# 1044 NP_002576.1 Already existis
# 1045 NP_008927.1 Already existis
# 1046 NP_001002294.1 Already existis
# 1047 NP_066956.1 Already existis
# 1048 NP_002104.2 Already existis
# 1049 NP_796376.2 Already existis
# 1050 NP_000528.1 Already existis
# 1051 NP_758861.1 Already existis
# 1052 NP_060530.3 Already existis
# 1053 NP_001366332.1 Already existis
# 1054 NP_064632.2 Already existis
# 1055 NP_073623.1 Already existis
# 1056 NP_665860.2 Already existis
# 1057 NP_991331.1 Already existis
# 1058 NP_001193673.1 Already existis
# 1059 NP_001034451.1 Already existis
# 1060 NP_002372.1 Already existis
# 1061 NP_000173.2 Already existis
# 1062 NP_066918.2 Already existis
# 1063 NP_002428.1 Already existis
# 1064 NP_001029288.1 Already existis
# 1065 NP_002700.1 Already existis
# 1066 NP_071881.1 Already existis
# 1067 NP_071882.1 Already existis
# 1068 NP_001165084.1 Already existis
# 1069 NP_001177203.1 Already existis
# 1070 NP_060532.2 Already existis
# 1071 NP_001231639.1 Already existis
# 1072 NP_001683.2 Already existis
# 1073 NP_003115.1 Already existis
# 1074 NP_006293.2 Already existis
# 1075 NP_001129121.1 Already existis
# 1076 NP_653164.2 Already existis
# 1077 NP_068587.1 Already existis
# 1078 NP_006334.2 Already existis
# 1079 NP_003457.1 Already existis
# 1080 NP_000113.1 Already existis
# 1081 NP_689735.1 Already existis
# 1082 NP_000879.2 Already existis
# 1083 NP_006054.2 Already existis
# 1084 NP_000808.2 Already existis
# 1085 NP_114148.3 Already existis
# 1086 NP_001138722.1 Already existis
# 1087 NP_000070.1 Already existis
# 1088 NP_001813.1 Already existis
# 1089 NP_000514.2 Already existis
# 1090 NP_006155.2 Already existis
# 1091 NP_055400.1 Already existis
# 1092 NP_000525.1 Already existis
# 1093 NP_055177.2 Already existis
# 1094 NP_055720.3 Already existis
# 1095 NP_001037850.1 Already existis
# 1096 NP_005205.2 Already existis
# 1097 NP_004997.4 Already existis
# 1098 NP_008822.2 Already existis
# 1099 NP_000456.2 Already existis
# 1100 NP_001548.1 Already existis
# 1101 NP_003581.1 Already existis
# 1102 NP_079519.1 Already existis
# 1103 NP_005190.4 Already existis
# 1104 NP_877437.2 Already existis
# 1105 NP_000835.1 Already existis
# 1106 NP_002871.1 Already existis
# 1107 NP_004619.3 Already existis
# 1108 NP_001895.1 Already existis
# 1109 NP_000307.1 Already existis
# 1110 NP_001026873.2 Already existis
# 1111 NP_001780.2 Already existis
# 1112 NP_338599.1 Already existis
# 1113 NP_003356.2 Already existis
# 1114 NP_000875.2 Already existis
# 1115 NP_942581.1 Already existis
# 1116 NP_068806.2 Already existis
# 1117 NP_002061.1 Already existis
# 1118 NP_006536.3 Already existis
# 1119 NP_001364334.1 Already existis
# 1120 NP_001341533.1 Already existis
# 1121 NP_001336267.1 Already existis
# 1122 NP_000297.1 Already existis
# 1123 NP_057673.2 Already existis
# 1124 NP_001186728.1 Already existis
# 1125 NP_068799.2 Already existis
# 1126 NP_004517.2 Already existis
# 1127 NP_116027.2 Already existis
# 1128 NP_001263199.1 Already existis
# 1129 NP_001054.2 Already existis
# 1130 NP_005621.2 Already existis
# 1131 NP_848649.3 Already existis
# 1132 NP_003403.2 Already existis
# 1133 NP_004121.2 Already existis
# 1134 NP_009220.2 Already existis
# 1135 NP_079272.4 Already existis
# 1136 NP_000046.1 Already existis
# 1137 NP_009148.2 Already existis
# 1138 NP_001958.2 Already existis
# 1139 NP_006571.2 Already existis
# 1140 NP_000987.2 Already existis
# 1141 NP_000274.3 Already existis
# 1142 NP_001116153.1 Already existis
# 1143 NP_714928.1 Already existis
# 1144 NP_006008.1 Already existis
# 1145 NP_056958.3 Already existis
# 1146 NP_000213.1 Already existis
# 1147 NP_006250.1 Already existis
# 1148 NP_001345850.1 Already existis
# 1149 NP_000288.1 Already existis
# 1150 NP_000336.1 Already existis
# 1151 NP_001156907.2 Already existis
# 1152 NP_898898.1 Already existis
# 1153 NP_005318.6 Already existis
# 1154 NP_660208.2 Already existis
# 1155 NP_476516.1 Already existis
# 1156 NP_000892.2 Already existis
# 1157 NP_005132.2 Already existis
# 1158 NP_068657.1 Already existis
# 1159 NP_068656.2 Already existis
# 1160 NP_612395.2 Already existis
# 1161 NP_001820.2 Already existis
# 1162 NP_000018.2 Already existis
# 1163 NP_997235.3 Already existis
# 1164 NP_000883.2 Already existis
# 1165 NP_000119.1 Already existis
# 1166 NP_001035.1 Already existis
# 1167 NP_036205.1 Already existis
# 1168 NP_004456.1 Already existis
# 1169 NP_001091981.1 Already existis
# 1170 NP_852664.1 Already existis
# 1171 NP_002308.2 Already existis
# 1172 NP_005331.1 Already existis
# 1173 NP_002706.1 Already existis
# 1174 NP_036340.1 Already existis
# 1175 NP_000167.1 Already existis
# 1176 NP_002691.1 Already existis
# 1177 NP_009217.3 Already existis
# 1178 NP_000818.2 Already existis
# 1179 NP_001136028.1 Already existis
# 1180 NP_002440.2 Already existis
# 1181 NP_003043.3 Already existis
# 1182 NP_006558.1 Already existis
# 1183 NP_000120.2 Already existis
# 1184 NP_001358995.1 Already existis
# 1185 NP_001229886.1 Already existis
# 1186 NP_004743.1 Already existis
# 1187 NP_001121636.1 Already existis
# 1188 NP_940988.2 Already existis
# 1189 NP_001461.1 Already existis
# 1190 NP_001103279.2 Already existis
# 1191 NP_821133.1 Already existis
# 1192 NP_000584.3 Already existis
# 1193 NP_001361552.1 Already existis
# 1194 NP_057143.1 Already existis
# 1195 NP_003212.2 Already existis
# 1196 NP_056414.1 Already existis
# 1197 NP_001073977.1 Already existis
# 1198 NP_001265645.1 Already existis
# 1199 NP_068775.1 Already existis
# 1200 NP_009145.1 Already existis
# 1201 NP_612468.1 Already existis
# 1202 NP_000279.1 Already existis
# 1203 NP_001278963.1 Already existis
# 1204 NP_997001.1 Already existis
# 1205 NP_004553.2 Already existis
# 1206 NP_057182.1 Already existis
# 1207 NP_005609.3 Already existis
# 1208 NP_001158232.1 Already existis
# 1209 NP_689956.2 Already existis
# 1210 NP_036426.4 Already existis
# 1211 NP_061932.1 Already existis
# 1212 NP_061820.1 Already existis
# 1213 NP_002128.1 Already existis
# 1214 NP_005514.1 Already existis
# 1215 NP_000513.2 Already existis
# 1216 NP_000814.2 Already existis
# 1217 NP_001211.3 Already existis
# 1218 NP_057122.2 Already existis
# 1219 NP_004594.1 Already existis
# 1220 NP_001382342.1 Already existis
# 1221 NP_005909.2 Already existis
# 1222 NP_036563.1 Already existis
# 1223 NP_005212.1 Already existis
# 1224 NP_005711.1 Already existis
# 1225 NP_004713.2 Already existis
# 1226 NP_005264.2 Already existis
# 1227 NP_001075.1 Already existis
# 1228 NP_945350.1 Already existis
# 1229 NP_001859.1 Already existis
# 1230 NP_001052.3 Already existis
# 1231 NP_005422.1 Already existis
# 1232 NP_000184.1 Already existis
# 1233 NP_061764.2 Already existis
# 1234 NP_078872.3 Already existis
# 1235 NP_699163.2 Already existis
# 1236 NP_619729.1 Already existis
# 1237 NP_808592.2 Already existis
# 1238 NP_055993.2 Already existis
# 1239 NP_006149.2 Already existis
# 1240 NP_001017420.1 Already existis
# 1241 NP_009106.1 Already existis
# 1242 NP_009129.1 Already existis
# 1243 NP_000340.2 Already existis
# 1244 NP_055277.1 Already existis
# 1245 NP_112216.3 Already existis
# 1246 NP_004811.1 Already existis
# 1247 NP_000494.2 Already existis
# 1248 NP_000058.1 Already existis
# 1249 NP_002476.2 Already existis
# 1250 NP_057107.4 Already existis
# 1251 NP_036286.2 Already existis
# 1252 NP_510965.1 Already existis
# 1253 NP_001350047.1 Already existis
# 1254 NP_570901.3 Already existis
# 1255 NP_003374.3 Already existis
# 1256 NP_000541.1 Already existis
# 1257 NP_001177666.1 Already existis
# 1258 NP_057609.2 Already existis
# 1259 NP_001152.1 Already existis
# 1260 NP_036276.1 Already existis
# 1261 NP_005857.1 Already existis
# 1262 NP_004620.1 Already existis
# 1263 NP_003280.2 Already existis
# 1264 NP_057126.2 Already existis
# 1265 NP_008845.2 Already existis
# 1266 NP_001689.1 Already existis
# 1267 NP_004551.2 Already existis
# 1268 NP_006406.1 Already existis
# 1269 NP_000127.2 Already existis
# 1270 NP_000188.1 Already existis
# 1271 NP_061819.2 Already existis
# 1272 NP_005449.5 Already existis
# 1273 NP_775822.3 Already existis
# 1274 NP_061924.1 Already existis
# 1275 NP_005583.1 Already existis
# 1276 NP_036342.2 Already existis
# 1277 NP_003156.1 Already existis
# 1278 NP_003854.1 Already existis
# 1279 NP_005085.2 Already existis
# 1280 NP_003002.2 Already existis
# 1281 NP_055723.1 Already existis
# 1282 NP_115925.2 Already existis
# 1283 NP_055509.2 Already existis
# 1284 NP_835258.1 Already existis
# 1285 NP_006079.1 Already existis
# 1286 NP_055970.1 Already existis
# 1287 NP_001008213.1 Already existis
# 1288 NP_057288.1 Already existis
# 1289 NP_660161.1 Already existis
# 1290 NP_001345192.1 Already existis
# 1291 NP_060814.4 Already existis
# 1292 NP_004264.2 Already existis
# 1293 NP_001354463.1 Already existis
# 1294 NP_001092138.1 Already existis
# 1295 NP_004320.2 Already existis
# 1296 NP_005262.1 Already existis
# 1297 NP_001604.1 Already existis
# 1298 NP_005088.1 Already existis
# 1299 NP_510870.1 Already existis
# 1300 NP_000269.3 Already existis
# 1301 NP_060119.3 Already existis
# 1302 NP_569157.2 Already existis
# 1303 NP_031399.2 Already existis
# 1304 NP_001600.1 Already existis
# 1305 NP_065109.1 Already existis
# 1306 NP_003273.1 Already existis
# 1307 NP_001014437.1 Already existis
# 1308 NP_055304.1 Already existis
# 1309 NP_001369496.1 Already existis
# 1310 NP_001243615.1 Already existis
# 1311 NP_001018067.1 Already existis
# 1312 NP_001354802.1 Already existis
# 1313 NP_005557.1 Already existis
# 1314 NP_998764.1 Already existis
# 1315 NP_000602.1 Already existis
# 1316 NP_004162.2 Already existis
# 1317 NP_997005.1 Already existis
# 1318 NP_004804.2 Already existis
# 1319 NP_000497.1 Already existis
# 1320 NP_004542.1 Already existis
# 1321 NP_001116427.1 Already existis
# 1322 NP_006259.1 Already existis
# 1323 NP_660201.1 Already existis
# 1324 NP_002487.1 Already existis
# 1325 NP_006010.2 Already existis
# 1326 NP_060105.3 Already existis
# 1327 NP_060631.2 Already existis
# 1328 NP_001138341.1 Already existis
# 1329 NP_001122394.1 Already existis
# 1330 NP_002567.3 Already existis
# 1331 NP_004259.3 Already existis
# 1332 NP_005582.1 Already existis
# 1333 NP_002418.1 Already existis
# 1334 NP_005788.1 Already existis
# 1335 NP_004388.2 Already existis
# 1336 NP_001157749.1 Already existis
# 1337 NP_001245173.1 Already existis
# 1338 NP_002008.2 Already existis
# 1339 NP_000881.3 Already existis
# 1340 NP_001750.1 Already existis
# 1341 NP_065689.1 Already existis
# 1342 NP_002226.1 Already existis
# 1343 NP_001056.1 Already existis
# 1344 NP_001724.4 Already existis
# 1345 NP_065712.1 Already existis
# 1346 NP_001978.1 Already existis
# 1347 NP_004973.1 Already existis
# 1348 NP_945316.1 Already existis
# 1349 NP_085911.2 Already existis
# 1350 NP_001035526.1 Already existis
# 1351 NP_000280.1 Already existis
# 1352 NP_004809.2 Already existis
# 1353 NP_003385.2 Already existis
# 1354 NP_060583.2 Already existis
# 1355 NP_003067.3 Already existis
# 1356 NP_000414.2 Already existis
# 1357 NP_002896.2 Already existis
# 1358 NP_001027558.1 Already existis
# 1359 NP_005717.3 Already existis
# 1360 NP_002067.1 Already existis
# 1361 NP_055134.2 Already existis
# 1362 NP_001026849.1 Already existis
# 1363 NP_065134.1 Already existis
# 1364 NP_078961.3 Already existis
# 1365 NP_647480.1 Already existis
# 1366 NP_001193908.1 Already existis
# 1367 NP_055521.1 Already existis
# 1368 NP_443077.1 Already existis
# 1369 NP_000422.1 Already existis
# 1370 NP_001076007.1 Already existis
# 1371 NP_002825.3 Already existis
# 1372 NP_005987.3 Already existis
# 1373 NP_000008.1 Already existis
# 1374 NP_001405.1 Already existis
# 1375 NP_079085.2 Already existis
# 1376 NP_036595.2 Already existis
# 1377 NP_079491.2 Already existis
# 1378 NP_005923.3 Already existis
# 1379 NP_001251.1 Already existis
# 1380 NP_000200.1 Already existis
# 1381 NP_001256.4 Already existis
# 1382 NP_919299.3 Already existis
# 1383 NP_570718.1 Already existis
# 1384 NP_057701.1 Already existis
# 1385 NP_055120.1 Already existis
# 1386 NP_009060.2 Already existis
# 1387 NP_996820.1 Already existis
# 1388 NP_062562.1 Already existis
# 1389 NP_060277.1 Already existis
# 1390 NP_000261.2 Already existis
# 1391 NP_001092744.1 Already existis
# 1392 NP_002733.2 Already existis
# 1393 NP_006355.2 Already existis
# 1394 NP_002854.3 Already existis
# 1395 NP_001193.2 Already existis
# 1396 NP_060269.3 Already existis
# 1397 NP_068374.1 Already existis
# 1398 NP_005973.1 Already existis
# 1399 NP_001521.1 Already existis
# 1400 NP_647479.2 Already existis
# 1401 NP_060261.2 Already existis
# 1402 NP_078772.1 Already existis
# 1403 NP_037514.2 Already existis
# 1404 NP_004854.1 Already existis
# 1405 NP_000286.3 Already existis
# 1406 NP_003375.1 Already existis
# 1407 NP_612808.1 Already existis
# 1408 NP_001357524.1 Already existis
# 1409 NP_001369359.1 Already existis
# 1410 NP_001510.2 Already existis
# 1411 NP_570854.1 Already existis
# 1412 NP_055782.3 Already existis
# 1413 NP_005150.1 Already existis
# 1414 NP_733775.1 Already existis
# 1415 NP_002866.2 Already existis
# 1416 NP_689661.1 Already existis
# 1417 NP_997464.2 Already existis
# 1418 NP_001473.1 Already existis
# 1419 NP_076968.2 Already existis
# 1420 NP_000227.2 Already existis
# 1421 NP_599023.1 Already existis
# 1422 NP_001018005.1 Already existis
# 1423 NP_000933.1 Already existis
# 1424 NP_004654.1 Already existis
# 1425 NP_005893.1 Already existis
# 1426 NP_060352.1 Already existis
# 1427 NP_000772.2 Already existis
# 1428 NP_002426.1 Already existis
# 1429 NP_000741.1 Already existis
# 1430 NP_066285.1 Already existis
# 1431 NP_000684.2 Already existis
# 1432 NP_005852.2 Already existis
# 1433 NP_076425.1 Already existis
# 1434 NP_115647.2 Already existis
# 1435 NP_001752.2 Already existis
# 1436 NP_001186036.1 Already existis
# 1437 NP_077315.2 Already existis
# 1438 NP_001129944.1 Already existis
# 1439 NP_005227.1 Already existis
# 1440 NP_002573.1 Already existis
# 1441 NP_001077083.1 Already existis
# 1442 NP_001035897.1 Already existis
# 1443 NP_015556.1 Already existis
# 1444 NP_660282.2 Already existis
# 1445 NP_009005.1 Already existis
# 1446 NP_000285.1 Already existis
# 1447 NP_443106.1 Already existis
# 1448 NP_597700.1 Already existis
# 1449 NP_003022.3 Already existis
# 1450 NP_114091.4 Already existis
# 1451 NP_055484.3 Already existis
# 1452 NP_958933.1 Already existis
# 1453 NP_037374.1 Already existis
# 1454 NP_000187.3 Already existis
# 1455 NP_006556.1 Already existis
# 1456 NP_061896.1 Already existis
# 1457 NP_115758.3 Already existis
# 1458 NP_001119.3 Already existis
# 1459 NP_000092.2 Already existis
# 1460 NP_000968.2 Already existis
# 1461 NP_542435.2 Already existis
# 1462 NP_055619.2 Already existis
# 1463 NP_808218.1 Already existis
# 1464 NP_000738.2 Already existis
# 1465 NP_060597.4 Already existis
# 1466 NP_001036162.1 Already existis
# 1467 NP_004269.1 Already existis
# 1468 NP_659434.2 Already existis
# 1469 NP_056496.1 Already existis
# 1470 NP_000682.3 Already existis
# 1471 NP_114140.4 Already existis
# 1472 NP_065842.1 Already existis
# 1473 NP_056170.2 Already existis
# 1474 NP_001253981.1 Already existis
# 1475 NP_219487.3 Already existis
# 1476 NP_955366.1 Already existis
# 1477 NP_003070.3 Already existis
# 1478 NP_000217.2 Already existis
# 1479 NP_000517.3 Already existis
# 1480 NP_068758.3 Already existis
# 1481 NP_036580.2 Already existis
# 1482 NP_001061.2 Already existis
# 1483 NP_001073143.1 Already existis
# 1484 NP_612396.1 Already existis
# 1485 NP_003387.1 Already existis
# 1486 NP_004278.2 Already existis
# 1487 NP_001007229.1 Already existis
# 1488 NP_003638.1 Already existis
# 1489 NP_003611.1 Already existis
# 1490 NP_006843.2 Already existis
# 1491 NP_000506.2 Already existis
# 1492 NP_060035.2 Already existis
# 1493 NP_000882.1 Already existis
# 1494 NP_997229.2 Already existis
# 1495 NP_001153245.1 Already existis
# 1496 NP_000909.2 Already existis
# 1497 NP_008838.2 Already existis
# 1498 NP_066552.2 Already existis
# 1499 NP_000520.1 Already existis
# 1500 NP_002885.1 Already existis
# 1501 NP_055083.1 Already existis
# 1502 NP_005350.1 Already existis
# 1503 NP_004530.1 Already existis
# 1504 NP_005903.2 Already existis
# 1505 NP_003830.1 Already existis
# 1506 NP_077718.3 Already existis
# 1507 NP_001051.1 Already existis
# 1508 NP_001952.1 Already existis
# 1509 NP_109587.1 Already existis
# 1510 NP_115484.2 Already existis
# 1511 NP_891549.1 Already existis
# 1512 NP_783313.1 Already existis
# 1513 NP_006003.1 Already existis
# 1514 NP_001005361.1 Already existis
# 1515 NP_001276033.1 Already existis
# 1516 NP_000519.2 Already existis
# 1517 NP_001369170.1 Already existis
# 1518 NP_001129507.1 Already existis
# 1519 NP_443108.1 Already existis
# 1520 NP_775754.2 Already existis
# 1521 NP_004741.1 Already existis
# 1522 NP_001483.3 Already existis
# 1523 NP_004829.3 Already existis
# 1524 NP_113636.2 Already existis
# 1525 NP_644813.1 Already existis
# 1526 NP_079152.3 Already existis
# 1527 NP_114429.2 Already existis
# 1528 NP_008990.2 Already existis
# 1529 NP_004968.2 Already existis
# 1530 NP_149059.1 Already existis
# 1531 NP_055040.2 Already existis
# 1532 NP_055331.1 Already existis
# 1533 NP_001243644.1 Already existis
# 1534 NP_009210.1 Already existis
# 1535 NP_945345.2 Already existis
# 1536 NP_003082.1 Already existis
# 1537 NP_000302.1 Already existis
# 1538 NP_740754.1 Already existis
# 1539 NP_077025.2 Already existis
# 1540 NP_006354.2 Already existis
# 1541 NP_068556.2 Already existis
# 1542 NP_003089.1 Already existis
# 1543 NP_001269862.1 Already existis
# 1544 NP_000169.1 Already existis
# 1545 NP_056289.2 Already existis
# 1546 NP_542119.1 Already existis
# 1547 NP_001073941.1 Already existis
# 1548 NP_004985.2 Already existis
# 1549 NP_073740.2 Already existis
# 1550 NP_059142.3 Already existis
# 1551 NP_001276054.1 Already existis
# 1552 NP_000620.2 Already existis
# 1553 NP_005060.1 Already existis
# 1554 NP_000062.1 Already existis
# 1555 NP_056074.1 Already existis
# 1556 NP_001121121.1 Already existis
# 1557 NP_001366129.1 Already existis
# 1558 NP_878315.2 Already existis
# 1559 NP_004773.1 Already existis
# 1560 NP_002736.3 Already existis
# 1561 NP_003064.2 Already existis
# 1562 NP_001878.1 Already existis
# 1563 NP_001877.1 Already existis
# 1564 NP_002863.1 Already existis
# 1565 NP_443177.1 Already existis
# 1566 NP_000389.1 Already existis
# 1567 NP_758448.1 Already existis
# 1568 NP_001307681.2 Already existis
# 1569 NP_001821.2 Already existis
# 1570 NP_004586.2 Already existis
# 1571 NP_000466.2 Already existis
# 1572 NP_005756.2 Already existis
# 1573 NP_001129470.1 Already existis
# 1574 NP_005667.2 Already existis
# 1575 NP_008881.2 Already existis
# 1576 NP_982301.1 Already existis
# 1577 NP_001027554.1 Already existis
# 1578 NP_001129629.1 Already existis
# 1579 NP_003170.1 Already existis
# 1580 NP_001138545.1 Already existis
# 1581 NP_001121370.1 Already existis
# 1582 NP_004484.1 Already existis
# 1583 NP_002538.1 Already existis
# 1584 NP_000197.1 Already existis
# 1585 NP_000298.3 Already existis
# 1586 NP_001004051.1 Already existis
# 1587 NP_004771.2 Already existis
# 1588 NP_002755.1 Already existis
# 1589 NP_001137453.1 Already existis
# 1590 NP_004199.1 Already existis
# 1591 NP_004475.1 Already existis
# 1592 NP_001366039.1 Already existis
# 1593 NP_003404.1 Already existis
# 1594 NP_004105.1 Already existis
# 1595 NP_002015.1 Already existis
# 1596 NP_001702.1 Already existis
# 1597 NP_003482.1 Already existis
# 1598 NP_001174.2 Already existis
# 1599 NP_004690.1 Already existis
# 1600 NP_000393.4 Already existis
# 1601 NP_001093327.1 Already existis
# 1602 NP_003131.1 Already existis
# #-unique NCBI protein sequences downloaded:  1603
# Creating merged fasta document.
