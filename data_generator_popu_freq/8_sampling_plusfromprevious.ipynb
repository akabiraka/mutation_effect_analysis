# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
home_dir = "../"

import pandas as pd

# %%
task = "popu_freq"
snvs_with_dbnsfp_result_df = pd.read_csv(home_dir+f"models/dbnsfp/outputs_postprocessed/{task}.tsv", sep="\t")
print(snvs_with_dbnsfp_result_df.columns)
print(snvs_with_dbnsfp_result_df.shape)
print(snvs_with_dbnsfp_result_df["class"].value_counts())
# Out:
# Index(['snp_id', 'gene_name', 'mane_refseq_prot', 'mane_refseq_nuc',
#        'mane_status', 'chrom_acc_version', 'chrom_num', 'source_ref_allele',
#        'source_alt_alleles', 'alfa_chrom_pos', 'alfa_ref_allele',
#        'alfa_alt_allele', 'alfa_alt_alleles', 'prot_variant',
#        'prot_acc_version', '1indexed_prot_mt_pos', 'wt_aa', 'mt_aa',
#        'wt_aa_1letter', 'mt_aa_1letter', 'wt_population', 'mt_population',
#        'wt_freq', 'mt_freq', 'class', 'MetaRNN_score', 'MVP_score',
#        'SIFT_score', 'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score',
#        'integrated_fitCons_score', 'phyloP17way_primate',
#        'phastCons17way_primate', 'bStatistic'],
#       dtype='object')
# (1027660, 35)
# Singleton     578418
# Ultra-rare    388752
# Rare           36200
# Common         24290
# Name: class, dtype: int64

# %%
print(snvs_with_dbnsfp_result_df.shape)
print(snvs_with_dbnsfp_result_df["snp_id"].unique().shape[0])
print(snvs_with_dbnsfp_result_df["gene_name"].unique().shape[0])
print(snvs_with_dbnsfp_result_df["mane_refseq_prot"].unique().shape[0])
# Out:
# (1027660, 35)
# 1010254
# 16577
# 16608

# %%
# computing number of supervised models score available for each row
supervised_method_cols = ['MetaRNN_score', 'MVP_score', 'SIFT_score', 'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score']
def get_num_of_methods_have_prediction_on_this_row(row):
    n = 0
    for col in supervised_method_cols:
        # print(pd.isna(row[col]))
        if not pd.isna(row[col]):
            n += 1
    # print(n)
    return n

snvs_with_dbnsfp_result_df["n_methods_having_preds"] = snvs_with_dbnsfp_result_df.apply(get_num_of_methods_have_prediction_on_this_row, axis=1)

print(snvs_with_dbnsfp_result_df.shape)
print(snvs_with_dbnsfp_result_df.columns)
# Out:
# (1027660, 36)
# Index(['snp_id', 'gene_name', 'mane_refseq_prot', 'mane_refseq_nuc',
#        'mane_status', 'chrom_acc_version', 'chrom_num', 'source_ref_allele',
#        'source_alt_alleles', 'alfa_chrom_pos', 'alfa_ref_allele',
#        'alfa_alt_allele', 'alfa_alt_alleles', 'prot_variant',
#        'prot_acc_version', '1indexed_prot_mt_pos', 'wt_aa', 'mt_aa',
#        'wt_aa_1letter', 'mt_aa_1letter', 'wt_population', 'mt_population',
#        'wt_freq', 'mt_freq', 'class', 'MetaRNN_score', 'MVP_score',
#        'SIFT_score', 'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score',
#        'integrated_fitCons_score', 'phyloP17way_primate',
#        'phastCons17way_primate', 'bStatistic', 'n_methods_having_preds'],
#       dtype='object')

# %%
def print_missing_things(x:pd.DataFrame):
    model_names = ['MetaRNN_score', 'MVP_score',
       'SIFT_score', 'Polyphen2_HVAR_score', 'CADD_raw', 'REVEL_score',
       'integrated_fitCons_score', 'phyloP17way_primate',
       'phastCons17way_primate', 'bStatistic']

    # print("", "Common", "Rare", "Ultra-rare", "Singleton", sep="\t")
    print("\t", end="")
    for i, cls in enumerate(["Common", "Rare", "Ultra-rare", "Singleton"]):
        prots = x[(x["class"]==cls)]["prot_acc_version"].unique().shape[0]
        print(f"{cls}({prots})", end="\t")
    print()
    for model_name in model_names:
        print(model_name, end="\t")
        for i, cls in enumerate(["Common", "Rare", "Ultra-rare", "Singleton"]):
            missing = x[(x["class"]==cls) & pd.isna(x[model_name])].shape[0]
            not_missing = x[(x["class"]==cls) & ~pd.isna(x[model_name])].shape[0]
            total = x[(x["class"]==cls)].shape[0]
            
            print(f"{missing}/{not_missing}", end="\t")
            if i==3: print()

print_missing_things(snvs_with_dbnsfp_result_df)
# Out:
# 	Common(9153)	Rare(12120)	Ultra-rare(16486)	Singleton(16539)
# MetaRNN_score	0/24290	0/36200	0/388752	0/578418
# MVP_score	20057/4233	3640/32560	4917/383835	6247/572171
# SIFT_score	2496/21794	2935/33265	17934/370818	26297/552121
# Polyphen2_HVAR_score	3654/20636	4460/31740	25657/363095	36801/541617
# CADD_raw	0/24290	0/36200	0/388752	0/578418
# REVEL_score	2516/21774	3005/33195	16122/372630	23363/555055
# integrated_fitCons_score	1077/23213	1449/34751	10914/377838	8949/569469
# phyloP17way_primate	26/24264	27/36173	71/388681	100/578318
# phastCons17way_primate	26/24264	27/36173	71/388681	100/578318
# bStatistic	686/23604	928/35272	6653/382099	9297/569121

# %%
# loading the previous sampled data
prev_snvs_with_dbnsfp_result_df = pd.read_csv(home_dir+f"data/datasets_popu_freq/popu_freq_with_dbnsfp_sampled_prev.tsv", sep="\t")
print(prev_snvs_with_dbnsfp_result_df.columns)
print(prev_snvs_with_dbnsfp_result_df.shape)
print(prev_snvs_with_dbnsfp_result_df["class"].value_counts())
# Out:
# Index(['snp_id', 'chrom_acc_version', 'chrom_pos', 'ref_allele', 'alt_allele',
#        'prot_acc_version', 'prot_pos', 'wt', 'mut', 'wt_population',
#        'mut_poulation', 'wt_freq', 'mt_freq', 'class', 'chrom', 'SIFT_score',
#        'Polyphen2_HVAR_score', 'MetaRNN_score', 'REVEL_score', 'MVP_score',
#        'CADD_raw_score', 'integrated_fitCons_score',
#        'phyloP17way_primate_score', 'phastCons17way_primate_score',
#        'bStatistic_score', 'n_methods_having_preds'],
#       dtype='object')
# (26409, 26)
# Common        6976
# Ultra-rare    6957
# Singleton     6955
# Rare          5521
# Name: class, dtype: int64

# %%
# this is only to see of how many can be mapped
selected_df = prev_snvs_with_dbnsfp_result_df[['prot_acc_version', 'prot_pos', 'wt', 'mut']]
y = snvs_with_dbnsfp_result_df.merge(right=selected_df, how="inner", 
                                 left_on=['prot_acc_version', '1indexed_prot_mt_pos', 'wt_aa_1letter', 'mt_aa_1letter'],
                                 right_on=['prot_acc_version', 'prot_pos', 'wt', 'mut'])
y.shape
# Out:
# (26367, 39)

# %%
selected_df = prev_snvs_with_dbnsfp_result_df[['prot_acc_version', 'prot_pos', 'wt', 'mut']]
result_with_prevsamples_df = snvs_with_dbnsfp_result_df.merge(right=selected_df, how="left", 
                                 left_on=['prot_acc_version', '1indexed_prot_mt_pos', 'wt_aa_1letter', 'mt_aa_1letter'],
                                 right_on=['prot_acc_version', 'prot_pos', 'wt', 'mut'])
result_with_prevsamples_df.shape
# Out:
# (1027660, 39)

# %%
# keeping 1 col if a row is previously sampled
def xxx(row):
    if not pd.isna(row.prot_pos) and not pd.isna(row.wt) and not pd.isna(row.mut):
        return True
    return False
    
result_with_prevsamples_df["is_selected_prev"] = result_with_prevsamples_df.apply(xxx, axis=1)

result_with_prevsamples_df.drop(['prot_pos', 'wt', 'mut'], axis=1, inplace=True)
result_with_prevsamples_df["is_selected_prev"].value_counts()
# Out:
# False    1001293
# True       26367
# Name: is_selected_prev, dtype: int64

# %%
a = set(result_with_prevsamples_df[(result_with_prevsamples_df["class"]=="Common")]["prot_acc_version"].unique())
b = set(result_with_prevsamples_df[(result_with_prevsamples_df["class"]=="Rare")]["prot_acc_version"].unique())
c = set(result_with_prevsamples_df[(result_with_prevsamples_df["class"]=="Ultra-rare")]["prot_acc_version"].unique())
d = set(result_with_prevsamples_df[(result_with_prevsamples_df["class"]=="Singleton")]["prot_acc_version"].unique())

cmn_and_rare_prots = a.intersection(b)
cmn_and_ultrarare_prots = a.intersection(c)
cmn_and_singleton_prots = a.intersection(d)
cmn_prots = cmn_and_rare_prots.union(cmn_and_ultrarare_prots).union(cmn_and_singleton_prots)
cmn_rare_ultrarare_singleton_prots = a.intersection(b).intersection(c).intersection(d)
print(len(cmn_and_rare_prots), len(cmn_and_ultrarare_prots), len(cmn_and_singleton_prots), len(cmn_prots), len(cmn_rare_ultrarare_singleton_prots))
# Out:
# 7697 9124 9119 9142 7679

# %%
def sample_variants(class_name, prots_to_cover):
    print(len(prots_to_cover))
    y = result_with_prevsamples_df[(result_with_prevsamples_df["class"]==class_name)].copy()
    rem = prots_to_cover

    for i in range(6, 1, -1):
        y_i = y[(y["prot_acc_version"].isin(rem)) & (y["n_methods_having_preds"]==i)] #rare-cmn=null
        
        # select the rows that was previously sampled and keep only 1 for each protein
        prev_selected_rows = y_i[(y_i["is_selected_prev"]==True)]
        prev_selected_rows = prev_selected_rows.groupby("prot_acc_version").sample(1)

        # defining new df for the new proteins
        prev_selected_prot_set = set(prev_selected_rows["prot_acc_version"].unique())
        remaining_prot_set = set(y_i["prot_acc_version"].unique()) - prev_selected_prot_set
        z_i = y_i[(y_i["prot_acc_version"].isin(remaining_prot_set))]

        # sample 1 row corresponding to each new proteins
        new_sampled_rows = z_i.groupby("prot_acc_version").sample(1)

        # concate previously sampled and newly sampled rows
        sampled_rows = pd.concat([prev_selected_rows, new_sampled_rows])

        if i==6: data = sampled_rows
        else: data = pd.concat([data, sampled_rows])
        covered = set(data["prot_acc_version"].unique())
        rem = prots_to_cover - covered
        print("total covered: ", len(covered), "remained: ", len(rem))
        if len(rem)==0: break

    # print_missing_things(data)
    return data

c = sample_variants("Common", cmn_prots)
r = sample_variants("Rare", cmn_and_rare_prots)
ur = sample_variants("Ultra-rare", cmn_and_ultrarare_prots)
s = sample_variants("Singleton", cmn_and_singleton_prots)

# test
# c_set = set(c["prot_acc_version"].unique())
# r_set = set(r["prot_acc_version"].unique())
# r_set - c_set # this should be empty
# Out:
# 9142
# total covered:  1879 remained:  7263
# total covered:  8118 remained:  1024
# total covered:  8620 remained:  522
# total covered:  8905 remained:  237
# total covered:  9142 remained:  0
# 7697
# total covered:  6567 remained:  1130
# total covered:  7192 remained:  505
# total covered:  7404 remained:  293
# total covered:  7565 remained:  132
# total covered:  7697 remained:  0
# 9124
# total covered:  8074 remained:  1050
# total covered:  8612 remained:  512
# total covered:  8825 remained:  299
# total covered:  8992 remained:  132
# total covered:  9124 remained:  0
# 9119
# total covered:  8079 remained:  1040
# total covered:  8613 remained:  506
# total covered:  8825 remained:  294
# total covered:  8987 remained:  132
# total covered:  9119 remained:  0

# %%
good_data = pd.concat([c, r, ur, s])
print_missing_things(good_data)

c_set = set(good_data[good_data["class"]=="Common"]["prot_acc_version"].unique())
r_set = set(good_data[good_data["class"]=="Rare"]["prot_acc_version"].unique())
ur_set = set(good_data[good_data["class"]=="Ultra-rare"]["prot_acc_version"].unique())
s_set = set(good_data[good_data["class"]=="Singleton"]["prot_acc_version"].unique())

print(len(c_set), len(r_set), len(ur_set), len(s_set))

print(r_set - c_set)
print(ur_set - c_set)
print(s_set - c_set)
# Out:
# 	Common(9142)	Rare(7697)	Ultra-rare(9124)	Singleton(9119)
# MetaRNN_score	0/9142	0/7697	0/9124	0/9119
# MVP_score	6931/2211	321/7376	191/8933	189/8930
# SIFT_score	639/8503	501/7196	504/8620	500/8619
# Polyphen2_HVAR_score	878/8264	754/6943	782/8342	777/8342
# CADD_raw	0/9142	0/7697	0/9124	0/9119
# REVEL_score	598/8544	484/7213	516/8608	506/8613
# integrated_fitCons_score	345/8797	264/7433	307/8817	295/8824
# phyloP17way_primate	4/9138	4/7693	3/9121	3/9116
# phastCons17way_primate	4/9138	4/7693	3/9121	3/9116
# bStatistic	184/8958	162/7535	179/8945	171/8948
# 9142 7697 9124 9119
# set()
# set()
# set()

# %%
good_data["is_selected_prev"].value_counts()
# Out:
# True     26029
# False     9053
# Name: is_selected_prev, dtype: int64

# %%
out_filepath = home_dir+f"data/datasets_popu_freq/popu_freq_with_dbnsfp_sampled"
good_data.to_csv(out_filepath+".tsv", sep="\t", index=False)
# result_df = pd.read_csv(out_filepath+".tsv", sep="\t")

# Creating merged fasta document ...
protein_acc_list = list(good_data["prot_acc_version"].unique())
print(len(protein_acc_list))
from utils.ncbi_proteins import create_combined_fasta
create_combined_fasta(protein_acc_list, out_filepath+".fasta", home_dir)
# Out:
# 9142
# 0 NP_000015.2 Already existis
# 1 NP_000024.2 Already existis
# 2 NP_000053.2 Already existis
# 3 NP_000054.2 Already existis
# 4 NP_000068.1 Already existis
# 5 NP_000076.2 Already existis
# 6 NP_000086.2 Already existis
# 7 NP_000133.1 Already existis
# 8 NP_000144.2 Already existis
# 9 NP_000148.2 Already existis
# 10 NP_000156.1 Already existis
# 11 NP_000161.2 Already existis
# 12 NP_000162.2 Already existis
# 13 NP_000194.2 Already existis
# 14 NP_000209.2 Already existis
# 15 NP_000210.2 Already existis
# 16 NP_000249.1 Already existis
# 17 NP_000253.1 Already existis
# 18 NP_000256.4 Already existis
# 19 NP_000264.2 Already existis
# 20 NP_000265.1 Already existis
# 21 NP_000274.3 Already existis
# 22 NP_000280.1 Already existis
# 23 NP_000286.3 Already existis
# 24 NP_000292.1 Already existis
# 25 NP_000333.1 Already existis
# 26 NP_000337.1 Already existis
# 27 NP_000340.2 Already existis
# 28 NP_000352.1 Already existis
# 29 NP_000388.2 Already existis
# 30 NP_000408.1 Already existis
# 31 NP_000412.4 Already existis
# 32 NP_000422.1 Already existis
# 33 NP_000437.3 Already existis
# 34 NP_000456.2 Already existis
# 35 NP_000466.2 Already existis
# 36 NP_000469.3 Already existis
# 37 NP_000491.4 Already existis
# 38 NP_000492.2 Already existis
# 39 NP_000515.2 Already existis
# 40 NP_000527.2 Already existis
# 41 NP_000552.2 Already existis
# 42 NP_000557.1 Already existis
# 43 NP_000560.7 Already existis
# 44 NP_000599.1 Already existis
# 45 NP_000628.2 Already existis
# 46 NP_000684.2 Already existis
# 47 NP_000688.2 Already existis
# 48 NP_000693.1 Already existis
# 49 NP_000700.1 Already existis
# 50 NP_000737.1 Already existis
# 51 NP_000763.1 Already existis
# 52 NP_000802.2 Already existis
# 53 NP_000834.2 Already existis
# 54 NP_000838.3 Already existis
# 55 NP_000839.1 Already existis
# 56 NP_000853.1 Already existis
# 57 NP_000854.1 Already existis
# 58 NP_000880.1 Already existis
# 59 NP_000921.1 Already existis
# 60 NP_000937.1 Already existis
# 61 NP_000957.1 Already existis
# 62 NP_000973.2 Already existis
# 63 NP_001001480.2 Already existis
# 64 NP_001001551.2 Already existis
# 65 NP_001001656.1 Already existis
# 66 NP_001001824.1 Already existis
# 67 NP_001001827.1 Already existis
# 68 NP_001001913.1 Already existis
# 69 NP_001001961.2 Already existis
# 70 NP_001001966.1 Already existis
# 71 NP_001002901.1 Already existis
# 72 NP_001003.1 Already existis
# 73 NP_001003750.1 Already existis
# 74 NP_001003897.1 Already existis
# 75 NP_001003931.4 Already existis
# 76 NP_001004052.1 Already existis
# 77 NP_001004059.2 Already existis
# 78 NP_001004106.1 Already existis
# 79 NP_001004125.2 Already existis
# 80 NP_001004136.1 Already existis
# 81 NP_001004137.1 Already existis
# 82 NP_001004313.1 Already existis
# 83 NP_001004328.1 Already existis
# 84 NP_001004343.1 Already existis
# 85 NP_001004431.1 Already existis
# 86 NP_001004432.1 Already existis
# 87 NP_001004452.1 Already existis
# 88 NP_001004459.2 Already existis
# 89 NP_001004474.2 Already existis
# 90 NP_001004481.1 Already existis
# 91 NP_001004482.1 Already existis
# 92 NP_001004483.1 Already existis
# 93 NP_001004690.1 Already existis
# 94 NP_001004692.1 Already existis
# 95 NP_001004694.2 Already existis
# 96 NP_001004695.1 Already existis
# 97 NP_001004696.2 Already existis
# 98 NP_001004700.2 Already existis
# 99 NP_001004705.1 Already existis
# 100 NP_001004723.1 Already existis
# 101 NP_001005184.2 Already existis
# 102 NP_001005186.2 Already existis
# 103 NP_001005199.1 Already existis
# 104 NP_001005204.1 Already existis
# 105 NP_001005211.1 Already existis
# 106 NP_001005235.1 Already existis
# 107 NP_001005240.1 Already existis
# 108 NP_001005242.2 Already existis
# 109 NP_001005274.1 Already existis
# 110 NP_001005338.1 Already existis
# 111 NP_001005484.2 Already existis
# 112 NP_001005495.1 Already existis
# 113 NP_001005498.2 Already existis
# 114 NP_001005504.1 Already existis
# 115 NP_001005512.2 Already existis
# 116 NP_001005514.1 Already existis
# 117 NP_001005851.1 Already existis
# 118 NP_001005853.1 Already existis
# 119 NP_001006635.1 Already existis
# 120 NP_001009611.2 Already existis
# 121 NP_001010853.1 Already existis
# 122 NP_001010889.1 Already existis
# 123 NP_001010909.2 Already existis
# 124 NP_001010923.1 Already existis
# 125 NP_001011547.2 Already existis
# 126 NP_001011720.1 Already existis
# 127 NP_001012276.2 Already existis
# 128 NP_001012277.2 Already existis
# 129 NP_001012677.1 Already existis
# 130 NP_001012728.1 Already existis
# 131 NP_001012999.3 Already existis
# 132 NP_001013011.2 Already existis
# 133 NP_001013372.1 Already existis
# 134 NP_001013453.1 Already existis
# 135 NP_001013597.1 Already existis
# 136 NP_001013653.1 Already existis
# 137 NP_001013663.1 Already existis
# 138 NP_001013867.1 Already existis
# 139 NP_001014305.1 Already existis
# 140 NP_001014987.1 Already existis
# 141 NP_001015038.1 Already existis
# 142 NP_001015880.1 Already existis
# 143 NP_001017964.1 Already existis
# 144 NP_001018123.1 Already existis
# 145 NP_001018855.2 Already existis
# 146 NP_001018861.3 Already existis
# 147 NP_001019978.1 Already existis
# 148 NP_001020262.1 Already existis
# 149 NP_001020366.1 Already existis
# 150 NP_001020371.3 Already existis
# 151 NP_001020424.1 Already existis
# 152 NP_001020527.2 Already existis
# 153 NP_001020528.1 Already existis
# 154 NP_001020774.1 Already existis
# 155 NP_001025231.1 Already existis
# 156 NP_001026862.1 Already existis
# 157 NP_001026891.2 Already existis
# 158 NP_001026918.2 Already existis
# 159 NP_001027462.1 Already existis
# 160 NP_001030312.3 Already existis
# 161 NP_001032821.1 Already existis
# 162 NP_001032902.1 Already existis
# 163 NP_001033.1 Already existis
# 164 NP_001033729.2 Already existis
# 165 NP_001034450.3 Already existis
# 166 NP_001034658.1 Already existis
# 167 NP_001034681.1 Already existis
# 168 NP_001034703.1 Already existis
# 169 NP_001034704.2 Already existis
# 170 NP_001034706.1 Already existis
# 171 NP_001034749.1 Already existis
# 172 NP_001034852.3 Already existis
# 173 NP_001034869.1 Already existis
# 174 NP_001035121.2 Already existis
# 175 NP_001035167.2 Already existis
# 176 NP_001035214.1 Already existis
# 177 NP_001035350.2 Already existis
# 178 NP_001035364.2 Already existis
# 179 NP_001035552.1 Already existis
# 180 NP_001037770.1 Already existis
# 181 NP_001041648.1 Already existis
# 182 NP_001070146.1 Already existis
# 183 NP_001070246.1 Already existis
# 184 NP_001070667.1 Already existis
# 185 NP_001070731.1 Already existis
# 186 NP_001070966.1 Already existis
# 187 NP_001071107.1 Already existis
# 188 NP_001072998.1 Already existis
# 189 NP_001073865.1 Already existis
# 190 NP_001073909.1 Already existis
# 191 NP_001073947.1 Already existis
# 192 NP_001073956.2 Already existis
# 193 NP_001073957.1 Already existis
# 194 NP_001073980.2 Already existis
# 195 NP_001073992.2 Already existis
# 196 NP_001074239.1 Already existis
# 197 NP_001074299.2 Already existis
# 198 NP_001074312.1 Already existis
# 199 NP_001074318.1 Already existis
# 200 NP_001074467.1 Already existis
# 201 NP_001075106.2 Already existis
# 202 NP_001077006.1 Already existis
# 203 NP_001078846.2 Already existis
# 204 NP_001089.1 Already existis
# 205 NP_001091058.1 Already existis
# 206 NP_001091639.1 Already existis
# 207 NP_001091989.1 Already existis
# 208 NP_001092096.1 Already existis
# 209 NP_001092099.1 Already existis
# 210 NP_001092264.1 Already existis
# 211 NP_001092314.1 Already existis
# 212 NP_001092741.1 Already existis
# 213 NP_001092808.1 Already existis
# 214 NP_001092872.1 Already existis
# 215 NP_001092885.2 Already existis
# 216 NP_001093155.1 Already existis
# 217 NP_001093162.1 Already existis
# 218 NP_001093167.1 Already existis
# 219 NP_001093242.1 Already existis
# 220 NP_001093250.1 Already existis
# 221 NP_001093321.1 Already existis
# 222 NP_001093629.1 Already existis
# 223 NP_001093866.1 Already existis
# 224 NP_001094077.1 Already existis
# 225 NP_001094385.1 Already existis
# 226 NP_001095937.1 Already existis
# 227 NP_001095940.1 Already existis
# 228 NP_001096127.1 Already existis
# 229 NP_001098539.1 Already existis
# 230 NP_001098673.1 Already existis
# 231 NP_001099009.1 Already existis
# 232 NP_001099026.1 Already existis
# 233 NP_001099043.1 Already existis
# 234 NP_001099044.1 Already existis
# 235 NP_001104262.1 Already existis
# 236 NP_001107605.1 Already existis
# 237 NP_001107606.1 Already existis
# 238 NP_001108225.1 Already existis
# 239 NP_001116310.1 Already existis
# 240 NP_001116437.1 Already existis
# 241 NP_001116836.1 Already existis
# 242 NP_001118230.1 Already existis
# 243 NP_001118231.1 Already existis
# 244 NP_001119580.2 Already existis
# 245 NP_001119806.1 Already existis
# 246 NP_001121636.1 Already existis
# 247 NP_001121700.2 Already existis
# 248 NP_001122303.1 Already existis
# 249 NP_001122389.1 Already existis
# 250 NP_001123484.1 Already existis
# 251 NP_001123530.1 Already existis
# 252 NP_001124183.1 Already existis
# 253 NP_001124336.1 Already existis
# 254 NP_001124389.2 Already existis
# 255 NP_001124401.1 Already existis
# 256 NP_001124435.1 Already existis
# 257 NP_001124488.1 Already existis
# 258 NP_001128179.1 Already existis
# 259 NP_001128206.1 Already existis
# 260 NP_001128508.1 Already existis
# 261 NP_001129491.1 Already existis
# 262 NP_001129579.1 Already existis
# 263 NP_001129588.1 Already existis
# 264 NP_001129628.1 Already existis
# 265 NP_001129691.1 Already existis
# 266 NP_001129975.1 Already existis
# 267 NP_001129979.1 Already existis
# 268 NP_001131.3 Already existis
# 269 NP_001131080.1 Already existis
# 270 NP_001131082.1 Already existis
# 271 NP_001131143.1 Already existis
# 272 NP_001132914.2 Already existis
# 273 NP_001134.1 Already existis
# 274 NP_001135.3 Already existis
# 275 NP_001135419.1 Already existis
# 276 NP_001135823.1 Already existis
# 277 NP_001136050.1 Already existis
# 278 NP_001137410.1 Already existis
# 279 NP_001137460.1 Already existis
# 280 NP_001137472.1 Already existis
# 281 NP_001138297.1 Already existis
# 282 NP_001138461.1 Already existis
# 283 NP_001138486.1 Already existis
# 284 NP_001138594.1 Already existis
# 285 NP_001138615.1 Already existis
# 286 NP_001138696.1 Already existis
# 287 NP_001138740.2 Already existis
# 288 NP_001138785.1 Already existis
# 289 NP_001138906.1 Already existis
# 290 NP_001139200.1 Already existis
# 291 NP_001139513.1 Already existis
# 292 NP_001139734.1 Already existis
# 293 NP_001143.2 Already existis
# 294 NP_001149946.1 Already existis
# 295 NP_001152859.1 Already existis
# 296 NP_001153797.1 Already existis
# 297 NP_001154971.1 Already existis
# 298 NP_001156386.1 Already existis
# 299 NP_001156787.2 Already existis
# 300 NP_001157032.1 Already existis
# 301 NP_001157633.1 Already existis
# 302 NP_001157876.1 Already existis
# 303 NP_001158160.1 Already existis
# 304 NP_001159811.1 Already existis
# 305 NP_001159867.1 Already existis
# 306 NP_001161713.1 Already existis
# 307 NP_001162597.1 Already existis
# 308 NP_001165347.1 Already existis
# 309 NP_001165774.1 Already existis
# 310 NP_001165972.1 Already existis
# 311 NP_001166171.1 Already existis
# 312 NP_001167.2 Already existis
# 313 NP_001170777.1 Already existis
# 314 NP_001170990.1 Already existis
# 315 NP_001171754.1 Already existis
# 316 NP_001173.2 Already existis
# 317 NP_001176.1 Already existis
# 318 NP_001177986.1 Already existis
# 319 NP_001179.1 Already existis
# 320 NP_001180559.1 Already existis
# 321 NP_001180575.1 Already existis
# 322 NP_001185.3 Already existis
# 323 NP_001185683.1 Already existis
# 324 NP_001186144.1 Already existis
# 325 NP_001186635.1 Already existis
# 326 NP_001189386.1 Already existis
# 327 NP_001191047.1 Already existis
# 328 NP_001193600.1 Already existis
# 329 NP_001229410.1 Already existis
# 330 NP_001229721.1 Already existis
# 331 NP_001229738.1 Already existis
# 332 NP_001230085.2 Already existis
# 333 NP_001230280.2 Already existis
# 334 NP_001230943.1 Already existis
# 335 NP_001234.3 Already existis
# 336 NP_001236.4 Already existis
# 337 NP_001239.2 Already existis
# 338 NP_001242904.1 Already existis
# 339 NP_001243035.1 Already existis
# 340 NP_001243333.1 Already existis
# 341 NP_001243727.1 Already existis
# 342 NP_001243788.1 Already existis
# 343 NP_001243792.1 Already existis
# 344 NP_001244288.1 Already existis
# 345 NP_001245235.1 Already existis
# 346 NP_001245236.1 Already existis
# 347 NP_001245303.1 Already existis
# 348 NP_001247.3 Already existis
# 349 NP_001253981.1 Already existis
# 350 NP_001255982.1 Already existis
# 351 NP_001257295.1 Already existis
# 352 NP_001257693.1 Already existis
# 353 NP_001263199.1 Already existis
# 354 NP_001263272.2 Already existis
# 355 NP_001264254.1 Already existis
# 356 NP_001265238.2 Already existis
# 357 NP_001265438.2 Already existis
# 358 NP_001268940.1 Already existis
# 359 NP_001269041.1 Already existis
# 360 NP_001269435.1 Already existis
# 361 NP_001269622.1 Already existis
# 362 NP_001273352.1 Already existis
# 363 NP_001273425.1 Already existis
# 364 NP_001273698.1 Already existis
# 365 NP_001275631.1 Already existis
# 366 NP_001275634.1 Already existis
# 367 NP_001275762.1 Already existis
# 368 NP_001276.3 Already existis
# 369 NP_001276091.1 Already existis
# 370 NP_001276900.1 Already existis
# 371 NP_001276972.1 Already existis
# 372 NP_001284365.1 Already existis
# 373 NP_001284517.1 Already existis
# 374 NP_001287719.1 Already existis
# 375 NP_001291317.1 Already existis
# 376 NP_001292102.1 Already existis
# 377 NP_001295101.1 Already existis
# 378 NP_001295124.1 Already existis
# 379 NP_001296.1 Already existis
# 380 NP_001304786.1 Already existis
# 381 NP_001305663.1 Already existis
# 382 NP_001307055.1 Already existis
# 383 NP_001308.1 Already existis
# 384 NP_001308049.1 Already existis
# 385 NP_001308756.2 Already existis
# 386 NP_001308887.1 Already existis
# 387 NP_001308993.1 Already existis
# 388 NP_001309060.1 Already existis
# 389 NP_001309184.1 Already existis
# 390 NP_001316681.1 Already existis
# 391 NP_001317142.1 Already existis
# 392 NP_001317159.1 Already existis
# 393 NP_001328.1 Already existis
# 394 NP_001332772.2 Already existis
# 395 NP_001333882.1 Already existis
# 396 NP_001335124.1 Already existis
# 397 NP_001338.2 Already existis
# 398 NP_001339443.1 Already existis
# 399 NP_001341412.1 Already existis
# 400 NP_001342333.1 Already existis
# 401 NP_001350467.1 Already existis
# 402 NP_001350693.1 Already existis
# 403 NP_001350759.2 Already existis
# 404 NP_001351493.1 Already existis
# 405 NP_001352481.1 Already existis
# 406 NP_001352504.1 Already existis
# 407 NP_001353136.1 Already existis
# 408 NP_001353710.1 Already existis
# 409 NP_001354221.1 Already existis
# 410 NP_001354413.1 Already existis
# 411 NP_001354800.1 Already existis
# 412 NP_001354815.1 Already existis
# 413 NP_001354838.1 Already existis
# 414 NP_001356425.1 Already existis
# 415 NP_001357058.1 Already existis
# 416 NP_001357390.1 Already existis
# 417 NP_001357405.1 Already existis
# 418 NP_001357452.1 Already existis
# 419 NP_001357478.1 Already existis
# 420 NP_001358166.1 Already existis
# 421 NP_001359002.1 Already existis
# 422 NP_001362737.1 Already existis
# 423 NP_001362936.1 Already existis
# 424 NP_001362942.1 Already existis
# 425 NP_001362978.1 Already existis
# 426 NP_001363241.1 Already existis
# 427 NP_001363271.1 Already existis
# 428 NP_001364232.1 Already existis
# 429 NP_001364959.1 Already existis
# 430 NP_001364963.1 Already existis
# 431 NP_001368831.1 Already existis
# 432 NP_001369233.1 Already existis
# 433 NP_001371408.1 Already existis
# 434 NP_001372090.1 Already existis
# 435 NP_001372122.1 Already existis
# 436 NP_001372570.1 Already existis
# 437 NP_001372962.1 Already existis
# 438 NP_001372993.1 Already existis
# 439 NP_001373884.1 Already existis
# 440 NP_001374209.1 Already existis
# 441 NP_001374359.1 Already existis
# 442 NP_001375419.1 Already existis
# 443 NP_001376485.1 Already existis
# 444 NP_001379002.1 Already existis
# 445 NP_001380331.1 Already existis
# 446 NP_001380591.1 Already existis
# 447 NP_001381001.1 Already existis
# 448 NP_001381027.1 Already existis
# 449 NP_001381406.1 Already existis
# 450 NP_001381484.1 Already existis
# 451 NP_001381684.1 Already existis
# 452 NP_001381712.1 Already existis
# 453 NP_001382181.1 Already existis
# 454 NP_001382204.1 Already existis
# 455 NP_001383171.1 Already existis
# 456 NP_001384175.1 Already existis
# 457 NP_001384275.1 Already existis
# 458 NP_001397.1 Already existis
# 459 NP_001424.3 Already existis
# 460 NP_001444.2 Already existis
# 461 NP_001446.1 Already existis
# 462 NP_001452.2 Already existis
# 463 NP_001554.2 Already existis
# 464 NP_001596.2 Already existis
# 465 NP_001600.1 Already existis
# 466 NP_001616.1 Already existis
# 467 NP_001657.3 Already existis
# 468 NP_001658.2 Already existis
# 469 NP_001659.1 Already existis
# 470 NP_001705.2 Already existis
# 471 NP_001750.1 Already existis
# 472 NP_001752.2 Already existis
# 473 NP_001755.1 Already existis
# 474 NP_001769.2 Already existis
# 475 NP_001783.2 Already existis
# 476 NP_001803.2 Already existis
# 477 NP_001806.2 Already existis
# 478 NP_001840.3 Already existis
# 479 NP_001859.1 Already existis
# 480 NP_001862.2 Already existis
# 481 NP_001874.2 Already existis
# 482 NP_001891.2 Already existis
# 483 NP_001897.4 Already existis
# 484 NP_001910.2 Already existis
# 485 NP_001918.3 Already existis
# 486 NP_001932.2 Already existis
# 487 NP_001962.3 Already existis
# 488 NP_001985.2 Already existis
# 489 NP_001991.1 Already existis
# 490 NP_001994.2 Already existis
# 491 NP_002051.2 Already existis
# 492 NP_002079.3 Already existis
# 493 NP_002089.4 Already existis
# 494 NP_002106.2 Already existis
# 495 NP_002107.3 Already existis
# 496 NP_002108.4 Already existis
# 497 NP_002110.1 Already existis
# 498 NP_002114.3 Already existis
# 499 NP_002115.2 Already existis
# 500 NP_002116.2 Already existis
# 501 NP_002136.1 Already existis
# 502 NP_002143.1 Already existis
# 503 NP_002163.2 Already existis
# 504 NP_002171.2 Already existis
# 505 NP_002187.1 Already existis
# 506 NP_002203.1 Already existis
# 507 NP_002204.2 Already existis
# 508 NP_002208.3 Already existis
# 509 NP_002212.3 Already existis
# 510 NP_002236.1 Already existis
# 511 NP_002258.2 Already existis
# 512 NP_002279.2 Already existis
# 513 NP_002304.3 Already existis
# 514 NP_002356.2 Already existis
# 515 NP_002362.1 Already existis
# 516 NP_002371.3 Already existis
# 517 NP_002372.1 Already existis
# 518 NP_002387.1 Already existis
# 519 NP_002418.1 Already existis
# 520 NP_002419.1 Already existis
# 521 NP_002420.1 Already existis
# 522 NP_002437.2 Already existis
# 523 NP_002468.1 Already existis
# 524 NP_002470.2 Already existis
# 525 NP_002472.2 Already existis
# 526 NP_002483.1 Already existis
# 527 NP_002520.2 Already existis
# 528 NP_002522.2 Already existis
# 529 NP_002527.1 Already existis
# 530 NP_002548.3 Already existis
# 531 NP_002551.2 Already existis
# 532 NP_002557.2 Already existis
# 533 NP_002559.2 Already existis
# 534 NP_002571.1 Already existis
# 535 NP_002573.1 Already existis
# 536 NP_002582.3 Already existis
# 537 NP_002584.2 Already existis
# 538 NP_002623.2 Already existis
# 539 NP_002624.2 Already existis
# 540 NP_002630.2 Already existis
# 541 NP_002634.1 Already existis
# 542 NP_002678.3 Already existis
# 543 NP_002707.3 Already existis
# 544 NP_002714.2 Already existis
# 545 NP_002716.1 Already existis
# 546 NP_002718.2 Already existis
# 547 NP_002740.2 Already existis
# 548 NP_002745.1 Already existis
# 549 NP_002760.1 Already existis
# 550 NP_002762.3 Already existis
# 551 NP_002771.2 Already existis
# 552 NP_002808.3 Already existis
# 553 NP_002820.3 Already existis
# 554 NP_002821.1 Already existis
# 555 NP_002838.2 Already existis
# 556 NP_002846.3 Already existis
# 557 NP_002876.2 Already existis
# 558 NP_002885.1 Already existis
# 559 NP_002909.4 Already existis
# 560 NP_002931.2 Already existis
# 561 NP_002971.2 Already existis
# 562 NP_002987.1 Already existis
# 563 NP_002997.2 Already existis
# 564 NP_003016.1 Already existis
# 565 NP_003036.1 Already existis
# 566 NP_003043.3 Already existis
# 567 NP_003095.2 Already existis
# 568 NP_003098.1 Already existis
# 569 NP_003110.1 Already existis
# 570 NP_003194.3 Already existis
# 571 NP_003197.2 Already existis
# 572 NP_003234.2 Already existis
# 573 NP_003239.2 Already existis
# 574 NP_003242.1 Already existis
# 575 NP_003251.2 Already existis
# 576 NP_003256.1 Already existis
# 577 NP_003285.2 Already existis
# 578 NP_003299.2 Already existis
# 579 NP_003346.2 Already existis
# 580 NP_003354.2 Already existis
# 581 NP_003369.2 Already existis
# 582 NP_003401.2 Already existis
# 583 NP_003405.4 Already existis
# 584 NP_003408.1 Already existis
# 585 NP_003414.2 Already existis
# 586 NP_003416.1 Already existis
# 587 NP_003432.1 Already existis
# 588 NP_003452.1 Already existis
# 589 NP_003457.1 Already existis
# 590 NP_003620.3 Already existis
# 591 NP_003669.4 Already existis
# 592 NP_003688.1 Already existis
# 593 NP_003697.2 Already existis
# 594 NP_003700.1 Already existis
# 595 NP_003710.1 Already existis
# 596 NP_003725.1 Already existis
# 597 NP_003727.1 Already existis
# 598 NP_003737.1 Already existis
# 599 NP_003789.1 Already existis
# 600 NP_003801.1 Already existis
# 601 NP_003899.2 Already existis
# 602 NP_003933.1 Already existis
# 603 NP_003935.2 Already existis
# 604 NP_003941.2 Already existis
# 605 NP_003958.2 Already existis
# 606 NP_003966.2 Already existis
# 607 NP_003973.3 Already existis
# 608 NP_003990.1 Already existis
# 609 NP_003991.2 Already existis
# 610 NP_004037.1 Already existis
# 611 NP_004051.1 Already existis
# 612 NP_004082.1 Already existis
# 613 NP_004086.1 Already existis
# 614 NP_004089.1 Already existis
# 615 NP_004152.1 Already existis
# 616 NP_004202.4 Already existis
# 617 NP_004215.2 Already existis
# 618 NP_004225.3 Already existis
# 619 NP_004226.3 Already existis
# 620 NP_004245.2 Already existis
# 621 NP_004303.2 Already existis
# 622 NP_004304.1 Already existis
# 623 NP_004309.2 Already existis
# 624 NP_004320.2 Already existis
# 625 NP_004359.1 Already existis
# 626 NP_004396.1 Already existis
# 627 NP_004413.1 Already existis
# 628 NP_004415.4 Already existis
# 629 NP_004438.3 Already existis
# 630 NP_004442.3 Already existis
# 631 NP_004445.1 Already existis
# 632 NP_004453.3 Already existis
# 633 NP_004454.2 Already existis
# 634 NP_004468.1 Already existis
# 635 NP_004479.1 Already existis
# 636 NP_004491.2 Already existis
# 637 NP_004517.2 Already existis
# 638 NP_004568.2 Already existis
# 639 NP_004575.1 Already existis
# 640 NP_004589.1 Already existis
# 641 NP_004607.1 Already existis
# 642 NP_004624.1 Already existis
# 643 NP_004636.1 Already existis
# 644 NP_004646.3 Already existis
# 645 NP_004676.3 Already existis
# 646 NP_004677.3 Already existis
# 647 NP_004680.2 Already existis
# 648 NP_004701.1 Already existis
# 649 NP_004702.2 Already existis
# 650 NP_004743.1 Already existis
# 651 NP_004751.2 Already existis
# 652 NP_004760.1 Already existis
# 653 NP_004814.1 Already existis
# 654 NP_004819.2 Already existis
# 655 NP_004855.2 Already existis
# 656 NP_004858.1 Already existis
# 657 NP_004877.1 Already existis
# 658 NP_004914.2 Already existis
# 659 NP_004916.1 Already existis
# 660 NP_004919.1 Already existis
# 661 NP_004943.1 Already existis
# 662 NP_004983.1 Already existis
# 663 NP_004985.2 Already existis
# 664 NP_005035.1 Already existis
# 665 NP_005073.2 Already existis
# 666 NP_005110.2 Already existis
# 667 NP_005182.1 Already existis
# 668 NP_005207.3 Already existis
# 669 NP_005221.2 Already existis
# 670 NP_005227.1 Already existis
# 671 NP_005230.1 Already existis
# 672 NP_005234.1 Already existis
# 673 NP_005248.2 Already existis
# 674 NP_005250.1 Already existis
# 675 NP_005251.1 Already existis
# 676 NP_005255.1 Already existis
# 677 NP_005267.2 Already existis
# 678 NP_005295.1 Already existis
# 679 NP_005299.1 Already existis
# 680 NP_005300.1 Already existis
# 681 NP_005307.1 Already existis
# 682 NP_005371.2 Already existis
# 683 NP_005410.1 Already existis
# 684 NP_005427.2 Already existis
# 685 NP_005440.1 Already existis
# 686 NP_005451.2 Already existis
# 687 NP_005471.3 Already existis
# 688 NP_005472.2 Already existis
# 689 NP_005497.1 Already existis
# 690 NP_005504.2 Already existis
# 691 NP_005517.1 Already existis
# 692 NP_005518.3 Already existis
# 693 NP_005538.2 Already existis
# 694 NP_005540.1 Already existis
# 695 NP_005563.1 Already existis
# 696 NP_005572.2 Already existis
# 697 NP_005574.2 Already existis
# 698 NP_005597.3 Already existis
# 699 NP_005680.1 Already existis
# 700 NP_005689.2 Already existis
# 701 NP_005692.1 Already existis
# 702 NP_005697.2 Already existis
# 703 NP_005738.4 Already existis
# 704 NP_005764.2 Already existis
# 705 NP_005783.2 Already existis
# 706 NP_005822.1 Already existis
# 707 NP_005856.1 Already existis
# 708 NP_005903.2 Already existis
# 709 NP_005904.1 Already existis
# 710 NP_005922.2 Already existis
# 711 NP_005947.3 Already existis
# 712 NP_005949.1 Already existis
# 713 NP_005996.2 Already existis
# 714 NP_006056.2 Already existis
# 715 NP_006059.2 Already existis
# 716 NP_006061.2 Already existis
# 717 NP_006064.2 Already existis
# 718 NP_006070.2 Already existis
# 719 NP_006081.1 Already existis
# 720 NP_006112.3 Already existis
# 721 NP_006159.2 Already existis
# 722 NP_006199.2 Already existis
# 723 NP_006219.1 Already existis
# 724 NP_006230.2 Already existis
# 725 NP_006233.1 Already existis
# 726 NP_006252.4 Already existis
# 727 NP_006272.2 Already existis
# 728 NP_006273.1 Already existis
# 729 NP_006284.2 Already existis
# 730 NP_006288.2 Already existis
# 731 NP_006291.2 Already existis
# 732 NP_006298.1 Already existis
# 733 NP_006305.2 Already existis
# 734 NP_006311.3 Already existis
# 735 NP_006334.2 Already existis
# 736 NP_006337.2 Already existis
# 737 NP_006349.1 Already existis
# 738 NP_006352.2 Already existis
# 739 NP_006360.3 Already existis
# 740 NP_006380.1 Already existis
# 741 NP_006389.2 Already existis
# 742 NP_006392.1 Already existis
# 743 NP_006394.1 Already existis
# 744 NP_006437.3 Already existis
# 745 NP_006448.5 Already existis
# 746 NP_006488.2 Already existis
# 747 NP_006504.2 Already existis
# 748 NP_006601.2 Already existis
# 749 NP_006633.1 Already existis
# 750 NP_006644.1 Already existis
# 751 NP_006654.2 Already existis
# 752 NP_006662.3 Already existis
# 753 NP_006707.1 Already existis
# 754 NP_006728.2 Already existis
# 755 NP_006762.3 Already existis
# 756 NP_006764.3 Already existis
# 757 NP_006796.1 Already existis
# 758 NP_006807.1 Already existis
# 759 NP_006816.2 Already existis
# 760 NP_006854.1 Already existis
# 761 NP_006855.3 Already existis
# 762 NP_006864.2 Already existis
# 763 NP_008823.1 Already existis
# 764 NP_008837.1 Already existis
# 765 NP_008844.1 Already existis
# 766 NP_008850.1 Already existis
# 767 NP_008900.3 Already existis
# 768 NP_008913.2 Already existis
# 769 NP_008919.3 Already existis
# 770 NP_008920.5 Already existis
# 771 NP_008933.2 Already existis
# 772 NP_009031.1 Already existis
# 773 NP_009068.2 Already existis
# 774 NP_009069.1 Already existis
# 775 NP_009087.1 Already existis
# 776 NP_009088.1 Already existis
# 777 NP_009094.3 Already existis
# 778 NP_009146.2 Already existis
# 779 NP_009158.3 Already existis
# 780 NP_009173.1 Already existis
# 781 NP_009186.1 Already existis
# 782 NP_009193.2 Already existis
# 783 NP_009196.1 Already existis
# 784 NP_009200.2 Already existis
# 785 NP_031367.2 Already existis
# 786 NP_031372.2 Already existis
# 787 NP_031381.2 Already existis
# 788 NP_031384.1 Already existis
# 789 NP_031397.1 Already existis
# 790 NP_036213.2 Already existis
# 791 NP_036221.2 Already existis
# 792 NP_036233.2 Already existis
# 793 NP_036260.2 Already existis
# 794 NP_036267.1 Already existis
# 795 NP_036275.1 Already existis
# 796 NP_036298.2 Already existis
# 797 NP_036316.1 Already existis
# 798 NP_036318.1 Already existis
# 799 NP_036325.2 Already existis
# 800 NP_036349.1 Already existis
# 801 NP_036362.3 Already existis
# 802 NP_036369.2 Already existis
# 803 NP_036386.1 Already existis
# 804 NP_036450.1 Already existis
# 805 NP_036497.1 Already existis
# 806 NP_036519.2 Already existis
# 807 NP_036544.1 Already existis
# 808 NP_036555.1 Already existis
# 809 NP_036557.1 Already existis
# 810 NP_036567.2 Already existis
# 811 NP_036581.1 Already existis
# 812 NP_036584.1 Already existis
# 813 NP_037404.2 Already existis
# 814 NP_037451.1 Already existis
# 815 NP_037472.2 Already existis
# 816 NP_037506.2 Already existis
# 817 NP_039226.1 Already existis
# 818 NP_054731.2 Already existis
# 819 NP_054789.2 Already existis
# 820 NP_054872.2 Already existis
# 821 NP_055022.2 Already existis
# 822 NP_055028.3 Already existis
# 823 NP_055033.2 Already existis
# 824 NP_055055.1 Already existis
# 825 NP_055072.3 Already existis
# 826 NP_055084.3 Already existis
# 827 NP_055086.1 Already existis
# 828 NP_055090.1 Already existis
# 829 NP_055107.3 Already existis
# 830 NP_055129.2 Already existis
# 831 NP_055134.2 Already existis
# 832 NP_055146.1 Already existis
# 833 NP_055152.1 Already existis
# 834 NP_055157.1 Already existis
# 835 NP_055174.1 Already existis
# 836 NP_055175.2 Already existis
# 837 NP_055183.2 Already existis
# 838 NP_055232.1 Already existis
# 839 NP_055288.1 Already existis
# 840 NP_055293.1 Already existis
# 841 NP_055313.1 Already existis
# 842 NP_055324.2 Already existis
# 843 NP_055385.3 Already existis
# 844 NP_055394.2 Already existis
# 845 NP_055397.1 Already existis
# 846 NP_055402.2 Already existis
# 847 NP_055403.2 Already existis
# 848 NP_055464.1 Already existis
# 849 NP_055469.3 Already existis
# 850 NP_055509.2 Already existis
# 851 NP_055531.1 Already existis
# 852 NP_055554.1 Already existis
# 853 NP_055557.2 Already existis
# 854 NP_055572.1 Already existis
# 855 NP_055573.3 Already existis
# 856 NP_055634.3 Already existis
# 857 NP_055760.1 Already existis
# 858 NP_055764.2 Already existis
# 859 NP_055842.2 Already existis
# 860 NP_056089.1 Already existis
# 861 NP_056117.1 Already existis
# 862 NP_056123.2 Already existis
# 863 NP_056155.1 Already existis
# 864 NP_056207.3 Already existis
# 865 NP_056216.2 Already existis
# 866 NP_056246.3 Already existis
# 867 NP_056249.1 Already existis
# 868 NP_056255.2 Already existis
# 869 NP_056300.3 Already existis
# 870 NP_056347.1 Already existis
# 871 NP_056360.2 Already existis
# 872 NP_056485.2 Already existis
# 873 NP_056494.1 Already existis
# 874 NP_056509.2 Already existis
# 875 NP_056520.2 Already existis
# 876 NP_056535.1 Already existis
# 877 NP_056949.4 Already existis
# 878 NP_056952.2 Already existis
# 879 NP_056975.1 Already existis
# 880 NP_056994.3 Already existis
# 881 NP_057026.3 Already existis
# 882 NP_057043.1 Already existis
# 883 NP_057053.1 Already existis
# 884 NP_057060.2 Already existis
# 885 NP_057108.2 Already existis
# 886 NP_057114.5 Already existis
# 887 NP_057128.2 Already existis
# 888 NP_057187.1 Already existis
# 889 NP_057195.2 Already existis
# 890 NP_057208.3 Already existis
# 891 NP_057218.1 Already existis
# 892 NP_057227.2 Already existis
# 893 NP_057256.2 Already existis
# 894 NP_057258.3 Already existis
# 895 NP_057268.1 Already existis
# 896 NP_057280.2 Already existis
# 897 NP_057300.2 Already existis
# 898 NP_057339.1 Already existis
# 899 NP_057416.1 Already existis
# 900 NP_057438.3 Already existis
# 901 NP_057441.1 Already existis
# 902 NP_057457.1 Already existis
# 903 NP_057467.1 Already existis
# 904 NP_057537.1 Already existis
# 905 NP_057538.1 Already existis
# 906 NP_057542.2 Already existis
# 907 NP_057594.5 Already existis
# 908 NP_057603.1 Already existis
# 909 NP_057632.2 Already existis
# 910 NP_057641.1 Already existis
# 911 NP_057645.1 Already existis
# 912 NP_057657.2 Already existis
# 913 NP_057693.4 Already existis
# 914 NP_057731.1 Already existis
# 915 NP_057732.2 Already existis
# 916 NP_057953.1 Already existis
# 917 NP_059110.2 Already existis
# 918 NP_059116.3 Already existis
# 919 NP_059132.1 Already existis
# 920 NP_060031.1 Already existis
# 921 NP_060036.2 Already existis
# 922 NP_060052.3 Already existis
# 923 NP_060082.2 Already existis
# 924 NP_060102.1 Already existis
# 925 NP_060122.2 Already existis
# 926 NP_060131.2 Already existis
# 927 NP_060134.2 Already existis
# 928 NP_060138.1 Already existis
# 929 NP_060161.2 Already existis
# 930 NP_060173.1 Already existis
# 931 NP_060189.3 Already existis
# 932 NP_060191.3 Already existis
# 933 NP_060220.3 Already existis
# 934 NP_060238.3 Already existis
# 935 NP_060247.2 Already existis
# 936 NP_060261.2 Already existis
# 937 NP_060271.1 Already existis
# 938 NP_060272.3 Already existis
# 939 NP_060276.2 Already existis
# 940 NP_060298.2 Already existis
# 941 NP_060349.1 Already existis
# 942 NP_060352.1 Already existis
# 943 NP_060358.2 Already existis
# 944 NP_060381.2 Already existis
# 945 NP_060401.3 Already existis
# 946 NP_060436.4 Already existis
# 947 NP_060460.4 Already existis
# 948 NP_060483.3 Already existis
# 949 NP_060495.2 Already existis
# 950 NP_060505.2 Already existis
# 951 NP_060556.2 Already existis
# 952 NP_060561.3 Already existis
# 953 NP_060567.1 Already existis
# 954 NP_060589.1 Already existis
# 955 NP_060601.4 Already existis
# 956 NP_060679.1 Already existis
# 957 NP_060741.3 Already existis
# 958 NP_060743.2 Already existis
# 959 NP_060810.2 Already existis
# 960 NP_060813.2 Already existis
# 961 NP_060835.1 Already existis
# 962 NP_060857.2 Already existis
# 963 NP_060867.2 Already existis
# 964 NP_060884.1 Already existis
# 965 NP_060886.1 Already existis
# 966 NP_060927.1 Already existis
# 967 NP_060961.3 Already existis
# 968 NP_061026.2 Already existis
# 969 NP_061029.2 Already existis
# 970 NP_061092.3 Already existis
# 971 NP_061122.4 Already existis
# 972 NP_061130.1 Already existis
# 973 NP_061140.1 Already existis
# 974 NP_061183.2 Already existis
# 975 NP_061185.1 Already existis
# 976 NP_061322.2 Already existis
# 977 NP_061730.1 Already existis
# 978 NP_061734.1 Already existis
# 979 NP_061738.1 Already existis
# 980 NP_061754.1 Already existis
# 981 NP_061759.1 Already existis
# 982 NP_061761.1 Already existis
# 983 NP_061816.1 Already existis
# 984 NP_061830.3 Already existis
# 985 NP_061866.1 Already existis
# 986 NP_061893.2 Already existis
# 987 NP_061948.1 Already existis
# 988 NP_061959.2 Already existis
# 989 NP_061961.2 Already existis
# 990 NP_061983.2 Already existis
# 991 NP_062551.1 Already existis
# 992 NP_062558.1 Already existis
# 993 NP_062817.2 Already existis
# 994 NP_062828.3 Already existis
# 995 NP_062832.1 Already existis
# 996 NP_063946.2 Already existis
# 997 NP_063950.2 Already existis
# 998 NP_064425.2 Already existis
# 999 NP_064440.1 Already existis
# 1000 NP_064530.1 Already existis
# 1001 NP_064536.2 Already existis
# 1002 NP_064548.1 Already existis
# 1003 NP_064562.1 Already existis
# 1004 NP_064612.2 Already existis
# 1005 NP_064715.1 Already existis
# 1006 NP_065089.2 Already existis
# 1007 NP_065137.1 Already existis
# 1008 NP_065166.2 Already existis
# 1009 NP_065184.2 Already existis
# 1010 NP_065574.4 Already existis
# 1011 NP_065682.2 Already existis
# 1012 NP_065688.1 Already existis
# 1013 NP_065764.1 Already existis
# 1014 NP_065822.2 Already existis
# 1015 NP_065838.2 Already existis
# 1016 NP_065846.1 Already existis
# 1017 NP_065879.1 Already existis
# 1018 NP_065906.1 Already existis
# 1019 NP_065919.3 Already existis
# 1020 NP_065930.2 Already existis
# 1021 NP_065941.2 Already existis
# 1022 NP_065945.2 Already existis
# 1023 NP_065983.1 Already existis
# 1024 NP_066275.3 Already existis
# 1025 NP_066278.3 Already existis
# 1026 NP_066282.1 Already existis
# 1027 NP_066284.2 Already existis
# 1028 NP_066384.2 Already existis
# 1029 NP_066959.1 Already existis
# 1030 NP_066971.2 Already existis
# 1031 NP_066978.1 Already existis
# 1032 NP_066981.2 Already existis
# 1033 NP_067020.2 Already existis
# 1034 NP_067078.1 Already existis
# 1035 NP_067633.2 Already existis
# 1036 NP_067678.1 Already existis
# 1037 NP_068555.2 Already existis
# 1038 NP_068743.3 Already existis
# 1039 NP_068767.3 Already existis
# 1040 NP_068779.1 Already existis
# 1041 NP_068800.2 Already existis
# 1042 NP_071319.3 Already existis
# 1043 NP_071361.2 Already existis
# 1044 NP_071375.1 Already existis
# 1045 NP_071417.2 Already existis
# 1046 NP_071450.2 Already existis
# 1047 NP_071505.2 Already existis
# 1048 NP_071764.3 Already existis
# 1049 NP_071882.1 Already existis
# 1050 NP_071894.1 Already existis
# 1051 NP_071896.8 Already existis
# 1052 NP_071931.2 Already existis
# 1053 NP_072095.2 Already existis
# 1054 NP_073152.2 Already existis
# 1055 NP_073210.1 Already existis
# 1056 NP_073563.1 Already existis
# 1057 NP_073571.1 Already existis
# 1058 NP_073586.5 Already existis
# 1059 NP_073597.2 Already existis
# 1060 NP_073624.2 Already existis
# 1061 NP_073713.2 Already existis
# 1062 NP_073741.3 Already existis
# 1063 NP_073751.3 Already existis
# 1064 NP_075044.2 Already existis
# 1065 NP_075047.1 Already existis
# 1066 NP_075055.1 Already existis
# 1067 NP_075389.2 Already existis
# 1068 NP_075390.1 Already existis
# 1069 NP_076433.3 Already existis
# 1070 NP_076931.1 Already existis
# 1071 NP_076957.3 Already existis
# 1072 NP_077001.1 Already existis
# 1073 NP_077270.1 Already existis
# 1074 NP_077274.3 Already existis
# 1075 NP_077310.1 Already existis
# 1076 NP_077721.2 Already existis
# 1077 NP_077733.3 Already existis
# 1078 NP_077734.2 Already existis
# 1079 NP_078777.1 Already existis
# 1080 NP_078781.3 Already existis
# 1081 NP_078801.3 Already existis
# 1082 NP_078870.1 Already existis
# 1083 NP_078873.2 Already existis
# 1084 NP_078904.4 Already existis
# 1085 NP_078932.2 Already existis
# 1086 NP_078962.4 Already existis
# 1087 NP_079003.2 Already existis
# 1088 NP_079010.2 Already existis
# 1089 NP_079012.3 Already existis
# 1090 NP_079062.1 Already existis
# 1091 NP_079074.2 Already existis
# 1092 NP_079085.2 Already existis
# 1093 NP_079104.3 Already existis
# 1094 NP_079107.6 Already existis
# 1095 NP_079124.1 Already existis
# 1096 NP_079195.3 Already existis
# 1097 NP_079203.4 Already existis
# 1098 NP_079217.2 Already existis
# 1099 NP_079243.1 Already existis
# 1100 NP_079272.4 Already existis
# 1101 NP_079316.2 Already existis
# 1102 NP_079321.3 Already existis
# 1103 NP_079331.3 Already existis
# 1104 NP_079368.3 Already existis
# 1105 NP_079388.3 Already existis
# 1106 NP_079389.2 Already existis
# 1107 NP_079406.4 Already existis
# 1108 NP_079467.3 Already existis
# 1109 NP_079478.1 Already existis
# 1110 NP_079520.1 Already existis
# 1111 NP_079521.1 Already existis
# 1112 NP_079544.1 Already existis
# 1113 NP_085139.2 Already existis
# 1114 NP_085911.2 Already existis
# 1115 NP_110385.1 Already existis
# 1116 NP_110415.1 Already existis
# 1117 NP_110429.1 Already existis
# 1118 NP_110447.2 Already existis
# 1119 NP_112229.1 Already existis
# 1120 NP_112241.2 Already existis
# 1121 NP_112489.3 Already existis
# 1122 NP_112573.1 Already existis
# 1123 NP_112587.2 Already existis
# 1124 NP_112600.1 Already existis
# 1125 NP_112601.3 Already existis
# 1126 NP_112603.2 Already existis
# 1127 NP_113603.1 Already existis
# 1128 NP_113627.1 Already existis
# 1129 NP_113637.3 Already existis
# 1130 NP_113663.2 Already existis
# 1131 NP_113676.2 Already existis
# 1132 NP_114123.2 Already existis
# 1133 NP_114127.3 Already existis
# 1134 NP_114143.1 Already existis
# 1135 NP_114166.1 Already existis
# 1136 NP_114167.2 Already existis
# 1137 NP_114407.3 Already existis
# 1138 NP_115485.1 Already existis
# 1139 NP_115501.2 Already existis
# 1140 NP_115505.2 Already existis
# 1141 NP_115516.1 Already existis
# 1142 NP_115545.3 Already existis
# 1143 NP_115584.1 Already existis
# 1144 NP_115619.4 Already existis
# 1145 NP_115622.2 Already existis
# 1146 NP_115640.1 Already existis
# 1147 NP_115669.3 Already existis
# 1148 NP_115679.2 Already existis
# 1149 NP_115687.2 Already existis
# 1150 NP_115743.1 Already existis
# 1151 NP_115761.2 Already existis
# 1152 NP_115785.1 Already existis
# 1153 NP_115793.1 Already existis
# 1154 NP_115806.1 Already existis
# 1155 NP_115814.1 Already existis
# 1156 NP_115824.1 Already existis
# 1157 NP_115850.2 Already existis
# 1158 NP_115865.1 Already existis
# 1159 NP_115874.3 Already existis
# 1160 NP_115890.2 Already existis
# 1161 NP_115904.1 Already existis
# 1162 NP_115914.1 Already existis
# 1163 NP_115986.3 Already existis
# 1164 NP_116078.4 Already existis
# 1165 NP_116124.2 Already existis
# 1166 NP_116171.3 Already existis
# 1167 NP_116176.2 Already existis
# 1168 NP_116191.2 Already existis
# 1169 NP_116193.2 Already existis
# 1170 NP_116202.2 Already existis
# 1171 NP_116213.1 Already existis
# 1172 NP_116217.1 Already existis
# 1173 NP_116225.2 Already existis
# 1174 NP_116249.2 Already existis
# 1175 NP_116254.4 Already existis
# 1176 NP_116569.1 Already existis
# 1177 NP_116752.1 Already existis
# 1178 NP_149022.3 Already existis
# 1179 NP_149023.2 Already existis
# 1180 NP_149040.3 Already existis
# 1181 NP_149048.2 Already existis
# 1182 NP_149092.3 Already existis
# 1183 NP_149093.1 Already existis
# 1184 NP_149094.3 Already existis
# 1185 NP_149111.1 Already existis
# 1186 NP_149115.2 Already existis
# 1187 NP_149123.3 Already existis
# 1188 NP_149129.2 Already existis
# 1189 NP_149461.2 Already existis
# 1190 NP_150285.3 Already existis
# 1191 NP_201574.4 Already existis
# 1192 NP_203528.3 Already existis
# 1193 NP_219481.1 Already existis
# 1194 NP_219485.1 Already existis
# 1195 NP_277047.2 Already existis
# 1196 NP_439897.1 Already existis
# 1197 NP_443078.1 Already existis
# 1198 NP_443131.2 Already existis
# 1199 NP_443148.1 Already existis
# 1200 NP_443169.2 Already existis
# 1201 NP_443177.1 Already existis
# 1202 NP_443187.1 Already existis
# 1203 NP_443189.1 Already existis
# 1204 NP_443193.1 Already existis
# 1205 NP_443198.1 Already existis
# 1206 NP_443202.3 Already existis
# 1207 NP_443729.1 Already existis
# 1208 NP_444272.1 Already existis
# 1209 NP_444279.2 Already existis
# 1210 NP_444507.1 Already existis
# 1211 NP_446464.1 Already existis
# 1212 NP_478067.2 Already existis
# 1213 NP_478126.1 Already existis
# 1214 NP_525124.3 Already existis
# 1215 NP_536356.3 Already existis
# 1216 NP_536737.3 Already existis
# 1217 NP_536739.1 Already existis
# 1218 NP_542164.2 Already existis
# 1219 NP_542174.1 Already existis
# 1220 NP_542188.1 Already existis
# 1221 NP_542383.1 Already existis
# 1222 NP_542397.1 Already existis
# 1223 NP_542763.1 Already existis
# 1224 NP_542784.1 Already existis
# 1225 NP_542785.1 Already existis
# 1226 NP_543136.1 Already existis
# 1227 NP_543139.4 Already existis
# 1228 NP_543149.1 Already existis
# 1229 NP_550433.1 Already existis
# 1230 NP_569082.2 Already existis
# 1231 NP_570116.2 Already existis
# 1232 NP_573403.1 Already existis
# 1233 NP_573441.2 Already existis
# 1234 NP_597724.1 Already existis
# 1235 NP_598004.1 Already existis
# 1236 NP_598194.1 Already existis
# 1237 NP_612143.2 Already existis
# 1238 NP_612412.2 Already existis
# 1239 NP_612424.1 Already existis
# 1240 NP_620049.1 Already existis
# 1241 NP_620135.1 Already existis
# 1242 NP_620145.2 Already existis
# 1243 NP_620155.1 Already existis
# 1244 NP_620410.3 Already existis
# 1245 NP_620414.1 Already existis
# 1246 NP_620591.3 Already existis
# 1247 NP_631912.3 Already existis
# 1248 NP_631918.3 Already existis
# 1249 NP_644813.1 Already existis
# 1250 NP_647593.1 Already existis
# 1251 NP_653186.2 Already existis
# 1252 NP_653244.2 Already existis
# 1253 NP_653249.1 Already existis
# 1254 NP_653272.2 Already existis
# 1255 NP_653283.3 Already existis
# 1256 NP_653306.1 Already existis
# 1257 NP_653312.2 Already existis
# 1258 NP_653320.3 Already existis
# 1259 NP_653326.3 Already existis
# 1260 NP_658983.3 Already existis
# 1261 NP_659411.2 Already existis
# 1262 NP_660208.2 Already existis
# 1263 NP_660213.1 Already existis
# 1264 NP_660306.1 Already existis
# 1265 NP_660313.1 Already existis
# 1266 NP_660334.3 Already existis
# 1267 NP_660350.2 Already existis
# 1268 NP_660358.2 Already existis
# 1269 NP_665875.1 Already existis
# 1270 NP_665893.2 Already existis
# 1271 NP_666019.1 Already existis
# 1272 NP_667339.1 Already existis
# 1273 NP_667340.2 Already existis
# 1274 NP_683763.2 Already existis
# 1275 NP_683765.2 Already existis
# 1276 NP_683766.2 Already existis
# 1277 NP_689449.1 Already existis
# 1278 NP_689473.1 Already existis
# 1279 NP_689481.2 Already existis
# 1280 NP_689498.1 Already existis
# 1281 NP_689504.2 Already existis
# 1282 NP_689560.3 Already existis
# 1283 NP_689587.1 Already existis
# 1284 NP_689607.2 Already existis
# 1285 NP_689608.2 Already existis
# 1286 NP_689624.2 Already existis
# 1287 NP_689671.2 Already existis
# 1288 NP_689676.2 Already existis
# 1289 NP_689688.2 Already existis
# 1290 NP_689689.2 Already existis
# 1291 NP_689704.4 Already existis
# 1292 NP_689714.2 Already existis
# 1293 NP_689732.2 Already existis
# 1294 NP_689753.2 Already existis
# 1295 NP_689757.2 Already existis
# 1296 NP_689758.1 Already existis
# 1297 NP_689771.3 Already existis
# 1298 NP_689786.2 Already existis
# 1299 NP_689814.1 Already existis
# 1300 NP_689826.2 Already existis
# 1301 NP_689839.1 Already existis
# 1302 NP_689896.1 Already existis
# 1303 NP_689963.2 Already existis
# 1304 NP_689976.2 Already existis
# 1305 NP_689986.2 Already existis
# 1306 NP_689996.4 Already existis
# 1307 NP_689997.3 Already existis
# 1308 NP_690008.2 Already existis
# 1309 NP_690875.1 Already existis
# 1310 NP_694822.2 Already existis
# 1311 NP_694939.2 Already existis
# 1312 NP_694945.2 Already existis
# 1313 NP_694967.3 Already existis
# 1314 NP_694999.3 Already existis
# 1315 NP_695001.2 Already existis
# 1316 NP_699160.2 Already existis
# 1317 NP_699189.2 Already existis
# 1318 NP_699192.1 Already existis
# 1319 NP_703149.1 Already existis
# 1320 NP_705718.1 Already existis
# 1321 NP_714922.1 Already existis
# 1322 NP_722450.1 Already existis
# 1323 NP_733745.1 Already existis
# 1324 NP_733821.1 Already existis
# 1325 NP_733932.1 Already existis
# 1326 NP_751951.1 Already existis
# 1327 NP_757384.1 Already existis
# 1328 NP_758961.1 Already existis
# 1329 NP_775102.3 Already existis
# 1330 NP_775487.2 Already existis
# 1331 NP_775736.2 Already existis
# 1332 NP_775764.2 Already existis
# 1333 NP_775781.1 Already existis
# 1334 NP_775794.2 Already existis
# 1335 NP_775836.4 Already existis
# 1336 NP_775858.2 Already existis
# 1337 NP_775864.3 Already existis
# 1338 NP_775872.1 Already existis
# 1339 NP_775890.2 Already existis
# 1340 NP_775900.2 Already existis
# 1341 NP_775913.2 Already existis
# 1342 NP_776173.3 Already existis
# 1343 NP_776248.1 Already existis
# 1344 NP_777562.1 Already existis
# 1345 NP_777565.3 Already existis
# 1346 NP_777637.1 Already existis
# 1347 NP_778146.2 Already existis
# 1348 NP_783161.1 Already existis
# 1349 NP_783165.1 Already existis
# 1350 NP_783866.3 Already existis
# 1351 NP_787052.3 Already existis
# 1352 NP_789744.1 Already existis
# 1353 NP_803136.2 Already existis
# 1354 NP_813977.1 Already existis
# 1355 NP_817084.2 Already existis
# 1356 NP_819056.1 Already existis
# 1357 NP_848521.1 Already existis
# 1358 NP_848547.4 Already existis
# 1359 NP_848563.1 Already existis
# 1360 NP_848591.2 Already existis
# 1361 NP_848635.2 Already existis
# 1362 NP_848639.2 Already existis
# 1363 NP_848648.2 Already existis
# 1364 NP_848651.2 Already existis
# 1365 NP_848658.3 Already existis
# 1366 NP_848663.1 Already existis
# 1367 NP_849196.2 Already existis
# 1368 NP_851849.1 Already existis
# 1369 NP_853512.1 Already existis
# 1370 NP_853642.1 Already existis
# 1371 NP_859062.1 Already existis
# 1372 NP_859067.2 Already existis
# 1373 NP_859074.1 Already existis
# 1374 NP_861441.2 Already existis
# 1375 NP_861524.2 Already existis
# 1376 NP_872293.2 Already existis
# 1377 NP_872301.2 Already existis
# 1378 NP_872311.2 Already existis
# 1379 NP_872328.1 Already existis
# 1380 NP_872348.2 Already existis
# 1381 NP_872349.1 Already existis
# 1382 NP_872378.3 Already existis
# 1383 NP_872415.1 Already existis
# 1384 NP_872429.2 Already existis
# 1385 NP_872578.1 Already existis
# 1386 NP_878905.2 Already existis
# 1387 NP_891552.1 Already existis
# 1388 NP_891554.1 Already existis
# 1389 NP_899058.1 Already existis
# 1390 NP_899061.1 Already existis
# 1391 NP_919227.2 Already existis
# 1392 NP_919231.1 Already existis
# 1393 NP_919274.1 Already existis
# 1394 NP_919288.2 Already existis
# 1395 NP_919307.1 Already existis
# 1396 NP_919417.1 Already existis
# 1397 NP_932079.1 Already existis
# 1398 NP_937784.2 Already existis
# 1399 NP_937791.2 Already existis
# 1400 NP_937825.2 Already existis
# 1401 NP_940873.2 Already existis
# 1402 NP_940876.2 Already existis
# 1403 NP_940897.2 Already existis
# 1404 NP_940932.2 Already existis
# 1405 NP_940937.1 Already existis
# 1406 NP_940974.2 Already existis
# 1407 NP_940986.1 Already existis
# 1408 NP_942147.3 Already existis
# 1409 NP_944605.2 Already existis
# 1410 NP_945345.2 Already existis
# 1411 NP_954584.2 Already existis
# 1412 NP_954586.4 Already existis
# 1413 NP_954993.1 Already existis
# 1414 NP_955352.1 Already existis
# 1415 NP_955805.1 Already existis
# 1416 NP_958804.2 Already existis
# 1417 NP_958815.1 Already existis
# 1418 NP_981953.2 Already existis
# 1419 NP_991111.2 Already existis
# 1420 NP_995321.1 Already existis
# 1421 NP_996892.1 Already existis
# 1422 NP_996898.2 Already existis
# 1423 NP_996996.1 Already existis
# 1424 NP_996998.1 Already existis
# 1425 NP_997218.2 Already existis
# 1426 NP_997222.1 Already existis
# 1427 NP_997243.2 Already existis
# 1428 NP_997249.2 Already existis
# 1429 NP_997254.3 Already existis
# 1430 NP_997290.2 Already existis
# 1431 NP_998759.1 Already existis
# 1432 NP_998770.2 Already existis
# 1433 NP_999627.2 Already existis
# 1434 NP_999876.2 Already existis
# 1435 NP_000013.2 Already existis
# 1436 NP_000018.2 Already existis
# 1437 NP_000113.1 Already existis
# 1438 NP_000180.2 Already existis
# 1439 NP_000215.1 Already existis
# 1440 NP_000242.1 Already existis
# 1441 NP_000305.3 Already existis
# 1442 NP_000374.1 Already existis
# 1443 NP_000443.2 Already existis
# 1444 NP_000526.2 Already existis
# 1445 NP_000536.6 Already existis
# 1446 NP_000588.3 Already existis
# 1447 NP_000773.2 Already existis
# 1448 NP_000972.1 Already existis
# 1449 NP_001001411.2 Already existis
# 1450 NP_001001888.3 Already existis
# 1451 NP_001001916.2 Already existis
# 1452 NP_001001958.1 Already existis
# ...
# 8685 NP_001229619.1 Already existis
# 8686 NP_001230008.1 Already existis
# 8687 NP_001243615.1 Already existis
# 8688 NP_001243798.1 Already existis
# 8689 NP_001243800.1 Already existis
# 8690 NP_001243801.1 Already existis
# 8691 NP_001243802.1 Already existis
# 8692 NP_001243803.1 Already existis
# 8693 NP_001244299.1 Already existis
# 8694 NP_001252506.1 Already existis
# 8695 NP_001257530.1 Already existis
# 8696 NP_001263642.1 Already existis
# 8697 NP_001264233.1 Already existis
# 8698 NP_001264262.1 Already existis
# 8699 NP_001265488.1 Already existis
# 8700 NP_001269421.1 Already existis
# 8701 NP_001274373.1 Already existis
# 8702 NP_001276903.1 Already existis
# 8703 NP_001277141.2 Already existis
# 8704 NP_001278309.1 Already existis
# 8705 NP_001278391.1 Already existis
# 8706 NP_001278392.1 Already existis
# 8707 NP_001278458.1 Already existis
# 8708 NP_001278469.1 Already existis
# 8709 NP_001287820.1 Already existis
# 8710 NP_001288711.1 Already existis
# 8711 NP_001289038.1 Already existis
# 8712 NP_001291348.1 Already existis
# 8713 NP_001292997.1 Already existis
# 8714 NP_001293001.1 Already existis
# 8715 NP_001297063.1 Already existis
# 8716 NP_001297148.1 Already existis
# 8717 NP_001303985.1 Already existis
# 8718 NP_001335886.1 Already existis
# 8719 NP_001342126.2 Already existis
# 8720 NP_001342150.1 Already existis
# 8721 NP_001342210.1 Already existis
# 8722 NP_001342408.1 Already existis
# 8723 NP_001344937.1 Already existis
# 8724 NP_001346013.1 Already existis
# 8725 NP_001349914.1 Already existis
# 8726 NP_001352171.1 Already existis
# 8727 NP_001352318.2 Already existis
# 8728 NP_001354585.1 Already existis
# 8729 NP_001354736.1 Already existis
# 8730 NP_001355057.1 Already existis
# 8731 NP_001369426.1 Already existis
# 8732 NP_001372211.1 Already existis
# 8733 NP_001372398.2 Already existis
# 8734 NP_001380320.1 Already existis
# 8735 NP_001383885.1 Already existis
# 8736 NP_001384335.1 Already existis
# 8737 NP_001636.1 Already existis
# 8738 NP_001898.1 Already existis
# 8739 NP_001901.1 Already existis
# 8740 NP_002774.2 Already existis
# 8741 NP_002786.2 Already existis
# 8742 NP_003538.1 Already existis
# 8743 NP_003566.1 Already existis
# 8744 NP_003692.1 Already existis
# 8745 NP_003787.2 Already existis
# 8746 NP_003976.2 Already existis
# 8747 NP_004252.2 Already existis
# 8748 NP_004463.1 Already existis
# 8749 NP_004979.3 Already existis
# 8750 NP_005353.1 Already existis
# 8751 NP_005743.5 Already existis
# 8752 NP_005963.4 Already existis
# 8753 NP_005992.1 Already existis
# 8754 NP_006090.2 Already existis
# 8755 NP_006322.4 Already existis
# 8756 NP_006463.3 Already existis
# 8757 NP_008941.3 Already existis
# 8758 NP_036501.2 Already existis
# 8759 NP_037496.4 Already existis
# 8760 NP_039224.2 Already existis
# 8761 NP_054721.1 Already existis
# 8762 NP_055064.1 Already existis
# 8763 NP_055413.2 Already existis
# 8764 NP_055632.2 Already existis
# 8765 NP_056399.1 Already existis
# 8766 NP_060553.4 Already existis
# 8767 NP_065139.2 Already existis
# 8768 NP_065140.3 Already existis
# 8769 NP_065159.1 Already existis
# 8770 NP_065760.1 Already existis
# 8771 NP_068375.3 Already existis
# 8772 NP_071336.1 Already existis
# 8773 NP_077005.2 Already existis
# 8774 NP_078959.3 Already existis
# 8775 NP_079140.2 Already existis
# 8776 NP_079486.1 Already existis
# 8777 NP_085143.1 Already existis
# 8778 NP_112181.3 Already existis
# 8779 NP_112186.3 Already existis
# 8780 NP_112214.3 Already existis
# 8781 NP_112599.2 Already existis
# 8782 NP_114107.2 Already existis
# 8783 NP_114118.2 Already existis
# 8784 NP_115543.3 Already existis
# 8785 NP_116072.2 Already existis
# 8786 NP_116739.1 Already existis
# 8787 NP_149420.4 Already existis
# 8788 NP_277021.2 Already existis
# 8789 NP_277053.2 Already existis
# 8790 NP_443118.1 Already existis
# 8791 NP_525125.2 Already existis
# 8792 NP_598328.1 Already existis
# 8793 NP_612356.2 Already existis
# 8794 NP_612377.4 Already existis
# 8795 NP_619638.2 Already existis
# 8796 NP_619651.3 Already existis
# 8797 NP_644814.1 Already existis
# 8798 NP_653299.4 Already existis
# 8799 NP_663629.1 Already existis
# 8800 NP_689343.3 Already existis
# 8801 NP_689479.1 Already existis
# 8802 NP_689503.3 Already existis
# 8803 NP_689971.4 Already existis
# 8804 NP_689975.2 Already existis
# 8805 NP_689994.2 Already existis
# 8806 NP_690878.2 Already existis
# 8807 NP_694533.1 Already existis
# 8808 NP_775183.1 Already existis
# 8809 NP_775808.4 Already existis
# 8810 NP_776193.3 Already existis
# 8811 NP_778227.3 Already existis
# 8812 NP_853637.2 Already existis
# 8813 NP_872321.2 Already existis
# 8814 NP_872604.1 Already existis
# 8815 NP_878315.2 Already existis
# 8816 NP_937824.3 Already existis
# 8817 NP_982283.2 Already existis
# 8818 NP_997202.3 Already existis
# 8819 NP_997238.2 Already existis
# 8820 NP_997299.2 Already existis
# 8821 NP_997301.2 Already existis
# 8822 NP_000449.1 Already existis
# 8823 NP_000673.2 Already existis
# 8824 NP_000698.1 Already existis
# 8825 NP_001001963.1 Already existis
# 8826 NP_001004730.1 Already existis
# 8827 NP_001005161.2 Already existis
# 8828 NP_001005166.3 Already existis
# 8829 NP_001005177.3 Already existis
# 8830 NP_001005237.1 Already existis
# 8831 NP_001012776.1 Already existis
# 8832 NP_001034254.2 Already existis
# 8833 NP_001041666.1 Already existis
# 8834 NP_001074259.1 Already existis
# 8835 NP_001074306.3 Already existis
# 8836 NP_001093143.1 Already existis
# 8837 NP_001093164.1 Already existis
# 8838 NP_001094861.1 Already existis
# 8839 NP_001096046.2 Already existis
# 8840 NP_001098990.1 Already existis
# 8841 NP_001116436.3 Already existis
# 8842 NP_001131020.1 Already existis
# 8843 NP_001138669.1 Already existis
# 8844 NP_001139505.1 Already existis
# 8845 NP_001139629.1 Already existis
# 8846 NP_001158051.1 Already existis
# 8847 NP_001182526.1 Already existis
# 8848 NP_001182566.1 Already existis
# 8849 NP_001230650.1 Already existis
# 8850 NP_001244197.1 Already existis
# 8851 NP_001269204.1 Already existis
# 8852 NP_001272414.1 Already existis
# 8853 NP_001276033.1 Already existis
# 8854 NP_001276989.1 Already existis
# 8855 NP_001277193.1 Already existis
# 8856 NP_001293070.1 Already existis
# 8857 NP_001333683.1 Already existis
# 8858 NP_001345339.1 Already existis
# 8859 NP_001352906.1 Already existis
# 8860 NP_001355064.1 Already existis
# 8861 NP_001363161.1 Already existis
# 8862 NP_001369297.1 Already existis
# 8863 NP_001371692.1 Already existis
# 8864 NP_001371924.1 Already existis
# 8865 NP_001382430.1 Already existis
# 8866 NP_001382882.1 Already existis
# 8867 NP_001382946.1 Already existis
# 8868 NP_001637.1 Already existis
# 8869 NP_002034.3 Already existis
# 8870 NP_002417.2 Already existis
# 8871 NP_002481.3 Already existis
# 8872 NP_002686.3 Already existis
# 8873 NP_002949.2 Already existis
# 8874 NP_002975.1 Already existis
# 8875 NP_003900.1 Already existis
# 8876 NP_004314.6 Already existis
# 8877 NP_005055.3 Already existis
# 8878 NP_006508.2 Already existis
# 8879 NP_008831.3 Already existis
# 8880 NP_009184.1 Already existis
# 8881 NP_056411.1 Already existis
# 8882 NP_057513.1 Already existis
# 8883 NP_059141.1 Already existis
# 8884 NP_060035.2 Already existis
# 8885 NP_060944.3 Already existis
# 8886 NP_061747.2 Already existis
# 8887 NP_061748.1 Already existis
# 8888 NP_066002.3 Already existis
# 8889 NP_077278.1 Already existis
# 8890 NP_079488.2 Already existis
# 8891 NP_113610.2 Already existis
# 8892 NP_149038.3 Already existis
# 8893 NP_149091.1 Already existis
# 8894 NP_277050.2 Already existis
# 8895 NP_443115.1 Already existis
# 8896 NP_612431.2 Already existis
# 8897 NP_660315.2 Already existis
# 8898 NP_689686.2 Already existis
# 8899 NP_775896.3 Already existis
# 8900 NP_776170.2 Already existis
# 8901 NP_848128.1 Already existis
# 8902 NP_853636.3 Already existis
# 8903 NP_937828.3 Already existis
# 8904 NP_941962.1 Already existis
# 8905 NP_000095.2 Already existis
# 8906 NP_000756.3 Already existis
# 8907 NP_001002905.1 Already existis
# 8908 NP_001010890.2 Already existis
# 8909 NP_001035173.1 Already existis
# 8910 NP_001036055.2 Already existis
# 8911 NP_001073905.1 Already existis
# 8912 NP_001078892.1 Already existis
# 8913 NP_001078926.1 Already existis
# 8914 NP_001078943.2 Already existis
# 8915 NP_001078945.1 Already existis
# 8916 NP_001083060.1 Already existis
# 8917 NP_001091079.1 Already existis
# 8918 NP_001091976.3 Already existis
# 8919 NP_001103669.1 Already existis
# 8920 NP_001116863.3 Already existis
# 8921 NP_001136202.1 Already existis
# 8922 NP_001138505.1 Already existis
# 8923 NP_001165378.1 Already existis
# 8924 NP_001177391.1 Already existis
# 8925 NP_001181915.1 Already existis
# 8926 NP_001182058.1 Already existis
# 8927 NP_001182067.1 Already existis
# 8928 NP_001182079.1 Already existis
# 8929 NP_001182201.1 Already existis
# 8930 NP_001182371.2 Already existis
# 8931 NP_001182449.1 Already existis
# 8932 NP_001182464.2 Already existis
# 8933 NP_001182762.1 Already existis
# 8934 NP_001186162.1 Already existis
# 8935 NP_001186753.1 Already existis
# 8936 NP_001193560.1 Already existis
# 8937 NP_001230166.1 Already existis
# 8938 NP_001244286.1 Already existis
# 8939 NP_001254645.1 Already existis
# 8940 NP_001258436.1 Already existis
# 8941 NP_001258799.2 Already existis
# 8942 NP_001264332.1 Already existis
# 8943 NP_001269229.1 Already existis
# 8944 NP_001277046.1 Already existis
# 8945 NP_001277622.1 Already existis
# 8946 NP_001278310.1 Already existis
# 8947 NP_001278394.1 Already existis
# 8948 NP_001278395.1 Already existis
# 8949 NP_001278404.1 Already existis
# 8950 NP_001303901.1 Already existis
# 8951 NP_001304036.1 Already existis
# 8952 NP_001304867.2 Already existis
# 8953 NP_001309173.1 Already existis
# 8954 NP_001309176.1 Already existis
# 8955 NP_001316913.1 Already existis
# 8956 NP_001317165.1 Already existis
# 8957 NP_001317377.1 Already existis
# 8958 NP_001336655.1 Already existis
# 8959 NP_001336656.1 Already existis
# 8960 NP_001337923.1 Already existis
# 8961 NP_001338236.1 Already existis
# 8962 NP_001338297.1 Already existis
# 8963 NP_001338518.1 Already existis
# 8964 NP_001338525.1 Already existis
# 8965 NP_001338551.1 Already existis
# 8966 NP_001340379.1 Already existis
# 8967 NP_001341560.1 Already existis
# 8968 NP_001341932.1 Already existis
# 8969 NP_001342148.1 Already existis
# 8970 NP_001342203.1 Already existis
# 8971 NP_001342205.2 Already existis
# 8972 NP_001342463.1 Already existis
# 8973 NP_001342495.1 Already existis
# 8974 NP_001347970.1 Already existis
# 8975 NP_001350436.1 Already existis
# 8976 NP_001350440.1 Already existis
# 8977 NP_001350509.1 Already existis
# 8978 NP_001350723.1 Already existis
# 8979 NP_001350774.1 Already existis
# 8980 NP_001351603.1 Already existis
# 8981 NP_001351606.1 Already existis
# 8982 NP_001352006.1 Already existis
# 8983 NP_001352384.1 Already existis
# 8984 NP_001353161.1 Already existis
# 8985 NP_001354699.1 Already existis
# 8986 NP_001357077.1 Already existis
# 8987 NP_001357297.1 Already existis
# 8988 NP_001362586.1 Already existis
# 8989 NP_001368803.1 Already existis
# 8990 NP_001372337.1 Already existis
# 8991 NP_001373954.1 Already existis
# 8992 NP_001375283.1 Already existis
# 8993 NP_001380867.1 Already existis
# 8994 NP_001381094.1 Already existis
# 8995 NP_001381248.1 Already existis
# 8996 NP_001381686.1 Already existis
# 8997 NP_001381716.1 Already existis
# 8998 NP_001381872.1 Already existis
# 8999 NP_001382260.1 Already existis
# 9000 NP_001382362.1 Already existis
# 9001 NP_001382572.1 Already existis
# 9002 NP_001384416.1 Already existis
# 9003 NP_002761.1 Already existis
# 9004 NP_003514.2 Already existis
# 9005 NP_003633.2 Already existis
# 9006 NP_003715.3 Already existis
# 9007 NP_004820.2 Already existis
# 9008 NP_004883.3 Already existis
# 9009 NP_055333.3 Already existis
# 9010 NP_056468.3 Already existis
# 9011 NP_056540.3 Already existis
# 9012 NP_061992.3 Already existis
# 9013 NP_066008.2 Already existis
# 9014 NP_067627.3 Already existis
# 9015 NP_077078.5 Already existis
# 9016 NP_079135.3 Already existis
# 9017 NP_110425.2 Already existis
# 9018 NP_115727.5 Already existis
# 9019 NP_115897.1 Already existis
# 9020 NP_116126.3 Already existis
# 9021 NP_116741.2 Already existis
# 9022 NP_149042.2 Already existis
# 9023 NP_542778.2 Already existis
# 9024 NP_542942.2 Already existis
# 9025 NP_660154.3 Already existis
# 9026 NP_689840.2 Already existis
# 9027 NP_694579.1 Already existis
# 9028 NP_777582.4 Already existis
# 9029 NP_835229.3 Already existis
# 9030 NP_835466.2 Already existis
# 9031 NP_848638.3 Already existis
# 9032 NP_940968.1 Already existis
# 9033 NP_954870.3 Already existis
# 9034 NP_996740.2 Already existis
# 9035 NP_997304.3 Already existis
# 9036 NP_000548.2 Already existis
# 9037 NP_000859.2 Already existis
# 9038 NP_001009609.2 Already existis
# 9039 NP_001020471.3 Already existis
# 9040 NP_001035531.2 Already existis
# 9041 NP_001094800.1 Already existis
# 9042 NP_001096079.2 Already existis
# 9043 NP_001131021.1 Already existis
# 9044 NP_001137504.2 Already existis
# 9045 NP_001139182.1 Already existis
# 9046 NP_001157734.2 Already existis
# 9047 NP_001157919.1 Already existis
# 9048 NP_001157920.1 Already existis
# 9049 NP_001157922.1 Already existis
# 9050 NP_001157924.1 Already existis
# 9051 NP_001159577.2 Already existis
# 9052 NP_001177984.1 Already existis
# 9053 NP_001180552.1 Already existis
# 9054 NP_001182144.1 Already existis
# 9055 NP_001230141.1 Already existis
# 9056 NP_001245240.1 Already existis
# 9057 NP_001265617.1 Already existis
# 9058 NP_001278464.1 Already existis
# 9059 NP_001296356.1 Already existis
# 9060 NP_001302423.1 Already existis
# 9061 NP_001310008.1 Already existis
# 9062 NP_001317351.1 Already existis
# 9063 NP_001338210.2 Already existis
# 9064 NP_001341568.1 Already existis
# 9065 NP_001341909.1 Already existis
# 9066 NP_001345593.1 Already existis
# 9067 NP_001345628.1 Already existis
# 9068 NP_001346157.1 Already existis
# 9069 NP_001349725.1 Already existis
# 9070 NP_001349739.1 Already existis
# 9071 NP_001350183.1 Already existis
# 9072 NP_001351598.1 Already existis
# 9073 NP_001352032.1 Already existis
# 9074 NP_001352103.1 Already existis
# 9075 NP_001352126.1 Already existis
# 9076 NP_001352300.1 Already existis
# 9077 NP_001355092.1 Already existis
# 9078 NP_001355094.1 Already existis
# 9079 NP_001356054.2 Already existis
# 9080 NP_001356145.1 Already existis
# 9081 NP_001358848.1 Already existis
# 9082 NP_001361767.1 Already existis
# 9083 NP_001365714.1 Already existis
# 9084 NP_001369274.1 Already existis
# 9085 NP_001373443.1 Already existis
# 9086 NP_001373666.1 Already existis
# 9087 NP_001373722.1 Already existis
# 9088 NP_001373723.1 Already existis
# 9089 NP_001373729.1 Already existis
# 9090 NP_001373752.1 Already existis
# 9091 NP_001374493.1 Already existis
# 9092 NP_001375357.1 Already existis
# 9093 NP_001382151.1 Already existis
# 9094 NP_001382182.1 Already existis
# 9095 NP_001382184.1 Already existis
# 9096 NP_001382309.1 Already existis
# 9097 NP_001382331.1 Already existis
# 9098 NP_001382332.1 Already existis
# 9099 NP_001382333.1 Already existis
# 9100 NP_001382334.1 Already existis
# 9101 NP_001382335.1 Already existis
# 9102 NP_001382336.1 Already existis
# 9103 NP_001382337.1 Already existis
# 9104 NP_001382338.1 Already existis
# 9105 NP_001382341.1 Already existis
# 9106 NP_001382849.1 Already existis
# 9107 NP_001382888.1 Already existis
# 9108 NP_001382891.1 Already existis
# 9109 NP_001382901.1 Already existis
# 9110 NP_001382911.1 Already existis
# 9111 NP_001382940.1 Already existis
# 9112 NP_001382941.1 Already existis
# 9113 NP_001382949.1 Already existis
# 9114 NP_001382958.1 Already existis
# 9115 NP_001382980.1 Already existis
# 9116 NP_001382985.1 Already existis
# 9117 NP_001382987.1 Already existis
# 9118 NP_001382988.1 Already existis
# 9119 NP_001382990.1 Already existis
# 9120 NP_001383001.1 Already existis
# 9121 NP_001383004.1 Already existis
# 9122 NP_001383061.1 Already existis
# 9123 NP_001384309.1 Already existis
# 9124 NP_001384311.1 Already existis
# 9125 NP_001384316.1 Already existis
# 9126 NP_002474.4 Already existis
# 9127 NP_004436.4 Already existis
# 9128 NP_005662.2 Already existis
# 9129 NP_005786.1 Already existis
# 9130 NP_006004.3 Already existis
# 9131 NP_006318.1 Already existis
# 9132 NP_057329.3 Already existis
# 9133 NP_061028.3 Already existis
# 9134 NP_061740.2 Already existis
# 9135 NP_064522.4 Already existis
# 9136 NP_077292.2 Already existis
# 9137 NP_077728.3 Already existis
# 9138 NP_079091.3 Already existis
# 9139 NP_619644.1 Already existis
# 9140 NP_758965.2 Already existis
# 9141 NP_997294.3 Already existis
# #-unique NCBI protein sequences downloaded:  9142
# Creating merged fasta document.

# %%
out_filepath = home_dir+f"data/datasets_popu_freq/popu_freq_with_dbnsfp_sampled"
good_data = pd.read_csv(out_filepath+".tsv", sep="\t")

# %%
from utils.plots_dicts import popu_freq_class_order
def print_summary(df, classes):
    print("", "#-genes", "#-proteins", "#-protein-variants", "#-unique-genomic-variants", sep="\t")
    for cls in classes:
        cls_df = df[df["class"]==cls]
        n_genes = cls_df["gene_name"].unique().shape[0]
        n_prots = cls_df["prot_acc_version"].unique().shape[0]
        n_prot_variants = cls_df["prot_variant"].shape[0] # this and the following line are same
        n_genomic_variants = cls_df[["chrom_num", "alfa_chrom_pos", "alfa_ref_allele", "alfa_alt_allele"]].drop_duplicates(keep="first").shape[0] # these keywords are from ALFAs
        print(cls, n_genes, n_prots, n_prot_variants, n_genomic_variants, sep="\t")

    total_n_genes = df["gene_name"].unique().shape[0]
    total_n_prots = df["prot_acc_version"].unique().shape[0]
    total_n_prot_variants = df["prot_variant"].shape[0]
    total_n_genomic_variants = df[["chrom_num", "alfa_chrom_pos", "alfa_ref_allele", "alfa_alt_allele"]].drop_duplicates(keep="first").shape[0] # these keywords are from ALFAs
    print("total", total_n_genes, total_n_prots, total_n_prot_variants, total_n_genomic_variants, sep="\t")

print_summary(good_data, popu_freq_class_order)
# Out:
# 	#-genes	#-proteins	#-protein-variants	#-unique-genomic-variants
# Singleton	9111	9119	9119	9119
# Ultra-rare	9116	9124	9124	9123
# Rare	7693	7697	7697	7693
# Common	9134	9142	9142	9136
# total	9134	9142	35082	35071
