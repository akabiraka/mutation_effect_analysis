# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
home_dir = "../"

import pandas as pd

# %%
from models.aa_common.data_loader import get_popu_freq_SNVs
task = "popu_freq"
variants_df = get_popu_freq_SNVs(home_dir)
# Out:
# Log: Loading data ...
# Index(['snp_id', 'gene_name', 'mane_refseq_prot', 'mane_refseq_nuc',
#        'mane_status', 'chrom_acc_version', 'chrom_num', 'source_ref_allele',
#        'source_alt_alleles', 'alfa_chrom_pos', 'alfa_ref_allele',
#        'alfa_alt_allele', 'alfa_alt_alleles', 'prot_variant',
#        'prot_acc_version', '1indexed_prot_mt_pos', 'wt_aa', 'mt_aa',
#        'wt_population', 'mt_population', 'wt_freq', 'mt_freq', 'class'],
#       dtype='object')
# total:  (1052676, 23)
# #-unique_rsids: 1034905
# #-unique_genes: 16640
# #-unique_refseq_prots: 16671
# Singleton     590841
# Ultra-rare    397925
# Rare           37702
# Common         26208
# Name: class, dtype: int64

# %%
variants_df[variants_df["chrom_num"]=="NT_187606.1"]
# Out:
#              snp_id gene_name mane_refseq_prot mane_refseq_nuc  mane_status  \
# 328036  rs778753849  GOLGA6L4   NP_001254465.2  NM_001267536.3  MANE Select
# 332560  rs778213820  GOLGA6L4   NP_001254465.2  NM_001267536.3  MANE Select
# 437527  rs765522381  GOLGA6L4   NP_001254465.2  NM_001267536.3  MANE Select
# 598838  rs746048806  GOLGA6L4   NP_001254465.2  NM_001267536.3  MANE Select
# 742932  rs368448994  GOLGA6L4   NP_001254465.2  NM_001267536.3  MANE Select
#
#        chrom_acc_version    chrom_num source_ref_allele source_alt_alleles  \
# 328036       NT_187606.1  NT_187606.1                 C                  G
# 332560       NT_187606.1  NT_187606.1                 C                  T
# 437527       NT_187606.1  NT_187606.1                 T                  C
# 598838       NT_187606.1  NT_187606.1                 G                  T
# 742932       NT_187606.1  NT_187606.1                 T                  C
#
#         alfa_chrom_pos  ...                prot_variant prot_acc_version  \
# 328036          134487  ...  NP_001254465.2:p.Glu151Gln   NP_001254465.2
# 332560          134463  ...  NP_001254465.2:p.Val159Ile   NP_001254465.2
# 437527          134438  ...  NP_001254465.2:p.Asn167Ser   NP_001254465.2
# 598838          134477  ...  NP_001254465.2:p.Ala154Glu   NP_001254465.2
# 742932          134355  ...  NP_001254465.2:p.Arg195Gly   NP_001254465.2
#
#        1indexed_prot_mt_pos wt_aa mt_aa  wt_population mt_population  \
# 328036                  151   Glu   Gln           1596           272
# 332560                  159   Val   Ile           1614            16
# 437527                  167   Asn   Ser           1616             6
# 598838                  154   Ala   Glu           1614             1
# 742932                  195   Arg   Gly           1580            20
#
#          wt_freq   mt_freq      class
# 328036  0.854390  0.145610     Common
# 332560  0.990184  0.009816       Rare
# 437527  0.996301  0.003699       Rare
# 598838  0.999381  0.000619  Singleton
# 742932  0.987500  0.012500     Common
#
# [5 rows x 23 columns]
